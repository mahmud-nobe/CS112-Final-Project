# %% [markdown]
# <a href="https://colab.research.google.com/github/mahmud-nobe/CS112-Final-Project/blob/master/Mahmud_CS112_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load and Preapre the Data

# %% [markdown]
#  This is what I did in my Rstudio to get the dataset in csv :
#
#
#
# > `dataset = load("tables1to5.RData")`
#
#  > `dataset`
#
# > `# 'x'`
#
# > `final.data = x`
#
# > `head(final.data)`
#
# > `write.csv(final.data, "tables1to5.csv")`
#
#
#
# Then I upload it in github.

# %%
url = "https://raw.githubusercontent.com/mahmud-nobe/CS112-Final-Project/master/tables1to5.csv"
data = read.csv(url)

# %%
head(data)
# Out:
#   X year stateuni       ipop     imale    pcr_prop  pcr_order  pcr_econ
# 1 1 1985 ANDHRA PRADESH 58733007 29755186 0.3701837 0.01159484 0.12194166
# 2 2 1986 ANDHRA PRADESH 60028840 30416752 0.3218286 0.05244146 0.03141823
# 3 3 1987 ANDHRA PRADESH 61324674 31078317 0.3477393 0.01025688 0.14506397
# 4 4 1988 ANDHRA PRADESH 62620508 31739883 0.4270326 0.08220949 0.04052985
# 5 5 1989 ANDHRA PRADESH 63916341 32401449 0.4614939 0.08195087 0.04596633
# 6 6 1990 ANDHRA PRADESH 65212174 33063015 0.4658639 0.08265328 0.04235406
#   pmurder    pcr_womtot ⋯ lpstrape lpstpoa lpstpcr lparrest_womcrime
# 1 0.02943830 0.06718931 ⋯ NA       NA      NA             NA
# 2 0.02663720 0.06629049 ⋯ NA       NA      NA             NA
# 3 0.02868340 0.05174177 ⋯ NA       NA      NA             NA
# 4 0.03265704 0.06434455 ⋯ NA       NA      NA      -2.295828
# 5 0.03595325 0.07145828 ⋯ NA       NA      NA      -2.153817
# 6 0.04003854 0.05710880 ⋯ NA       NA      NA      -2.437914
#   lparrest_rape lparrest_womgirl lparrest_nonwomen lparrest_kidmen lpmurder_m
# 1        NA            NA               NA                NA       NA
# 2        NA            NA               NA                NA       NA
# 3        NA            NA               NA                NA       NA
# 4 -4.422112     -4.599128        -4.339221         -5.081269       NA
# 5 -4.284273     -4.445257        -4.302086         -4.809580       NA
# 6 -4.500610     -4.538616        -4.560318         -4.442914       NA
#   lpmurder_f
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
str(colnames(data))
# Out:
#  chr [1:81] "X" "year" "stateuni" "ipop" "imale" "pcr_prop" "pcr_order" ...

# %%
data$newstateid<-as.character(data$stateid)
head(data$stateid)
head(data$newstateid)
# Out:
# [1] ANDHRA PRADESH ANDHRA PRADESH ANDHRA PRADESH ANDHRA PRADESH ANDHRA PRADESH
# [6] ANDHRA PRADESH
# 17 Levels: ANDHRA PRADESH ASSAM BIHAR GUJARAT HARYANA ... WEST BENGAL
# [1] "ANDHRA PRADESH" "ANDHRA PRADESH" "ANDHRA PRADESH" "ANDHRA PRADESH"
# [5] "ANDHRA PRADESH" "ANDHRA PRADESH"

# %%
summary(data$stateid)
summary(data$newstateid)
# Out:
#   ANDHRA PRADESH            ASSAM            BIHAR          GUJARAT
#               23               23               23               23
#          HARYANA HIMACHAL PRADESH  JAMMU & KASHMIR        KARNATAKA
#               23               23               23               23
#           KERALA   MADHYA PRADESH      MAHARASHTRA           ORISSA
#               23               23               23               23
#           PUNJAB        RAJASTHAN       TAMIL NADU    UTTAR PRADESH
#               23               23               23               23
#      WEST BENGAL
#               23
#    Length     Class      Mode
#       391 character character

# %%
#Creating a reservation year variable
data$year.res<-NULL
data$year.res[data$stateid == 'ANDHRA PRADESH']<-1995
data$year.res[data$stateid == 'ASSAM']<-2002
data$year.res[data$stateid == 'BIHAR']<-2001
data$year.res[data$stateid == 'GUJARAT']<-1995
data$year.res[data$stateid == 'HARYANA']<-1995
data$year.res[data$stateid == 'HIMACHAL PRADESH']<-1995
data$year.res[data$stateid == 'JAMMU & KASHMIR']<-2001
data$year.res[data$stateid == 'KARNATAKA']<-1987
data$year.res[data$stateid == 'KERALA']<-1991
data$year.res[data$stateid == 'MADHYA PRADESH']<-1994
data$year.res[data$stateid == 'MAHARASHTRA']<-1992
data$year.res[data$stateid == 'ORISSA']<-1992
data$year.res[data$stateid == 'PUNJAB']<-1994
data$year.res[data$stateid == 'RAJASTHAN']<-1995
data$year.res[data$stateid == 'TAMIL NADU']<-1996
data$year.res[data$stateid == 'UTTAR PRADESH']<-2006
data$year.res[data$stateid == 'WEST BENGAL']<-1993

# %%
data$treat <- NULL
data$treat <- as.integer(data$year >= data$year.res)

# %%
data$state <- as.integer(data$stateid)

# %%
#Subsetting data to years post-1994 and reservation post-1994
after.data <- data[which(data$year.res>=1995),]
after.data <- after.data[which(after.data$year>=1995),]
# View(better.data)
head(after.data)
# Out:
#    X  year stateuni       ipop     imale    pcr_prop  pcr_order  pcr_econ
# 11 11 1995 ANDHRA PRADESH 70388808 35645714 0.3257336 0.08722978 0.04314606
# 12 12 1996 ANDHRA PRADESH 71359008 36125997 0.3057217 0.07088103 0.04721198
# 13 13 1997 ANDHRA PRADESH 72329207 36606280 0.3230230 0.06644619 0.06015550
# 14 14 1998 ANDHRA PRADESH 73299407 37086563 0.3350914 0.07862274 0.06476178
# 15 15 1999 ANDHRA PRADESH 74269607 37566847 0.3073532 0.05264603 0.07184635
# 16 16 2000 ANDHRA PRADESH 75239807 38047130 0.3260641 0.04444456 0.07518627
#    pmurder    pcr_womtot ⋯ lparrest_rape lparrest_womgirl lparrest_nonwomen
# 11 0.03511922 0.2424079  ⋯ -4.185441     -4.740167        -4.340173
# 12 0.03656161 0.2523769  ⋯ -4.191689     -4.060709        -4.282272
# 13 0.03970733 0.2805201  ⋯ -3.962047     -4.418194        -4.405653
# 14 0.04054603 0.2887097  ⋯ -4.166159     -4.553323        -5.081213
# 15 0.03650214 0.3282587  ⋯ -4.060061     -4.375981        -4.902295
# 16 0.03593842 0.3652063  ⋯ -4.099138     -4.536352        -4.708059
#    lparrest_kidmen lpmurder_m lpmurder_f newstateid     year.res treat state
# 11 -4.385282             NA          NA  ANDHRA PRADESH 1995     1     1
# 12 -4.906383             NA          NA  ANDHRA PRADESH 1995     1     1
# 13 -4.719733             NA          NA  ANDHRA PRADESH 1995     1     1
# 14 -4.785575             NA          NA  ANDHRA PRADESH 1995     1     1
# 15 -4.361103       -2.87896   -3.994414  ANDHRA PRADESH 1995     1     1
# 16 -4.693194             NA          NA  ANDHRA PRADESH 1995     1     1

# %%
#Subsetting data to years pre-1994 and reservation pre-1994
before.data <- data[which(data$year.res<1995),]
before.data <- before.data[which(before.data$year<1995),]
# View(better.data)
head(before.data)
# Out:
#     X   year stateuni  ipop     imale    pcr_prop  pcr_order pcr_econ
# 162 162 1985 KARNATAKA 40272309 20534343 0.6110650 0.1448390 0.07300302
# 163 163 1986 KARNATAKA 41056458 20937272 0.5563802 0.1464082 0.06396071
# 164 164 1987 KARNATAKA 41840606 21340201 0.5894035 0.1856570 0.06644263
# 165 165 1988 KARNATAKA 42624755 21743130 0.5734696 0.1559188 0.06737868
# 166 166 1989 KARNATAKA 43408904 22146059 0.5705742 0.1552216 0.07337204
# 167 167 1990 KARNATAKA 44193052 22548988 0.6182420 0.1819064 0.07483077
#     pmurder    pcr_womtot ⋯ lparrest_rape lparrest_womgirl lparrest_nonwomen
# 162 0.02515376 0.11753997 ⋯        NA            NA               NA
# 163 0.02601296 0.09900998 ⋯        NA            NA               NA
# 164 0.02650535 0.08170570 ⋯        NA            NA               NA
# 165 0.02981835 0.14668399 ⋯ -5.043419     -4.605751        -4.734059
# 166 0.02796661 0.14932151 ⋯ -5.076301     -4.694484        -4.408559
# 167 0.03045728 0.12640879 ⋯ -5.166894     -5.086851        -4.320787
#     lparrest_kidmen lpmurder_m lpmurder_f newstateid year.res treat state
# 162        NA       NA         NA         KARNATAKA  1987     0     8
# 163        NA       NA         NA         KARNATAKA  1987     0     8
# 164        NA       NA         NA         KARNATAKA  1987     1     8
# 165 -6.768370       NA         NA         KARNATAKA  1987     1     8
# 166 -5.818607       NA         NA         KARNATAKA  1987     1     8
# 167 -5.754681       NA         NA         KARNATAKA  1987     1     8

# %%
## Outcome Variable
# pcr_womtat:Percent of total crime against women

## Treatment Variable
# treat : 0 if the year is before the law passed in the state, 1 otherwise

## Control Variables to Match on
# newstateid: State Name 
# pcgsdp	  : GDP per capita
# pfemale	  : Female-male Ratio
# plit  	  : Percent of Literacy
# pwlit	    : Prcent of Women's Literacy
# prural	  : Percent of rural

# %%
dim(data)
dim(after.data)
dim(before.data)
# Out:
# [1] 391  85
# [1] 130  85
# [1] 70 85

# %%
summary(as.factor(data$treat))
summary(as.factor(after.data$treat))
summary(as.factor(before.data$treat))
# Out:
#   0   1
# 179 212
#  0  1
# 31 99
#  0  1
# 48 22

# %% [markdown]
# ## Replication Figure and Table

# %% [markdown]
# ### Figure

# %%
#install.packages('ggplot2')
require('ggplot2')

############
# Figure 2 #
############

data$res<-"Post"
data$res[data$postwres==0]<-"Pre"

p<-ggplot(data, aes(y=pcr_womtot, x=year, group=newstateid, colour = factor(res))) + 
  geom_point() +facet_wrap( ~ newstateid, ncol = 3) +geom_vline(xintercept = 1993) +
  xlab("Year")+ ylab("Total Crimes against women per 1000 women") +  
  scale_colour_discrete(name = "Reservation Implementation")+theme(legend.position="bottom")

print(p)
# Out:
# plot without title

# %% [markdown]
# ### Table

# %%
# these two packages are necessary to run the next lines of code

install.packages("sandwich")
library(sandwich)

install.packages("lmtest")
library(lmtest)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘zoo’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
# define clustered standard errors function
cl <- function(dat,fm, cluster) {
  require(sandwich, quietly = TRUE)
  require(lmtest, quietly = TRUE)
  M <- length(unique(cluster))
  N <- length(cluster)
  K <- fm$rank
  dfc <- (M/(M-1))*((N-1)/(N-K))
  uj  <- apply(estfun(fm),2, function(x) tapply(x, cluster, sum))
  vcovCL <- dfc*sandwich(fm, meat=crossprod(uj)/N)
  return(list(coeftest(fm, vcovCL), n=round(length(fm$fitted.values),0), rsq=round(summary(fm)$r.squared,2)))
}

# %%
##################################################################
##TABLE 1
#Analysis of the data in Iyer et al. on and after 1995 in states where the reservation policy was implemented in 1995 and after

#Subsetting data to years post-1994 and reservation post-1994
better.data <- data[which(data$year.res>=1995),]
better.data <- data[which(better.data$year>=1995),]
# View(better.data)
head(better.data)
# Out:
#    X  year stateuni       ipop     imale    pcr_prop  pcr_order  pcr_econ
# 11 11 1995 ANDHRA PRADESH 70388808 35645714 0.3257336 0.08722978 0.04314606
# 12 12 1996 ANDHRA PRADESH 71359008 36125997 0.3057217 0.07088103 0.04721198
# 13 13 1997 ANDHRA PRADESH 72329207 36606280 0.3230230 0.06644619 0.06015550
# 14 14 1998 ANDHRA PRADESH 73299407 37086563 0.3350914 0.07862274 0.06476178
# 15 15 1999 ANDHRA PRADESH 74269607 37566847 0.3073532 0.05264603 0.07184635
# 16 16 2000 ANDHRA PRADESH 75239807 38047130 0.3260641 0.04444456 0.07518627
#    pmurder    pcr_womtot ⋯ lparrest_womgirl lparrest_nonwomen lparrest_kidmen
# 11 0.03511922 0.2424079  ⋯ -4.740167        -4.340173         -4.385282
# 12 0.03656161 0.2523769  ⋯ -4.060709        -4.282272         -4.906383
# 13 0.03970733 0.2805201  ⋯ -4.418194        -4.405653         -4.719733
# 14 0.04054603 0.2887097  ⋯ -4.553323        -5.081213         -4.785575
# 15 0.03650214 0.3282587  ⋯ -4.375981        -4.902295         -4.361103
# 16 0.03593842 0.3652063  ⋯ -4.536352        -4.708059         -4.693194
#    lpmurder_m lpmurder_f newstateid     year.res treat state res
# 11       NA          NA  ANDHRA PRADESH 1995     1     1     Post
# 12       NA          NA  ANDHRA PRADESH 1995     1     1     Post
# 13       NA          NA  ANDHRA PRADESH 1995     1     1     Post
# 14       NA          NA  ANDHRA PRADESH 1995     1     1     Post
# 15 -2.87896   -3.994414  ANDHRA PRADESH 1995     1     1     Post
# 16       NA          NA  ANDHRA PRADESH 1995     1     1     Post

# %%
#Running the initial model with post-1995 data, column 1
better.data$newstateid<-as.character(better.data$stateid)
new.column1<-lm(better.data$lpcr_womtot ~ better.data$postwres + factor(better.data$year) + factor(better.data$newstateid), subset=(better.data$majstate==1))
summary(new.column1)
# Out:
# Call:
# lm(formula = better.data$lpcr_womtot ~ better.data$postwres +
#     factor(better.data$year) + factor(better.data$newstateid),
#     subset = (better.data$majstate == 1))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.91519 -0.08505  0.00088  0.10176  0.69992
#
# Coefficients:
#                                                Estimate Std. Error t value
# (Intercept)                                    -1.75246    0.13425 -13.054
# better.data$postwres                            0.20821    0.09751   2.135
# factor(better.data$year)1996                    0.38270    0.11513   3.324
# factor(better.data$year)1997                    0.49516    0.11513   4.301
# factor(better.data$year)1998                    0.56664    0.11513   4.922
# factor(better.data$year)1999                    0.58801    0.11513   5.107
# factor(better.data$year)2000                    0.60838    0.11513   5.284
# factor(better.data$year)2001                    0.62751    0.11677   5.374
# factor(better.data$year)2002                    0.69596    0.11879   5.859
# factor(better.data$year)2003                    0.64287    0.11879   5.412
# factor(better.data$year)2004                    0.69375    0.11879   5.840
# factor(better.data$year)2005                    0.67132    0.11879   5.652
# factor(better.data$year)2006                    0.73013    0.11879   6.147
# factor(better.data$year)2007                    0.79735    0.11879   6.713
# factor(better.data$newstateid)ASSAM            -0.33524    0.11381  -2.946
# factor(better.data$newstateid)BIHAR            -1.08180    0.11055  -9.786
# factor(better.data$newstateid)GUJARAT          -0.77246    0.10097  -7.650
# factor(better.data$newstateid)HARYANA          -0.18966    0.10097  -1.878
# factor(better.data$newstateid)HIMACHAL PRADESH -0.47336    0.10097  -4.688
# factor(better.data$newstateid)JAMMU & KASHMIR  -0.33610    0.11055  -3.040
# factor(better.data$newstateid)KARNATAKA        -0.57365    0.10097  -5.681
# factor(better.data$newstateid)KERALA           -0.23843    0.10097  -2.361
# factor(better.data$newstateid)MADHYA PRADESH    0.12182    0.10097   1.206
#                                                Pr(>|t|)
# (Intercept)                                     < 2e-16 ***
# better.data$postwres                            0.03503 *
# factor(better.data$year)1996                    0.00122 **
# factor(better.data$year)1997                   3.77e-05 ***
# factor(better.data$year)1998                   3.13e-06 ***
# factor(better.data$year)1999                   1.43e-06 ***
# factor(better.data$year)2000                   6.70e-07 ***
# factor(better.data$year)2001                   4.54e-07 ***
# factor(better.data$year)2002                   5.21e-08 ***
# factor(better.data$year)2003                   3.84e-07 ***
# factor(better.data$year)2004                   5.67e-08 ***
# factor(better.data$year)2005                   1.33e-07 ***
# factor(better.data$year)2006                   1.38e-08 ***
# factor(better.data$year)2007                   9.46e-10 ***
# factor(better.data$newstateid)ASSAM             0.00396 **
# factor(better.data$newstateid)BIHAR             < 2e-16 ***
# factor(better.data$newstateid)GUJARAT          9.29e-12 ***
# factor(better.data$newstateid)HARYANA           0.06305 .
# factor(better.data$newstateid)HIMACHAL PRADESH 8.18e-06 ***
# factor(better.data$newstateid)JAMMU & KASHMIR   0.00297 **
# factor(better.data$newstateid)KARNATAKA        1.16e-07 ***
# factor(better.data$newstateid)KERALA            0.02002 *
# factor(better.data$newstateid)MADHYA PRADESH    0.23029
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2574 on 107 degrees of freedom
# Multiple R-squared:  0.7646,	Adjusted R-squared:  0.7162
# F-statistic:  15.8 on 22 and 107 DF,  p-value: < 2.2e-16

# %%
column1.cl<- cl(better.data, new.column1, better.data$newstateid)
column1.cl
# Out:
# [[1]]
#
# t test of coefficients:
#
#                                                   Estimate  Std. Error
# (Intercept)                                    -1.7525e+00  2.1831e-01
# better.data$postwres                            2.0821e-01  1.1064e-01
# factor(better.data$year)1996                    3.8270e-01  2.7883e-01
# factor(better.data$year)1997                    4.9516e-01  2.8622e-01
# factor(better.data$year)1998                    5.6664e-01  2.9932e-01
# factor(better.data$year)1999                    5.8801e-01  2.9469e-01
# factor(better.data$year)2000                    6.0838e-01  2.8010e-01
# factor(better.data$year)2001                    6.2751e-01  2.8098e-01
# factor(better.data$year)2002                    6.9596e-01  2.7692e-01
# factor(better.data$year)2003                    6.4287e-01  2.9687e-01
# factor(better.data$year)2004                    6.9375e-01  3.0588e-01
# factor(better.data$year)2005                    6.7132e-01  3.0401e-01
# factor(better.data$year)2006                    7.3013e-01  3.2049e-01
# factor(better.data$year)2007                    7.9735e-01  3.2009e-01
# factor(better.data$newstateid)ASSAM            -3.3524e-01  5.9576e-02
# factor(better.data$newstateid)BIHAR            -1.0818e+00  5.1065e-02
# factor(better.data$newstateid)GUJARAT          -7.7246e-01  1.2504e-16
# factor(better.data$newstateid)HARYANA          -1.8966e-01  1.3999e-16
# factor(better.data$newstateid)HIMACHAL PRADESH -4.7336e-01  1.3638e-16
# factor(better.data$newstateid)JAMMU & KASHMIR  -3.3610e-01  5.1065e-02
# factor(better.data$newstateid)KARNATAKA        -5.7365e-01  1.3589e-16
# factor(better.data$newstateid)KERALA           -2.3843e-01  1.3681e-16
# factor(better.data$newstateid)MADHYA PRADESH    1.2182e-01  1.2705e-16
#                                                    t value  Pr(>|t|)
# (Intercept)                                    -8.0275e+00 1.378e-12 ***
# better.data$postwres                            1.8819e+00   0.06257 .
# factor(better.data$year)1996                    1.3725e+00   0.17276
# factor(better.data$year)1997                    1.7300e+00   0.08651 .
# factor(better.data$year)1998                    1.8931e+00   0.06105 .
# factor(better.data$year)1999                    1.9954e+00   0.04855 *
# factor(better.data$year)2000                    2.1720e+00   0.03206 *
# factor(better.data$year)2001                    2.2333e+00   0.02761 *
# factor(better.data$year)2002                    2.5132e+00   0.01345 *
# factor(better.data$year)2003                    2.1655e+00   0.03257 *
# factor(better.data$year)2004                    2.2681e+00   0.02533 *
# factor(better.data$year)2005                    2.2083e+00   0.02936 *
# factor(better.data$year)2006                    2.2782e+00   0.02470 *
# factor(better.data$year)2007                    2.4910e+00   0.01427 *
# factor(better.data$newstateid)ASSAM            -5.6272e+00 1.483e-07 ***
# factor(better.data$newstateid)BIHAR            -2.1185e+01 < 2.2e-16 ***
# factor(better.data$newstateid)GUJARAT          -6.1777e+15 < 2.2e-16 ***
# factor(better.data$newstateid)HARYANA          -1.3549e+15 < 2.2e-16 ***
# factor(better.data$newstateid)HIMACHAL PRADESH -3.4710e+15 < 2.2e-16 ***
# factor(better.data$newstateid)JAMMU & KASHMIR  -6.5818e+00 1.773e-09 ***
# factor(better.data$newstateid)KARNATAKA        -4.2215e+15 < 2.2e-16 ***
# factor(better.data$newstateid)KERALA           -1.7427e+15 < 2.2e-16 ***
# factor(better.data$newstateid)MADHYA PRADESH    9.5886e+14 < 2.2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
# $n
# [1] 130
#
# $rsq
# [1] 0.76

# %%
#Running the initial model with post-1995 data, column 6
better.data$newstateid<-as.character(better.data$stateid)
new.total.crimes<-lm(better.data$lpcr_womtot ~ better.data$postwres + better.data$newstateid:better.data$year + better.data$pfemale + better.data$prural + better.data$plit + better.data$pfarm + better.data$womancm + better.data$pcgsdp + better.data$ppol_strengt +
              factor(better.data$year) + factor(better.data$newstateid), subset=(better.data$year>=1985 & better.data$majstate==1))
summary(new.total.crimes)
# Out:
# Call:
# lm(formula = better.data$lpcr_womtot ~ better.data$postwres +
#     better.data$newstateid:better.data$year + better.data$pfemale +
#     better.data$prural + better.data$plit + better.data$pfarm +
#     better.data$womancm + better.data$pcgsdp + better.data$ppol_strengt +
#     factor(better.data$year) + factor(better.data$newstateid),
#     subset = (better.data$year >= 1985 & better.data$majstate ==
#         1))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.05213 -0.09026 -0.00074  0.07835  0.65888
#
# Coefficients: (1 not defined because of singularities)
#                                                           Estimate Std. Error
# (Intercept)                                             1402.59546  394.19170
# better.data$postwres                                      -0.04511    0.16137
# better.data$pfemale                                     -925.37030  199.53770
# better.data$prural                                      -103.07092   91.62905
# better.data$plit                                        -154.68056   38.33032
# better.data$pfarm                                       -368.73463  125.55800
# better.data$womancm                                        0.10381    0.13282
# better.data$pcgsdp                                         1.08961    0.34508
# better.data$ppol_strengt                                  -0.02230    0.08910
# factor(better.data$year)1996                               0.78392    0.51814
# factor(better.data$year)1997                               1.36218    1.00877
# factor(better.data$year)1998                               1.85387    1.48980
# factor(better.data$year)1999                               2.33152    1.95761
# factor(better.data$year)2000                               2.82645    2.41332
# factor(better.data$year)2001                               3.35930    2.86016
# factor(better.data$year)2002                               3.87345    3.29167
# factor(better.data$year)2003                               4.22034    3.71064
# factor(better.data$year)2004                               4.65562    4.11573
# factor(better.data$year)2005                               5.02753    4.51801
# factor(better.data$year)2006                               5.45279    4.91004
# factor(better.data$year)2007                               5.87489    5.28973
# factor(better.data$newstateid)ASSAM                      881.22589  524.69170
# factor(better.data$newstateid)BIHAR                      121.23641  402.29880
# factor(better.data$newstateid)GUJARAT                   3691.56500  762.45487
# factor(better.data$newstateid)HARYANA                   1056.97989  747.89419
# factor(better.data$newstateid)HIMACHAL PRADESH          1678.79433  403.66560
# factor(better.data$newstateid)JAMMU & KASHMIR            556.43231  606.58089
# factor(better.data$newstateid)KARNATAKA                 1152.50512  546.99557
# factor(better.data$newstateid)KERALA                     289.60837  706.18029
# factor(better.data$newstateid)MADHYA PRADESH            -301.43522  232.36055
# better.data$newstateidANDHRA PRADESH:better.data$year     -0.13220    0.11251
# better.data$newstateidASSAM:better.data$year              -0.60376    0.26451
# better.data$newstateidBIHAR:better.data$year              -0.22972    0.19414
# better.data$newstateidGUJARAT:better.data$year            -2.01779    0.39686
# better.data$newstateidHARYANA:better.data$year            -0.72937    0.29355
# better.data$newstateidHIMACHAL PRADESH:better.data$year   -0.96387    0.21265
# better.data$newstateidJAMMU & KASHMIR:better.data$year    -0.47512    0.24249
# better.data$newstateidKARNATAKA:better.data$year          -0.72089    0.22959
# better.data$newstateidKERALA:better.data$year             -0.25040    0.35292
# better.data$newstateidMADHYA PRADESH:better.data$year           NA         NA
#                                                         t value Pr(>|t|)
# (Intercept)                                               3.558 0.000596 ***
# better.data$postwres                                     -0.280 0.780482
# better.data$pfemale                                      -4.638 1.18e-05 ***
# better.data$prural                                       -1.125 0.263602
# better.data$plit                                         -4.035 0.000113 ***
# better.data$pfarm                                        -2.937 0.004200 **
# better.data$womancm                                       0.782 0.436497
# better.data$pcgsdp                                        3.158 0.002159 **
# better.data$ppol_strengt                                 -0.250 0.802919
# factor(better.data$year)1996                              1.513 0.133762
# factor(better.data$year)1997                              1.350 0.180258
# factor(better.data$year)1998                              1.244 0.216557
# factor(better.data$year)1999                              1.191 0.236751
# factor(better.data$year)2000                              1.171 0.244581
# factor(better.data$year)2001                              1.175 0.243252
# factor(better.data$year)2002                              1.177 0.242367
# factor(better.data$year)2003                              1.137 0.258373
# factor(better.data$year)2004                              1.131 0.260953
# factor(better.data$year)2005                              1.113 0.268736
# factor(better.data$year)2006                              1.111 0.269693
# factor(better.data$year)2007                              1.111 0.269658
# factor(better.data$newstateid)ASSAM                       1.680 0.096483 .
# factor(better.data$newstateid)BIHAR                       0.301 0.763828
# factor(better.data$newstateid)GUJARAT                     4.842 5.24e-06 ***
# factor(better.data$newstateid)HARYANA                     1.413 0.160987
# factor(better.data$newstateid)HIMACHAL PRADESH            4.159 7.23e-05 ***
# factor(better.data$newstateid)JAMMU & KASHMIR             0.917 0.361397
# factor(better.data$newstateid)KARNATAKA                   2.107 0.037871 *
# factor(better.data$newstateid)KERALA                      0.410 0.682693
# factor(better.data$newstateid)MADHYA PRADESH             -1.297 0.197816
# better.data$newstateidANDHRA PRADESH:better.data$year    -1.175 0.243051
# better.data$newstateidASSAM:better.data$year             -2.283 0.024784 *
# better.data$newstateidBIHAR:better.data$year             -1.183 0.239780
# better.data$newstateidGUJARAT:better.data$year           -5.084 1.96e-06 ***
# better.data$newstateidHARYANA:better.data$year           -2.485 0.014797 *
# better.data$newstateidHIMACHAL PRADESH:better.data$year  -4.533 1.77e-05 ***
# better.data$newstateidJAMMU & KASHMIR:better.data$year   -1.959 0.053139 .
# better.data$newstateidKARNATAKA:better.data$year         -3.140 0.002280 **
# better.data$newstateidKERALA:better.data$year            -0.709 0.479829
# better.data$newstateidMADHYA PRADESH:better.data$year        NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2013 on 91 degrees of freedom
# Multiple R-squared:  0.8776,	Adjusted R-squared:  0.8265
# F-statistic: 17.18 on 38 and 91 DF,  p-value: < 2.2e-16

# %%
column2.cl<- cl(better.data, new.total.crimes, better.data$newstateid)
column2.cl
# Out:
# [[1]]
#
# t test of coefficients:
#
#                                                            Estimate  Std. Error
# (Intercept)                                             1402.595459  878.371843
# better.data$postwres                                      -0.045107    0.109138
# better.data$pfemale                                     -925.370299  483.936102
# better.data$prural                                      -103.070923  191.481139
# better.data$plit                                        -154.680564   87.696643
# better.data$pfarm                                       -368.734630  250.140219
# better.data$womancm                                        0.103807    0.119418
# better.data$pcgsdp                                         1.089607    1.016926
# better.data$ppol_strengt                                  -0.022301    0.079896
# factor(better.data$year)1996                               0.783919    0.841481
# factor(better.data$year)1997                               1.362176    1.619231
# factor(better.data$year)1998                               1.853869    2.364886
# factor(better.data$year)1999                               2.331517    3.072889
# factor(better.data$year)2000                               2.826450    3.775966
# factor(better.data$year)2001                               3.359302    4.457001
# factor(better.data$year)2002                               3.873448    5.088305
# factor(better.data$year)2003                               4.220339    5.755277
# factor(better.data$year)2004                               4.655625    6.394183
# factor(better.data$year)2005                               5.027526    7.022628
# factor(better.data$year)2006                               5.452792    7.639588
# factor(better.data$year)2007                               5.874888    8.221773
# factor(better.data$newstateid)ASSAM                      881.225888 1103.350707
# factor(better.data$newstateid)BIHAR                      121.236406  739.060190
# factor(better.data$newstateid)GUJARAT                   3691.564999 1919.604408
# factor(better.data$newstateid)HARYANA                   1056.979886 1240.729137
# factor(better.data$newstateid)HIMACHAL PRADESH          1678.794334  810.658962
# factor(better.data$newstateid)JAMMU & KASHMIR            556.432309  902.648720
# factor(better.data$newstateid)KARNATAKA                 1152.505120 1123.226758
# factor(better.data$newstateid)KERALA                     289.608366 1308.160362
# factor(better.data$newstateid)MADHYA PRADESH            -301.435218  383.634395
# better.data$newstateidANDHRA PRADESH:better.data$year     -0.132204    0.182955
# better.data$newstateidASSAM:better.data$year              -0.603763    0.561789
# better.data$newstateidBIHAR:better.data$year              -0.229721    0.327434
# better.data$newstateidGUJARAT:better.data$year            -2.017794    1.056857
# better.data$newstateidHARYANA:better.data$year            -0.729374    0.584778
# better.data$newstateidHIMACHAL PRADESH:better.data$year   -0.963872    0.496586
# better.data$newstateidJAMMU & KASHMIR:better.data$year    -0.475116    0.396343
# better.data$newstateidKARNATAKA:better.data$year          -0.720891    0.548655
# better.data$newstateidKERALA:better.data$year             -0.250397    0.626894
#                                                         t value Pr(>|t|)
# (Intercept)                                              1.5968  0.11377
# better.data$postwres                                    -0.4133  0.68036
# better.data$pfemale                                     -1.9122  0.05900 .
# better.data$prural                                      -0.5383  0.59170
# better.data$plit                                        -1.7638  0.08112 .
# better.data$pfarm                                       -1.4741  0.14390
# better.data$womancm                                      0.8693  0.38698
# better.data$pcgsdp                                       1.0715  0.28679
# better.data$ppol_strengt                                -0.2791  0.78078
# factor(better.data$year)1996                             0.9316  0.35401
# factor(better.data$year)1997                             0.8412  0.40241
# factor(better.data$year)1998                             0.7839  0.43513
# factor(better.data$year)1999                             0.7587  0.44997
# factor(better.data$year)2000                             0.7485  0.45607
# factor(better.data$year)2001                             0.7537  0.45297
# factor(better.data$year)2002                             0.7612  0.44848
# factor(better.data$year)2003                             0.7333  0.46526
# factor(better.data$year)2004                             0.7281  0.46842
# factor(better.data$year)2005                             0.7159  0.47588
# factor(better.data$year)2006                             0.7138  0.47721
# factor(better.data$year)2007                             0.7146  0.47671
# factor(better.data$newstateid)ASSAM                      0.7987  0.42655
# factor(better.data$newstateid)BIHAR                      0.1640  0.87006
# factor(better.data$newstateid)GUJARAT                    1.9231  0.05760 .
# factor(better.data$newstateid)HARYANA                    0.8519  0.39650
# factor(better.data$newstateid)HIMACHAL PRADESH           2.0709  0.04120 *
# factor(better.data$newstateid)JAMMU & KASHMIR            0.6164  0.53914
# factor(better.data$newstateid)KARNATAKA                  1.0261  0.30758
# factor(better.data$newstateid)KERALA                     0.2214  0.82529
# factor(better.data$newstateid)MADHYA PRADESH            -0.7857  0.43406
# better.data$newstateidANDHRA PRADESH:better.data$year   -0.7226  0.47178
# better.data$newstateidASSAM:better.data$year            -1.0747  0.28534
# better.data$newstateidBIHAR:better.data$year            -0.7016  0.48473
# better.data$newstateidGUJARAT:better.data$year          -1.9092  0.05938 .
# better.data$newstateidHARYANA:better.data$year          -1.2473  0.21550
# better.data$newstateidHIMACHAL PRADESH:better.data$year -1.9410  0.05535 .
# better.data$newstateidJAMMU & KASHMIR:better.data$year  -1.1988  0.23374
# better.data$newstateidKARNATAKA:better.data$year        -1.3139  0.19217
# better.data$newstateidKERALA:better.data$year           -0.3994  0.69052
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
# $n
# [1] 130
#
# $rsq
# [1] 0.88

# %%
#Table 3 column 1 code for total crimes against women in Iyer
model1w<-lm(data$lpcr_womtot ~ data$postwres +  
              factor(data$year) + factor(data$newstateid), subset=(data$year>=1985 & data$majstate==1))
summary(model1w)
# Out:
# Call:
# lm(formula = data$lpcr_womtot ~ data$postwres + factor(data$year) +
#     factor(data$newstateid), subset = (data$year >= 1985 & data$majstate ==
#     1))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.82621 -0.21707  0.00651  0.25783  1.56950
#
# Coefficients:
#                                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             -3.14521    0.15331 -20.515  < 2e-16
# data$postwres                            0.36511    0.09573   3.814 0.000162
# factor(data$year)1986                    0.15913    0.16649   0.956 0.339817
# factor(data$year)1987                    0.12377    0.16658   0.743 0.457995
# factor(data$year)1988                    0.27887    0.16658   1.674 0.095012
# factor(data$year)1989                    0.36170    0.16658   2.171 0.030579
# factor(data$year)1990                    0.30469    0.16658   1.829 0.068237
# factor(data$year)1991                    0.25821    0.16687   1.547 0.122674
# factor(data$year)1992                    0.28438    0.16800   1.693 0.091402
# factor(data$year)1993                    0.32019    0.16885   1.896 0.058747
# factor(data$year)1994                    0.27934    0.17109   1.633 0.103431
# factor(data$year)1995                    1.47607    0.17968   8.215 4.12e-15
# factor(data$year)1996                    1.72608    0.18187   9.491  < 2e-16
# factor(data$year)1997                    1.78819    0.18187   9.832  < 2e-16
# factor(data$year)1998                    1.87549    0.18187  10.312  < 2e-16
# factor(data$year)1999                    1.90626    0.18187  10.481  < 2e-16
# factor(data$year)2000                    1.94920    0.18187  10.717  < 2e-16
# factor(data$year)2001                    1.92627    0.18669  10.318  < 2e-16
# factor(data$year)2002                    1.91942    0.18930  10.139  < 2e-16
# factor(data$year)2003                    1.88723    0.18930   9.969  < 2e-16
# factor(data$year)2004                    1.93699    0.18930  10.232  < 2e-16
# factor(data$year)2005                    1.92218    0.18930  10.154  < 2e-16
# factor(data$year)2006                    1.94353    0.19205  10.120  < 2e-16
# factor(data$year)2007                    2.03515    0.19205  10.597  < 2e-16
# factor(data$newstateid)ASSAM            -0.22726    0.14607  -1.556 0.120645
# factor(data$newstateid)BIHAR            -0.81945    0.14530  -5.640 3.51e-08
# factor(data$newstateid)GUJARAT          -1.12832    0.14313  -7.883 4.07e-14
# factor(data$newstateid)HARYANA          -0.52207    0.14313  -3.647 0.000305
# factor(data$newstateid)HIMACHAL PRADESH -0.63358    0.14313  -4.426 1.28e-05
# factor(data$newstateid)JAMMU & KASHMIR  -0.29658    0.14530  -2.041 0.041978
# factor(data$newstateid)KARNATAKA        -0.14696    0.14696  -1.000 0.317982
# factor(data$newstateid)KERALA           -0.71922    0.14410  -4.991 9.47e-07
# factor(data$newstateid)MADHYA PRADESH    0.13818    0.14319   0.965 0.335208
# factor(data$newstateid)MAHARASHTRA      -0.31758    0.14368  -2.210 0.027726
# factor(data$newstateid)ORISSA           -0.80810    0.14368  -5.624 3.81e-08
# factor(data$newstateid)PUNJAB           -1.56178    0.14319 -10.907  < 2e-16
# factor(data$newstateid)RAJASTHAN        -0.18979    0.14313  -1.326 0.185710
# factor(data$newstateid)TAMIL NADU        0.60502    0.14319   4.225 3.05e-05
# factor(data$newstateid)UTTAR PRADESH    -0.53413    0.15028  -3.554 0.000431
# factor(data$newstateid)WEST BENGAL      -0.82391    0.14338  -5.746 1.98e-08
#
# (Intercept)                             ***
# data$postwres                           ***
# factor(data$year)1986
# factor(data$year)1987
# factor(data$year)1988                   .
# factor(data$year)1989                   *
# factor(data$year)1990                   .
# factor(data$year)1991
# factor(data$year)1992                   .
# factor(data$year)1993                   .
# factor(data$year)1994
# factor(data$year)1995                   ***
# factor(data$year)1996                   ***
# factor(data$year)1997                   ***
# factor(data$year)1998                   ***
# factor(data$year)1999                   ***
# factor(data$year)2000                   ***
# factor(data$year)2001                   ***
# factor(data$year)2002                   ***
# factor(data$year)2003                   ***
# factor(data$year)2004                   ***
# factor(data$year)2005                   ***
# factor(data$year)2006                   ***
# factor(data$year)2007                   ***
# factor(data$newstateid)ASSAM
# factor(data$newstateid)BIHAR            ***
# factor(data$newstateid)GUJARAT          ***
# factor(data$newstateid)HARYANA          ***
# factor(data$newstateid)HIMACHAL PRADESH ***
# factor(data$newstateid)JAMMU & KASHMIR  *
# factor(data$newstateid)KARNATAKA
# factor(data$newstateid)KERALA           ***
# factor(data$newstateid)MADHYA PRADESH
# factor(data$newstateid)MAHARASHTRA      *
# factor(data$newstateid)ORISSA           ***
# factor(data$newstateid)PUNJAB           ***
# factor(data$newstateid)RAJASTHAN
# factor(data$newstateid)TAMIL NADU       ***
# factor(data$newstateid)UTTAR PRADESH    ***
# factor(data$newstateid)WEST BENGAL      ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4854 on 351 degrees of freedom
# Multiple R-squared:  0.846,	Adjusted R-squared:  0.8289
# F-statistic: 49.46 on 39 and 351 DF,  p-value: < 2.2e-16

# %%
model1cw<- cl(data, model1w, data$newstateid)
model1cw
# Out:
# [[1]]
#
# t test of coefficients:
#
#                                            Estimate  Std. Error     t value
# (Intercept)                             -3.1452e+00  2.3829e-01 -1.3199e+01
# data$postwres                            3.6511e-01  1.9031e-01  1.9185e+00
# factor(data$year)1986                    1.5913e-01  1.5517e-01  1.0255e+00
# factor(data$year)1987                    1.2377e-01  1.7864e-01  6.9280e-01
# factor(data$year)1988                    2.7887e-01  1.8055e-01  1.5446e+00
# factor(data$year)1989                    3.6170e-01  2.0170e-01  1.7933e+00
# factor(data$year)1990                    3.0469e-01  2.2600e-01  1.3482e+00
# factor(data$year)1991                    2.5821e-01  2.0731e-01  1.2455e+00
# factor(data$year)1992                    2.8438e-01  2.0276e-01  1.4026e+00
# factor(data$year)1993                    3.2019e-01  2.1805e-01  1.4684e+00
# factor(data$year)1994                    2.7934e-01  2.5292e-01  1.1045e+00
# factor(data$year)1995                    1.4761e+00  3.0806e-01  4.7914e+00
# factor(data$year)1996                    1.7261e+00  3.1538e-01  5.4731e+00
# factor(data$year)1997                    1.7882e+00  3.2142e-01  5.5634e+00
# factor(data$year)1998                    1.8755e+00  3.2260e-01  5.8136e+00
# factor(data$year)1999                    1.9063e+00  3.2196e-01  5.9208e+00
# factor(data$year)2000                    1.9492e+00  3.1932e-01  6.1042e+00
# factor(data$year)2001                    1.9263e+00  3.3976e-01  5.6695e+00
# factor(data$year)2002                    1.9194e+00  3.4023e-01  5.6415e+00
# factor(data$year)2003                    1.8872e+00  3.4327e-01  5.4978e+00
# factor(data$year)2004                    1.9370e+00  3.5190e-01  5.5044e+00
# factor(data$year)2005                    1.9222e+00  3.5589e-01  5.4010e+00
# factor(data$year)2006                    1.9435e+00  3.7136e-01  5.2336e+00
# factor(data$year)2007                    2.0351e+00  3.7053e-01  5.4925e+00
# factor(data$newstateid)ASSAM            -2.2726e-01  5.7920e-02 -3.9237e+00
# factor(data$newstateid)BIHAR            -8.1945e-01  4.9645e-02 -1.6506e+01
# factor(data$newstateid)GUJARAT          -1.1283e+00  2.1138e-16 -5.3378e+15
# factor(data$newstateid)HARYANA          -5.2207e-01  1.9020e-16 -2.7448e+15
# factor(data$newstateid)HIMACHAL PRADESH -6.3358e-01  1.8893e-16 -3.3534e+15
# factor(data$newstateid)JAMMU & KASHMIR  -2.9658e-01  4.9645e-02 -5.9739e+00
# factor(data$newstateid)KARNATAKA        -1.4696e-01  6.6194e-02 -2.2202e+00
# factor(data$newstateid)KERALA           -7.1922e-01  3.3097e-02 -2.1731e+01
# factor(data$newstateid)MADHYA PRADESH    1.3818e-01  8.2742e-03  1.6700e+01
# factor(data$newstateid)MAHARASHTRA      -3.1758e-01  2.4823e-02 -1.2794e+01
# factor(data$newstateid)ORISSA           -8.0810e-01  2.4823e-02 -3.2555e+01
# factor(data$newstateid)PUNJAB           -1.5618e+00  8.2742e-03 -1.8875e+02
# factor(data$newstateid)RAJASTHAN        -1.8979e-01  1.7297e-16 -1.0973e+15
# factor(data$newstateid)TAMIL NADU        6.0502e-01  8.2742e-03  7.3121e+01
# factor(data$newstateid)UTTAR PRADESH    -5.3413e-01  9.1017e-02 -5.8685e+00
# factor(data$newstateid)WEST BENGAL      -8.2391e-01  1.6548e-02 -4.9788e+01
#                                          Pr(>|t|)
# (Intercept)                             < 2.2e-16 ***
# data$postwres                           0.0558573 .
# factor(data$year)1986                   0.3058137
# factor(data$year)1987                   0.4888786
# factor(data$year)1988                   0.1233482
# factor(data$year)1989                   0.0737913 .
# factor(data$year)1990                   0.1784722
# factor(data$year)1991                   0.2137738
# factor(data$year)1992                   0.1616317
# factor(data$year)1993                   0.1428953
# factor(data$year)1994                   0.2701486
# factor(data$year)1995                   2.448e-06 ***
# factor(data$year)1996                   8.434e-08 ***
# factor(data$year)1997                   5.256e-08 ***
# factor(data$year)1998                   1.375e-08 ***
# factor(data$year)1999                   7.631e-09 ***
# factor(data$year)2000                   2.737e-09 ***
# factor(data$year)2001                   2.993e-08 ***
# factor(data$year)2002                   3.475e-08 ***
# factor(data$year)2003                   7.415e-08 ***
# factor(data$year)2004                   7.163e-08 ***
# factor(data$year)2005                   1.224e-07 ***
# factor(data$year)2006                   2.868e-07 ***
# factor(data$year)2007                   7.619e-08 ***
# factor(data$newstateid)ASSAM            0.0001049 ***
# factor(data$newstateid)BIHAR            < 2.2e-16 ***
# factor(data$newstateid)GUJARAT          < 2.2e-16 ***
# factor(data$newstateid)HARYANA          < 2.2e-16 ***
# factor(data$newstateid)HIMACHAL PRADESH < 2.2e-16 ***
# factor(data$newstateid)JAMMU & KASHMIR  5.684e-09 ***
# factor(data$newstateid)KARNATAKA        0.0270460 *
# factor(data$newstateid)KERALA           < 2.2e-16 ***
# factor(data$newstateid)MADHYA PRADESH   < 2.2e-16 ***
# factor(data$newstateid)MAHARASHTRA      < 2.2e-16 ***
# factor(data$newstateid)ORISSA           < 2.2e-16 ***
# factor(data$newstateid)PUNJAB           < 2.2e-16 ***
# factor(data$newstateid)RAJASTHAN        < 2.2e-16 ***
# factor(data$newstateid)TAMIL NADU       < 2.2e-16 ***
# factor(data$newstateid)UTTAR PRADESH    1.018e-08 ***
# factor(data$newstateid)WEST BENGAL      < 2.2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
# $n
# [1] 391
#
# $rsq
# [1] 0.85

# %%
# Table 3 column 6 code for total crimes against women in Iyer
model6w<-lm(data$lpcr_womtot ~ data$postwres + data$newstateid:data$year + data$pfemale + data$prural + data$plit + data$pfarm + data$womancm + data$pcgsdp + data$ppol_strengt +
              factor(data$year) + factor(data$newstateid), subset=(data$year>=1985 & data$majstate==1))
summary(model6w)
# Out:
# Call:
# lm(formula = data$lpcr_womtot ~ data$postwres + data$newstateid:data$year +
#     data$pfemale + data$prural + data$plit + data$pfarm + data$womancm +
#     data$pcgsdp + data$ppol_strengt + factor(data$year) + factor(data$newstateid),
#     subset = (data$year >= 1985 & data$majstate == 1))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.87459 -0.11660 -0.00157  0.12497  0.70362
#
# Coefficients: (1 not defined because of singularities)
#                                             Estimate Std. Error t value
# (Intercept)                               -1.815e+01  5.308e+01  -0.342
# data$postwres                              2.288e-01  6.158e-02   3.716
# data$pfemale                              -2.046e+01  1.045e+01  -1.958
# data$prural                                1.184e+01  4.436e+00   2.668
# data$plit                                 -2.896e+00  3.615e+00  -0.801
# data$pfarm                                 1.615e+01  6.929e+00   2.331
# data$womancm                              -6.440e-02  7.653e-02  -0.842
# data$pcgsdp                               -1.893e-01  9.523e-02  -1.987
# data$ppol_strengt                         -9.182e-02  7.322e-02  -1.254
# factor(data$year)1986                      2.072e-01  9.911e-02   2.091
# factor(data$year)1987                      2.465e-01  1.112e-01   2.217
# factor(data$year)1988                      4.498e-01  1.266e-01   3.552
# factor(data$year)1989                      5.886e-01  1.456e-01   4.044
# factor(data$year)1990                      5.824e-01  1.660e-01   3.509
# factor(data$year)1991                      5.851e-01  1.858e-01   3.148
# factor(data$year)1992                      8.224e-01  2.124e-01   3.872
# factor(data$year)1993                      1.061e+00  2.437e-01   4.355
# factor(data$year)1994                      1.221e+00  2.766e-01   4.413
# factor(data$year)1995                      2.635e+00  3.104e-01   8.488
# factor(data$year)1996                      3.049e+00  3.437e-01   8.871
# factor(data$year)1997                      3.284e+00  3.769e-01   8.713
# factor(data$year)1998                      3.533e+00  4.100e-01   8.617
# factor(data$year)1999                      3.719e+00  4.421e-01   8.413
# factor(data$year)2000                      3.905e+00  4.728e-01   8.259
# factor(data$year)2001                      4.053e+00  5.040e-01   8.041
# factor(data$year)2002                      4.196e+00  5.337e-01   7.861
# factor(data$year)2003                      4.311e+00  5.635e-01   7.650
# factor(data$year)2004                      4.509e+00  5.927e-01   7.608
# factor(data$year)2005                      4.633e+00  6.215e-01   7.455
# factor(data$year)2006                      4.803e+00  6.504e-01   7.385
# factor(data$year)2007                      5.008e+00  6.758e-01   7.411
# factor(data$newstateid)ASSAM               5.440e-01  4.651e+01   0.012
# factor(data$newstateid)BIHAR               1.346e+02  4.915e+01   2.738
# factor(data$newstateid)GUJARAT            -1.011e+01  5.396e+01  -0.187
# factor(data$newstateid)HARYANA            -4.356e+01  4.932e+01  -0.883
# factor(data$newstateid)HIMACHAL PRADESH    4.042e+01  3.281e+01   1.232
# factor(data$newstateid)JAMMU & KASHMIR     1.206e+02  4.661e+01   2.588
# factor(data$newstateid)KARNATAKA           1.843e+02  4.021e+01   4.584
# factor(data$newstateid)KERALA             -1.243e+02  8.320e+01  -1.495
# factor(data$newstateid)MADHYA PRADESH      1.548e+01  2.730e+01   0.567
# factor(data$newstateid)MAHARASHTRA         9.390e+01  4.294e+01   2.187
# factor(data$newstateid)ORISSA             -1.754e+02  4.356e+01  -4.027
# factor(data$newstateid)PUNJAB             -9.378e+01  4.293e+01  -2.184
# factor(data$newstateid)RAJASTHAN           5.888e+01  5.628e+01   1.046
# factor(data$newstateid)TAMIL NADU          1.306e+02  7.848e+01   1.664
# factor(data$newstateid)UTTAR PRADESH       3.518e+00  4.137e+01   0.085
# factor(data$newstateid)WEST BENGAL         2.312e+01  4.692e+01   0.493
# data$newstateidANDHRA PRADESH:data$year    1.136e-02  2.310e-02   0.492
# data$newstateidASSAM:data$year             1.047e-02  2.016e-02   0.519
# data$newstateidBIHAR:data$year            -5.768e-02  2.272e-02  -2.539
# data$newstateidGUJARAT:data$year           1.677e-02  2.942e-02   0.570
# data$newstateidHARYANA:data$year           3.282e-02  2.484e-02   1.321
# data$newstateidHIMACHAL PRADESH:data$year -9.590e-03  2.517e-02  -0.381
# data$newstateidJAMMU & KASHMIR:data$year  -4.906e-02  2.146e-02  -2.287
# data$newstateidKARNATAKA:data$year        -8.037e-02  1.912e-02  -4.204
# data$newstateidKERALA:data$year            7.595e-02  3.076e-02   2.469
# data$newstateidMADHYA PRADESH:data$year    3.093e-03  2.473e-02   0.125
# data$newstateidMAHARASHTRA:data$year      -3.482e-02  2.870e-02  -1.213
# data$newstateidORISSA:data$year            9.857e-02  3.299e-02   2.988
# data$newstateidPUNJAB:data$year            5.810e-02  2.428e-02   2.393
# data$newstateidRAJASTHAN:data$year        -1.870e-02  2.730e-02  -0.685
# data$newstateidTAMIL NADU:data$year       -5.223e-02  3.663e-02  -1.426
# data$newstateidUTTAR PRADESH:data$year     8.551e-03  1.568e-02   0.545
# data$newstateidWEST BENGAL:data$year              NA         NA      NA
#                                           Pr(>|t|)
# (Intercept)                               0.732594
# data$postwres                             0.000237 ***
# data$pfemale                              0.051086 .
# data$prural                               0.008015 **
# data$plit                                 0.423777
# data$pfarm                                0.020382 *
# data$womancm                              0.400676
# data$pcgsdp                               0.047701 *
# data$ppol_strengt                         0.210733
# factor(data$year)1986                     0.037305 *
# factor(data$year)1987                     0.027310 *
# factor(data$year)1988                     0.000439 ***
# factor(data$year)1989                     6.57e-05 ***
# factor(data$year)1990                     0.000512 ***
# factor(data$year)1991                     0.001793 **
# factor(data$year)1992                     0.000131 ***
# factor(data$year)1993                     1.78e-05 ***
# factor(data$year)1994                     1.39e-05 ***
# factor(data$year)1995                     7.36e-16 ***
# factor(data$year)1996                      < 2e-16 ***
# factor(data$year)1997                      < 2e-16 ***
# factor(data$year)1998                     2.96e-16 ***
# factor(data$year)1999                     1.25e-15 ***
# factor(data$year)2000                     3.66e-15 ***
# factor(data$year)2001                     1.63e-14 ***
# factor(data$year)2002                     5.53e-14 ***
# factor(data$year)2003                     2.26e-13 ***
# factor(data$year)2004                     2.98e-13 ***
# factor(data$year)2005                     8.08e-13 ***
# factor(data$year)2006                     1.27e-12 ***
# factor(data$year)2007                     1.07e-12 ***
# factor(data$newstateid)ASSAM              0.990674
# factor(data$newstateid)BIHAR              0.006511 **
# factor(data$newstateid)GUJARAT            0.851513
# factor(data$newstateid)HARYANA            0.377729
# factor(data$newstateid)HIMACHAL PRADESH   0.218846
# factor(data$newstateid)JAMMU & KASHMIR    0.010094 *
# factor(data$newstateid)KARNATAKA          6.49e-06 ***
# factor(data$newstateid)KERALA             0.135997
# factor(data$newstateid)MADHYA PRADESH     0.571001
# factor(data$newstateid)MAHARASHTRA        0.029465 *
# factor(data$newstateid)ORISSA             7.01e-05 ***
# factor(data$newstateid)PUNJAB             0.029654 *
# factor(data$newstateid)RAJASTHAN          0.296297
# factor(data$newstateid)TAMIL NADU         0.097087 .
# factor(data$newstateid)UTTAR PRADESH      0.932279
# factor(data$newstateid)WEST BENGAL        0.622464
# data$newstateidANDHRA PRADESH:data$year   0.623349
# data$newstateidASSAM:data$year            0.604047
# data$newstateidBIHAR:data$year            0.011578 *
# data$newstateidGUJARAT:data$year          0.568989
# data$newstateidHARYANA:data$year          0.187269
# data$newstateidHIMACHAL PRADESH:data$year 0.703490
# data$newstateidJAMMU & KASHMIR:data$year  0.022848 *
# data$newstateidKARNATAKA:data$year        3.39e-05 ***
# data$newstateidKERALA:data$year           0.014054 *
# data$newstateidMADHYA PRADESH:data$year   0.900538
# data$newstateidMAHARASHTRA:data$year      0.225878
# data$newstateidORISSA:data$year           0.003021 **
# data$newstateidPUNJAB:data$year           0.017285 *
# data$newstateidRAJASTHAN:data$year        0.493751
# data$newstateidTAMIL NADU:data$year       0.154847
# data$newstateidUTTAR PRADESH:data$year    0.585919
# data$newstateidWEST BENGAL:data$year            NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2766 on 328 degrees of freedom
# Multiple R-squared:  0.9533,	Adjusted R-squared:  0.9445
# F-statistic:   108 on 62 and 328 DF,  p-value: < 2.2e-16

# %%
model6cw<- cl(data, model6w, data$newstateid)
model6cw
# Out:
# [[1]]
#
# t test of coefficients:
#
#                                              Estimate  Std. Error t value
# (Intercept)                               -1.8151e+01  9.9215e+01 -0.1829
# data$postwres                              2.2885e-01  8.4441e-02  2.7102
# data$pfemale                              -2.0461e+01  1.8347e+01 -1.1153
# data$prural                                1.1835e+01  7.0727e+00  1.6734
# data$plit                                 -2.8955e+00  5.1406e+00 -0.5633
# data$pfarm                                 1.6149e+01  1.3363e+01  1.2085
# data$womancm                              -6.4402e-02  7.0851e-02 -0.9090
# data$pcgsdp                               -1.8927e-01  1.0245e-01 -1.8474
# data$ppol_strengt                         -9.1816e-02  5.3947e-02 -1.7020
# factor(data$year)1986                      2.0723e-01  1.5085e-01  1.3737
# factor(data$year)1987                      2.4650e-01  1.8910e-01  1.3036
# factor(data$year)1988                      4.4976e-01  1.9259e-01  2.3352
# factor(data$year)1989                      5.8862e-01  2.2554e-01  2.6099
# factor(data$year)1990                      5.8241e-01  2.4776e-01  2.3507
# factor(data$year)1991                      5.8509e-01  2.4574e-01  2.3809
# factor(data$year)1992                      8.2236e-01  3.1523e-01  2.6087
# factor(data$year)1993                      1.0613e+00  3.9733e-01  2.6710
# factor(data$year)1994                      1.2205e+00  4.9610e-01  2.4602
# factor(data$year)1995                      2.6348e+00  6.3049e-01  4.1789
# factor(data$year)1996                      3.0489e+00  6.9951e-01  4.3586
# factor(data$year)1997                      3.2843e+00  7.8334e-01  4.1926
# factor(data$year)1998                      3.5329e+00  8.4998e-01  4.1564
# factor(data$year)1999                      3.7192e+00  9.1609e-01  4.0599
# factor(data$year)2000                      3.9051e+00  9.7249e-01  4.0156
# factor(data$year)2001                      4.0531e+00  1.0410e+00  3.8936
# factor(data$year)2002                      4.1956e+00  1.1034e+00  3.8024
# factor(data$year)2003                      4.3107e+00  1.1676e+00  3.6921
# factor(data$year)2004                      4.5091e+00  1.2255e+00  3.6795
# factor(data$year)2005                      4.6331e+00  1.2838e+00  3.6088
# factor(data$year)2006                      4.8031e+00  1.3483e+00  3.5622
# factor(data$year)2007                      5.0083e+00  1.3872e+00  3.6104
# factor(data$newstateid)ASSAM               5.4398e-01  6.4401e+01  0.0084
# factor(data$newstateid)BIHAR               1.3458e+02  6.9888e+01  1.9257
# factor(data$newstateid)GUJARAT            -1.0109e+01  9.6203e+01 -0.1051
# factor(data$newstateid)HARYANA            -4.3560e+01  9.1519e+01 -0.4760
# factor(data$newstateid)HIMACHAL PRADESH    4.0421e+01  4.7944e+01  0.8431
# factor(data$newstateid)JAMMU & KASHMIR     1.2061e+02  8.2609e+01  1.4600
# factor(data$newstateid)KARNATAKA           1.8431e+02  6.2237e+01  2.9615
# factor(data$newstateid)KERALA             -1.2434e+02  1.3421e+02 -0.9265
# factor(data$newstateid)MADHYA PRADESH      1.5481e+01  1.6889e+01  0.9167
# factor(data$newstateid)MAHARASHTRA         9.3901e+01  6.8029e+01  1.3803
# factor(data$newstateid)ORISSA             -1.7542e+02  5.1033e+01 -3.4374
# factor(data$newstateid)PUNJAB             -9.3779e+01  7.2151e+01 -1.2998
# factor(data$newstateid)RAJASTHAN           5.8875e+01  8.7908e+01  0.6697
# factor(data$newstateid)TAMIL NADU          1.3058e+02  1.1907e+02  1.0966
# factor(data$newstateid)UTTAR PRADESH       3.5180e+00  6.4685e+01  0.0544
# factor(data$newstateid)WEST BENGAL         2.3121e+01  8.6980e+01  0.2658
# data$newstateidANDHRA PRADESH:data$year    1.1357e-02  4.2534e-02  0.2670
# data$newstateidASSAM:data$year             1.0467e-02  2.6676e-02  0.3924
# data$newstateidBIHAR:data$year            -5.7683e-02  2.5423e-02 -2.2689
# data$newstateidGUJARAT:data$year           1.6773e-02  4.8548e-02  0.3455
# data$newstateidHARYANA:data$year           3.2824e-02  4.0823e-02  0.8041
# data$newstateidHIMACHAL PRADESH:data$year -9.5901e-03  4.2791e-02 -0.2241
# data$newstateidJAMMU & KASHMIR:data$year  -4.9064e-02  2.3478e-02 -2.0898
# data$newstateidKARNATAKA:data$year        -8.0371e-02  2.6277e-02 -3.0586
# data$newstateidKERALA:data$year            7.5954e-02  3.7837e-02  2.0074
# data$newstateidMADHYA PRADESH:data$year    3.0926e-03  4.4367e-02  0.0697
# data$newstateidMAHARASHTRA:data$year      -3.4822e-02  4.9630e-02 -0.7016
# data$newstateidORISSA:data$year            9.8567e-02  6.1115e-02  1.6128
# data$newstateidPUNJAB:data$year            5.8099e-02  3.8890e-02  1.4939
# data$newstateidRAJASTHAN:data$year        -1.8703e-02  3.3731e-02 -0.5545
# data$newstateidTAMIL NADU:data$year       -5.2228e-02  5.7214e-02 -0.9128
# data$newstateidUTTAR PRADESH:data$year     8.5512e-03  2.2513e-02  0.3798
#                                            Pr(>|t|)
# (Intercept)                               0.8549503
# data$postwres                             0.0070789 **
# data$pfemale                              0.2655569
# data$prural                               0.0952026 .
# data$plit                                 0.5736407
# data$pfarm                                0.2277393
# data$womancm                              0.3640278
# data$pcgsdp                               0.0655931 .
# data$ppol_strengt                         0.0897055 .
# factor(data$year)1986                     0.1704616
# factor(data$year)1987                     0.1933005
# factor(data$year)1988                     0.0201332 *
# factor(data$year)1989                     0.0094734 **
# factor(data$year)1990                     0.0193275 *
# factor(data$year)1991                     0.0178388 *
# factor(data$year)1992                     0.0095035 **
# factor(data$year)1993                     0.0079395 **
# factor(data$year)1994                     0.0143994 *
# factor(data$year)1995                     3.761e-05 ***
# factor(data$year)1996                     1.754e-05 ***
# factor(data$year)1997                     3.552e-05 ***
# factor(data$year)1998                     4.130e-05 ***
# factor(data$year)1999                     6.145e-05 ***
# factor(data$year)2000                     7.355e-05 ***
# factor(data$year)2001                     0.0001197 ***
# factor(data$year)2002                     0.0001708 ***
# factor(data$year)2003                     0.0002604 ***
# factor(data$year)2004                     0.0002731 ***
# factor(data$year)2005                     0.0003557 ***
# factor(data$year)2006                     0.0004222 ***
# factor(data$year)2007                     0.0003535 ***
# factor(data$newstateid)ASSAM              0.9932657
# factor(data$newstateid)BIHAR              0.0550058 .
# factor(data$newstateid)GUJARAT            0.9163750
# factor(data$newstateid)HARYANA            0.6344151
# factor(data$newstateid)HIMACHAL PRADESH   0.3997883
# factor(data$newstateid)JAMMU & KASHMIR    0.1452450
# factor(data$newstateid)KARNATAKA          0.0032853 **
# factor(data$newstateid)KERALA             0.3548866
# factor(data$newstateid)MADHYA PRADESH     0.3599973
# factor(data$newstateid)MAHARASHTRA        0.1684313
# factor(data$newstateid)ORISSA             0.0006630 ***
# factor(data$newstateid)PUNJAB             0.1945951
# factor(data$newstateid)RAJASTHAN          0.5034949
# factor(data$newstateid)TAMIL NADU         0.2736008
# factor(data$newstateid)UTTAR PRADESH      0.9566603
# factor(data$newstateid)WEST BENGAL        0.7905415
# data$newstateidANDHRA PRADESH:data$year   0.7896286
# data$newstateidASSAM:data$year            0.6950320
# data$newstateidBIHAR:data$year            0.0239212 *
# data$newstateidGUJARAT:data$year          0.7299406
# data$newstateidHARYANA:data$year          0.4219485
# data$newstateidHIMACHAL PRADESH:data$year 0.8228080
# data$newstateidJAMMU & KASHMIR:data$year  0.0374047 *
# data$newstateidKARNATAKA:data$year        0.0024070 **
# data$newstateidKERALA:data$year           0.0455275 *
# data$newstateidMADHYA PRADESH:data$year   0.9444708
# data$newstateidMAHARASHTRA:data$year      0.4834063
# data$newstateidORISSA:data$year           0.1077498
# data$newstateidPUNJAB:data$year           0.1361502
# data$newstateidRAJASTHAN:data$year        0.5796355
# data$newstateidTAMIL NADU:data$year       0.3619959
# data$newstateidUTTAR PRADESH:data$year    0.7043099
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
# $n
# [1] 391
#
# $rsq
# [1] 0.95

# %%
# Outputting the results from the model restricted to post-1995
table2.1<-as.matrix(c(round(column1.cl[[1]]["better.data$postwres",1],3),paste("[",round(column1.cl[[1]]["better.data$postwres",2],3),"]"),round(column1.cl[[3]],2), round(column1.cl[[2]],0) ))
table2.2<-as.matrix(c(round(column2.cl[[1]]["better.data$postwres",1],3),paste("[",round(column2.cl[[1]]["better.data$postwres",2],3),"]"),round(column2.cl[[3]],2), round(column2.cl[[2]],0) ))
table2.3<-as.matrix(c(round(model1cw[[1]]["data$postwres",1],3),paste("[",round(model1cw[[1]]["data$postwres",2],3),"]"),round(model1cw[[3]],2), round(model1cw[[2]],0) ))
table2.4<-as.matrix(c(round(model6cw[[1]]["data$postwres",1],3),paste("[",round(model6cw[[1]]["data$postwres",2],3),"]"),round(model6cw[[3]],2), round(model6cw[[2]],0) ))

# %%
table2_out <- matrix(NA,nrow=8,ncol=2)
table2_out[1:4,1] <- table2.1
table2_out[1:4,2] <- table2.2
table2_out[5:8,1] <- table2.3
table2_out[5:8,2] <- table2.4

# %%
colnames(table2_out) <- c("No controls (1)", "Control for state-specific time trends + other controls (2)")
rownames(table2_out)<- c("Total crimes against women per 1,000 women", "", "R2", "Observations",
                         "Total crimes against women per 1,000 women", "", "R2", "Observations")

(table2_out)
# Out:
#                                            No controls (1)
# Total crimes against women per 1,000 women 0.208
#                                            [ 0.111 ]
# R2                                         0.76
# Observations                               130
# Total crimes against women per 1,000 women 0.365
#                                            [ 0.19 ]
# R2                                         0.85
# Observations                               391
#                                            Control for state-specific time trends + other controls (2)
# Total crimes against women per 1,000 women -0.045
#                                            [ 0.109 ]
# R2                                         0.88
# Observations                               130
# Total crimes against women per 1,000 women 0.229
#                                            [ 0.084 ]
# R2                                         0.95
# Observations                               391

# %%
install.packages('stargazer')
library(stargazer)
stargazer(table2_out,title="Women's Political Representation and Crimes against Women")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# % Table created by stargazer v.5.2.2 by Marek Hlavac, Harvard University. E-mail: hlavac at fas.harvard.edu
# % Date and time: Fri, Dec 20, 2019 - 06:27:25 AM
# \begin{table}[!htbp] \centering
#   \caption{Women's Political Representation and Crimes against Women}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}} ccc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & No controls (1) & Control for state-specific time trends + other controls (2) \\
# \hline \\[-1.8ex]
# Total.crimes.against.women.per.1.000.women & 0.208 & -0.045 \\
# X & [ 0.111 ] & [ 0.109 ] \\
# R2 & 0.76 & 0.88 \\
# Observations & 130 & 130 \\
# Total.crimes.against.women.per.1.000.women.1 & 0.365 & 0.229 \\
# X.1 & [ 0.19 ] & [ 0.084 ] \\
# R2.1 & 0.85 & 0.95 \\
# Observations.1 & 391 & 391 \\
# \hline \\[-1.8ex]
# \end{tabular}
# \end{table}

# %% [markdown]
# **Table 2:**
#
# I copy paste the above latex code to a latex editor and copy the picture to the github and add the link here.
#
# ![Table 2](https://github.com/mahmud-nobe/CS112-Final-Project/raw/master/table%202.PNG)

# %% [markdown]
# **Table 2.2:**
#
# Disregarding Panel A, this is the replication of the table from original paper:
#
# ![Table 2](https://github.com/mahmud-nobe/CS112-Final-Project/raw/master/table%202.2.PNG)

# %% [markdown]
# ## GenMatch

# %%
# installing library for genmatch
install.packages('Matching')
install.packages('rgenoud')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(Matching)
# Out:
# Loading required package: MASS
#
# ##
# ##  Matching (Version 4.9-6, Build Date: 2019-04-07)
# ##  See http://sekhon.berkeley.edu/matching for additional documentation.
# ##  Please cite software as:
# ##   Jasjeet S. Sekhon. 2011. ``Multivariate and Propensity Score Matching
# ##   Software with Automated Balance Optimization: The Matching package for R.''
# ##   Journal of Statistical Software, 42(7): 1-52.
# ##

# %%
attach(after.data)
X = cbind(state, pcgsdp, pfemale, plit, pwlit, prural)
X.all = cbind(state, pcgsdp, pfemale, plit, pwlit, prural, state^2, pcgsdp^2, pfemale^2, plit^2, pwlit^2, prural^2, 
          state*pcgsdp, state*pfemale, state*plit, state*pwlit, state*prural,
          pcgsdp*pfemale, pcgsdp*plit, pcgsdp*pwlit, pcgsdp*prural,
          pfemale*plit, pfemale*pwlit, pfemale*prural, plit*pwlit, plit*prural, pwlit*prural)
Tr = treat
Y = pcr_womtot
detach(after.data)
# Out:
# The following object is masked _by_ .GlobalEnv:
#
#     X

# %%
genout = GenMatch(Tr = Tr, X = X, M=1, pop.size = 250,
                  max.generations = 20, wait.generations = 25,
                  exact = c(T, F, F, F, F, F))
mout = Match(Tr = Tr, X = X, M=1, Weight.matrix = genout,
                  exact = c(T, F, F, F, F, F))
summary(mout)
mb <- MatchBalance(data$treat ~ data$state + data$pcgsdp + data$pfemale + data$plit + data$pwlit + data$prural, match.out=mout, nboots=500)
# Out:
# Loading required namespace: rgenoud
# Fri Dec 20 10:11:04 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	30
# 	(2) Uniform Mutation.................. 	31
# 	(3) Boundary Mutation................. 	31
# 	(4) Non-Uniform Mutation.............. 	31
# 	(5) Polytope Crossover................ 	31
# 	(6) Simple Crossover.................. 	32
# 	(7) Whole Non-Uniform Mutation........ 	31
# 	(8) Heuristic Crossover............... 	32
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 20
# Maximum Nonchanging Generations: 25
# Population size       : 250
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 250, #Total UniqueCount: 250
# var 1:
# best............ 1.000000e+00
# mean............ 4.708131e+02
# variance........ 7.255893e+04
# var 2:
# best............ 1.000000e+00
# mean............ 4.930084e+02
# variance........ 8.688968e+04
# var 3:
# best............ 1.000000e+00
# mean............ 4.960855e+02
# variance........ 8.347941e+04
# var 4:
# best............ 1.000000e+00
# mean............ 5.416773e+02
# variance........ 8.141594e+04
# var 5:
# best............ 1.000000e+00
# mean............ 5.021364e+02
# variance........ 9.296008e+04
# var 6:
# best............ 1.000000e+00
# mean............ 4.789683e+02
# variance........ 8.551681e+04
#
# GENERATION: 1
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 187, #Total UniqueCount: 437
# var 1:
# best............ 1.000000e+00
# mean............ 2.553253e+02
# variance........ 6.963970e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.552534e+02
# variance........ 1.250635e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.717329e+02
# variance........ 9.568098e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.581486e+02
# variance........ 7.511518e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.270219e+02
# variance........ 1.360423e+05
# var 6:
# best............ 1.000000e+00
# mean............ 3.021074e+02
# variance........ 9.286888e+04
#
# GENERATION: 2
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 172, #Total UniqueCount: 609
# var 1:
# best............ 1.000000e+00
# mean............ 2.391324e+02
# variance........ 6.794251e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.563637e+02
# variance........ 1.222948e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.703164e+02
# variance........ 9.722428e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.794879e+02
# variance........ 8.870186e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.314847e+02
# variance........ 1.358576e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.777442e+02
# variance........ 8.905805e+04
#
# GENERATION: 3
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 159, #Total UniqueCount: 768
# var 1:
# best............ 1.000000e+00
# mean............ 2.643278e+02
# variance........ 6.906107e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.793594e+02
# variance........ 1.374992e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.860770e+02
# variance........ 9.510302e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.717134e+02
# variance........ 8.321246e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.568435e+02
# variance........ 1.367772e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.869869e+02
# variance........ 9.268146e+04
#
# GENERATION: 4
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 162, #Total UniqueCount: 930
# var 1:
# best............ 1.000000e+00
# mean............ 2.553254e+02
# variance........ 6.789202e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.958248e+02
# variance........ 1.352336e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.903903e+02
# variance........ 9.882330e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.690036e+02
# variance........ 8.025957e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.605370e+02
# variance........ 1.380507e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.767157e+02
# variance........ 8.800760e+04
#
# GENERATION: 5
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 165, #Total UniqueCount: 1095
# var 1:
# best............ 1.000000e+00
# mean............ 2.624761e+02
# variance........ 7.083451e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.827696e+02
# variance........ 1.426297e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.724069e+02
# variance........ 9.938905e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.425505e+02
# variance........ 7.673816e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.323622e+02
# variance........ 1.408847e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.551739e+02
# variance........ 8.994422e+04
#
# GENERATION: 6
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 156, #Total UniqueCount: 1251
# var 1:
# best............ 1.000000e+00
# mean............ 2.302381e+02
# variance........ 6.844796e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.470569e+02
# variance........ 1.328978e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.426773e+02
# variance........ 9.881688e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.554341e+02
# variance........ 8.681630e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.007089e+02
# variance........ 1.428824e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.616886e+02
# variance........ 9.605729e+04
#
# GENERATION: 7
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 139, #Total UniqueCount: 1390
# var 1:
# best............ 1.000000e+00
# mean............ 2.083973e+02
# variance........ 6.650564e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.194211e+02
# variance........ 1.240175e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.236669e+02
# variance........ 9.565634e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.800854e+02
# variance........ 1.019298e+05
# var 5:
# best............ 1.000000e+00
# mean............ 3.957785e+02
# variance........ 1.345671e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.436272e+02
# variance........ 8.157280e+04
#
# GENERATION: 8
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 147, #Total UniqueCount: 1537
# var 1:
# best............ 1.000000e+00
# mean............ 2.273543e+02
# variance........ 6.985541e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.443003e+02
# variance........ 1.291461e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.512702e+02
# variance........ 9.829197e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.912640e+02
# variance........ 9.474422e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.343061e+02
# variance........ 1.447368e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.868186e+02
# variance........ 9.973194e+04
#
# GENERATION: 9
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 162, #Total UniqueCount: 1699
# var 1:
# best............ 1.000000e+00
# mean............ 2.244733e+02
# variance........ 7.196514e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.300873e+02
# variance........ 1.247979e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.726426e+02
# variance........ 9.803801e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.978727e+02
# variance........ 9.761818e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.680247e+02
# variance........ 1.481858e+05
# var 6:
# best............ 1.000000e+00
# mean............ 3.096952e+02
# variance........ 1.036909e+05
#
# GENERATION: 10
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 161, #Total UniqueCount: 1860
# var 1:
# best............ 1.000000e+00
# mean............ 2.190904e+02
# variance........ 6.685739e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.256732e+02
# variance........ 1.210621e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.581428e+02
# variance........ 9.671614e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.695030e+02
# variance........ 8.451794e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.464709e+02
# variance........ 1.473702e+05
# var 6:
# best............ 1.000000e+00
# mean............ 3.083555e+02
# variance........ 1.035855e+05
#
# GENERATION: 11
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 150, #Total UniqueCount: 2010
# var 1:
# best............ 1.000000e+00
# mean............ 2.280035e+02
# variance........ 6.908893e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.252770e+02
# variance........ 1.166533e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.863390e+02
# variance........ 1.005677e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.731473e+02
# variance........ 8.335928e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.468507e+02
# variance........ 1.427685e+05
# var 6:
# best............ 1.000000e+00
# mean............ 3.010154e+02
# variance........ 1.029598e+05
#
# GENERATION: 12
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 159, #Total UniqueCount: 2169
# var 1:
# best............ 1.000000e+00
# mean............ 2.217952e+02
# variance........ 7.283701e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.128793e+02
# variance........ 1.260616e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.491878e+02
# variance........ 1.071213e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.393270e+02
# variance........ 8.022142e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.072225e+02
# variance........ 1.496559e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.667739e+02
# variance........ 1.014206e+05
#
# GENERATION: 13
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 155, #Total UniqueCount: 2324
# var 1:
# best............ 1.000000e+00
# mean............ 2.360803e+02
# variance........ 6.707168e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.642279e+02
# variance........ 1.394482e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.951634e+02
# variance........ 1.043787e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.466420e+02
# variance........ 7.247417e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.685852e+02
# variance........ 1.439388e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.934906e+02
# variance........ 9.452124e+04
#
# GENERATION: 14
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 154, #Total UniqueCount: 2478
# var 1:
# best............ 1.000000e+00
# mean............ 2.253531e+02
# variance........ 6.849764e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.307508e+02
# variance........ 1.229555e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.727200e+02
# variance........ 9.832987e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.750657e+02
# variance........ 8.680723e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.567167e+02
# variance........ 1.458388e+05
# var 6:
# best............ 1.000000e+00
# mean............ 3.030712e+02
# variance........ 1.022893e+05
#
# GENERATION: 15
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 156, #Total UniqueCount: 2634
# var 1:
# best............ 1.000000e+00
# mean............ 2.344681e+02
# variance........ 6.818836e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.730194e+02
# variance........ 1.425850e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.867934e+02
# variance........ 1.069405e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.545094e+02
# variance........ 7.943788e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.331530e+02
# variance........ 1.469197e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.698035e+02
# variance........ 9.028085e+04
#
# GENERATION: 16
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 151, #Total UniqueCount: 2785
# var 1:
# best............ 1.000000e+00
# mean............ 2.256286e+02
# variance........ 6.955781e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.421300e+02
# variance........ 1.244237e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.785862e+02
# variance........ 9.785863e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.765714e+02
# variance........ 8.887564e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.496619e+02
# variance........ 1.443052e+05
# var 6:
# best............ 1.000000e+00
# mean............ 3.006996e+02
# variance........ 1.029089e+05
#
# GENERATION: 17
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 150, #Total UniqueCount: 2935
# var 1:
# best............ 1.000000e+00
# mean............ 2.246796e+02
# variance........ 6.642472e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.588047e+02
# variance........ 1.368899e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.687439e+02
# variance........ 9.988911e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.576551e+02
# variance........ 8.463616e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.344488e+02
# variance........ 1.457013e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.713248e+02
# variance........ 9.383555e+04
#
# GENERATION: 18
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 152, #Total UniqueCount: 3087
# var 1:
# best............ 1.000000e+00
# mean............ 2.258176e+02
# variance........ 6.593658e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.388028e+02
# variance........ 1.389441e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.437845e+02
# variance........ 1.008027e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.341194e+02
# variance........ 7.547261e+04
# var 5:
# best............ 1.000000e+00
# mean............ 3.974399e+02
# variance........ 1.425054e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.467816e+02
# variance........ 9.372163e+04
#
# GENERATION: 19
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 157, #Total UniqueCount: 3244
# var 1:
# best............ 1.000000e+00
# mean............ 2.460361e+02
# variance........ 6.797478e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.912080e+02
# variance........ 1.402551e+05
# var 3:
# best............ 1.000000e+00
# mean............ 4.006659e+02
# variance........ 1.029178e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.813863e+02
# variance........ 8.482619e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.768309e+02
# variance........ 1.410325e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.815763e+02
# variance........ 9.247474e+04
#
# GENERATION: 20
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 164, #Total UniqueCount: 3408
# var 1:
# best............ 1.000000e+00
# mean............ 2.212430e+02
# variance........ 6.983746e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.242491e+02
# variance........ 1.272598e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.470908e+02
# variance........ 1.063456e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.623000e+02
# variance........ 9.575322e+04
# var 5:
# best............ 1.000000e+00
# mean............ 3.879110e+02
# variance........ 1.405714e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.520168e+02
# variance........ 8.867226e+04
#
# Increasing 'max.generations' limit by 25 generations to 45 because the fitness is still impoving.
#
#
# GENERATION: 21
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 151, #Total UniqueCount: 3559
# var 1:
# best............ 1.000000e+00
# mean............ 2.370619e+02
# variance........ 6.723963e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.486451e+02
# variance........ 1.250160e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.681554e+02
# variance........ 9.714210e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.717706e+02
# variance........ 9.016892e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.354080e+02
# variance........ 1.401456e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.837033e+02
# variance........ 9.209908e+04
#
# GENERATION: 22
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 153, #Total UniqueCount: 3712
# var 1:
# best............ 1.000000e+00
# mean............ 2.288880e+02
# variance........ 6.638350e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.528574e+02
# variance........ 1.416504e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.476775e+02
# variance........ 1.036707e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.178147e+02
# variance........ 6.939179e+04
# var 5:
# best............ 1.000000e+00
# mean............ 3.903433e+02
# variance........ 1.399712e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.467418e+02
# variance........ 9.022518e+04
#
# GENERATION: 23
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 145, #Total UniqueCount: 3857
# var 1:
# best............ 1.000000e+00
# mean............ 2.123907e+02
# variance........ 6.970583e+04
# var 2:
# best............ 1.000000e+00
# mean............ 2.965962e+02
# variance........ 1.148660e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.231310e+02
# variance........ 9.482211e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.372815e+02
# variance........ 8.540555e+04
# var 5:
# best............ 1.000000e+00
# mean............ 3.902168e+02
# variance........ 1.387478e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.487247e+02
# variance........ 8.763898e+04
#
# GENERATION: 24
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 158, #Total UniqueCount: 4015
# var 1:
# best............ 1.000000e+00
# mean............ 2.486964e+02
# variance........ 6.787898e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.973257e+02
# variance........ 1.443359e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.886558e+02
# variance........ 1.005586e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.475653e+02
# variance........ 7.583235e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.590087e+02
# variance........ 1.476369e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.747292e+02
# variance........ 9.416229e+04
#
# GENERATION: 25
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 156, #Total UniqueCount: 4171
# var 1:
# best............ 1.000000e+00
# mean............ 2.367690e+02
# variance........ 7.237729e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.425645e+02
# variance........ 1.294881e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.591551e+02
# variance........ 1.002604e+05
# var 4:
# best............ 1.000000e+00
# mean............ 2.288307e+02
# variance........ 7.246031e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.115344e+02
# variance........ 1.462598e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.673842e+02
# variance........ 9.847765e+04
#
# GENERATION: 26
# Lexical Fit..... 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
# #unique......... 150, #Total UniqueCount: 4321
# var 1:
# best............ 1.000000e+00
# mean............ 2.276181e+02
# variance........ 6.405321e+04
# var 2:
# best............ 1.000000e+00
# mean............ 3.501333e+02
# variance........ 1.236701e+05
# var 3:
# best............ 1.000000e+00
# mean............ 3.540272e+02
# variance........ 9.392969e+04
# var 4:
# best............ 1.000000e+00
# mean............ 2.679330e+02
# variance........ 8.492986e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.246807e+02
# variance........ 1.409863e+05
# var 6:
# best............ 1.000000e+00
# mean............ 2.905407e+02
# variance........ 1.073386e+05
#
# 'wait.generations' limit reached.
# No significant improvement in 25 generations.
#
# Solution Lexical Fitness Value:
# 7.091676e-09  2.152124e-08  1.978875e-07  3.632187e-07  2.408537e-04  1.074108e-03  1.387813e-02  2.895102e-02  2.895102e-02  2.895102e-02  1.000000e+00  1.000000e+00
#
# Parameters at the Solution:
#
#  X[ 1] :	1.000000e+00
#  X[ 2] :	1.000000e+00
#  X[ 3] :	1.000000e+00
#  X[ 4] :	1.000000e+00
#  X[ 5] :	1.000000e+00
#  X[ 6] :	1.000000e+00
#
# Solution Found Generation 1
# Number of Generations Run 26
#
# Fri Dec 20 10:11:28 2019
# Total run time : 0 hours 0 minutes and 24 seconds
#
# Estimate...  0
# SE.........  0
# T-stat.....  NaN
# p.val......  NA
#
# Original number of observations..............  130
# Original number of treated obs...............  99
# Matched number of observations...............  34
# Matched number of observations  (unweighted).  34
#
# Number of obs dropped by 'exact' or 'caliper'  65
#
#
# ***** (V1) data$state *****
#                        Before Matching 	 	 After Matching
# mean treatment........     9.1981 	 	     3.6765
# mean control..........     8.7654 	 	     3.5294
# std mean diff.........     9.5532 	 	     8.9326
#
# mean raw eQQ diff.....     1.1285 	 	    0.14706
# med  raw eQQ diff.....          1 	 	          0
# max  raw eQQ diff.....          3 	 	          1
#
# mean eCDF diff........   0.066599 	 	   0.029412
# med  eCDF diff........   0.069701 	 	          0
# max  eCDF diff........    0.15758 	 	   0.088235
#
# var ratio (Tr/Co).....    0.72526 	 	    0.94676
# T-test p-value........    0.39191 	 	   0.021132
# KS Bootstrap p-value..      0.008 	 	      0.858
# KS Naive p-value......    0.01613 	 	    0.99938
# KS Statistic..........    0.15758 	 	   0.088235
#
#
# ***** (V2) data$pcgsdp *****
#                        Before Matching 	 	 After Matching
# mean treatment........     2.0496 	 	     2.3041
# mean control..........      1.229 	 	     2.0806
# std mean diff.........     108.53 	 	     25.512
#
# mean raw eQQ diff.....    0.81738 	 	    0.50374
# med  raw eQQ diff.....    0.71817 	 	    0.37882
# max  raw eQQ diff.....     1.8309 	 	     1.8971
#
# mean eCDF diff........    0.31994 	 	    0.18778
# med  eCDF diff........    0.35116 	 	    0.11765
# max  eCDF diff........    0.52008 	 	    0.55882
#
# var ratio (Tr/Co).....     2.5294 	 	     4.8781
# T-test p-value........ < 2.22e-16 	 	   0.071908
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	  4.896e-05
# KS Statistic..........    0.52008 	 	    0.55882
#
#
# ***** (V3) data$pfemale *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.94481 	 	    0.91546
# mean control..........    0.92679 	 	    0.91478
# std mean diff.........     37.914 	 	     1.6362
#
# mean raw eQQ diff.....   0.018939 	 	  0.0073151
# med  raw eQQ diff.....   0.015363 	 	  0.0033797
# max  raw eQQ diff.....   0.074693 	 	   0.054033
#
# mean eCDF diff........    0.12531 	 	    0.10106
# med  eCDF diff........    0.12454 	 	   0.088235
# max  eCDF diff........     0.2544 	 	    0.29412
#
# var ratio (Tr/Co).....     1.4871 	 	    0.87503
# T-test p-value........ 4.6574e-05 	 	     0.9044
# KS Bootstrap p-value.. < 2.22e-16 	 	      0.068
# KS Naive p-value...... 7.0012e-06 	 	    0.10559
# KS Statistic..........     0.2544 	 	    0.29412
#
#
# ***** (V4) data$plit *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.57891 	 	    0.54866
# mean control..........    0.43549 	 	     0.5339
# std mean diff.........     147.07 	 	     20.977
#
# mean raw eQQ diff.....    0.14248 	 	   0.032609
# med  raw eQQ diff.....    0.14219 	 	   0.031661
# max  raw eQQ diff.....    0.23656 	 	   0.054466
#
# mean eCDF diff........    0.36798 	 	    0.16139
# med  eCDF diff........    0.42036 	 	    0.11765
# max  eCDF diff........    0.59408 	 	    0.47059
#
# var ratio (Tr/Co).....    0.99148 	 	     1.9582
# T-test p-value........ < 2.22e-16 	 	    0.18245
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	  0.0010741
# KS Statistic..........    0.59408 	 	    0.47059
#
#
# ***** (V5) data$pwlit *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.49211 	 	    0.45953
# mean control..........    0.33003 	 	    0.43939
# std mean diff.........     134.38 	 	     29.478
#
# mean raw eQQ diff.....    0.16095 	 	   0.031169
# med  raw eQQ diff.....    0.15834 	 	    0.02714
# max  raw eQQ diff.....    0.30009 	 	   0.069738
#
# mean eCDF diff........    0.35596 	 	    0.16516
# med  eCDF diff........    0.39765 	 	    0.11765
# max  eCDF diff........    0.57099 	 	    0.47059
#
# var ratio (Tr/Co).....     1.0825 	 	     1.9892
# T-test p-value........ < 2.22e-16 	 	   0.084662
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	  0.0010741
# KS Statistic..........    0.57099 	 	    0.47059
#
#
# ***** (V6) data$prural *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.72439 	 	    0.76657
# mean control..........    0.77668 	 	    0.74959
# std mean diff.........    -54.919 	 	     15.289
#
# mean raw eQQ diff.....   0.053234 	 	   0.032333
# med  raw eQQ diff.....   0.051458 	 	   0.012495
# max  raw eQQ diff.....    0.10708 	 	    0.15329
#
# mean eCDF diff........    0.18615 	 	    0.10784
# med  eCDF diff........    0.17619 	 	   0.088235
# max  eCDF diff........    0.35174 	 	    0.35294
#
# var ratio (Tr/Co).....     1.3696 	 	     1.4259
# T-test p-value........ 1.0113e-08 	 	    0.15105
# KS Bootstrap p-value.. < 2.22e-16 	 	       0.02
# KS Naive p-value......  7.432e-11 	 	   0.028951
# KS Statistic..........    0.35174 	 	    0.35294
#
#
# Before Matching Minimum p.value: < 2.22e-16
# Variable Name(s): data$pcgsdp data$pfemale data$plit data$pwlit data$prural  Number(s): 2 3 4 5 6
#
# After Matching Minimum p.value: < 2.22e-16
# Variable Name(s): data$pcgsdp data$plit data$pwlit  Number(s): 2 4 5

# %%
genout = GenMatch(Tr = Tr, X = X.all, M=1, pop.size = 250,
                  max.generations = 20, wait.generations = 25)
# Out:
# Loading required namespace: rgenoud
# Fri Dec 20 02:07:52 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#  0.000000e+00   <=  X7   <=    1.000000e+03
#  0.000000e+00   <=  X8   <=    1.000000e+03
#  0.000000e+00   <=  X9   <=    1.000000e+03
#  0.000000e+00   <=  X10  <=    1.000000e+03
#  0.000000e+00   <=  X11  <=    1.000000e+03
#  0.000000e+00   <=  X12  <=    1.000000e+03
#  0.000000e+00   <=  X13  <=    1.000000e+03
#  0.000000e+00   <=  X14  <=    1.000000e+03
#  0.000000e+00   <=  X15  <=    1.000000e+03
#  0.000000e+00   <=  X16  <=    1.000000e+03
#  0.000000e+00   <=  X17  <=    1.000000e+03
#  0.000000e+00   <=  X18  <=    1.000000e+03
#  0.000000e+00   <=  X19  <=    1.000000e+03
#  0.000000e+00   <=  X20  <=    1.000000e+03
#  0.000000e+00   <=  X21  <=    1.000000e+03
#  0.000000e+00   <=  X22  <=    1.000000e+03
#  0.000000e+00   <=  X23  <=    1.000000e+03
#  0.000000e+00   <=  X24  <=    1.000000e+03
#  0.000000e+00   <=  X25  <=    1.000000e+03
#  0.000000e+00   <=  X26  <=    1.000000e+03
#  0.000000e+00   <=  X27  <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	30
# 	(2) Uniform Mutation.................. 	31
# 	(3) Boundary Mutation................. 	31
# 	(4) Non-Uniform Mutation.............. 	31
# 	(5) Polytope Crossover................ 	31
# 	(6) Simple Crossover.................. 	32
# 	(7) Whole Non-Uniform Mutation........ 	31
# 	(8) Heuristic Crossover............... 	32
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 20
# Maximum Nonchanging Generations: 25
# Population size       : 250
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  2.220446e-16  3.330669e-16  4.440892e-16  6.661338e-16  1.776357e-15  3.552714e-15  1.121325e-14  2.997602e-14  4.840572e-14  1.136868e-13  5.802026e-13  1.477485e-12  1.548149e-08  1.548149e-08  1.914826e-07  5.135620e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.879768e-06  4.127817e-06  4.127817e-06  7.385107e-06  1.355898e-05  2.891244e-05  3.340340e-05  5.640752e-05  6.440707e-05  7.871694e-05  1.217034e-04  1.596545e-04  4.089972e-04  4.089972e-04  4.089972e-04  4.089972e-04  4.604157e-04  5.946011e-03  9.558856e-03  1.505956e-02  1.505956e-02  5.216543e-02  5.349059e-02  7.081110e-02  1.021983e-01  1.079376e-01  1.212999e-01  1.215267e-01
# #unique......... 250, #Total UniqueCount: 250
# var 1:
# best............ 1.294637e+02
# mean............ 4.929006e+02
# variance........ 8.486082e+04
# var 2:
# best............ 6.803889e+02
# mean............ 4.723280e+02
# variance........ 8.481713e+04
# var 3:
# best............ 6.892171e+02
# mean............ 5.229749e+02
# variance........ 7.708197e+04
# var 4:
# best............ 6.261752e+02
# mean............ 4.948036e+02
# variance........ 8.363950e+04
# var 5:
# best............ 7.258305e+02
# mean............ 4.847395e+02
# variance........ 8.638477e+04
# var 6:
# best............ 3.974271e+02
# mean............ 4.840843e+02
# variance........ 8.489745e+04
# var 7:
# best............ 5.540306e+01
# mean............ 5.047388e+02
# variance........ 9.131195e+04
# var 8:
# best............ 3.746121e+02
# mean............ 5.049880e+02
# variance........ 9.298605e+04
# var 9:
# best............ 5.267974e+01
# mean............ 4.431740e+02
# variance........ 8.159938e+04
# var 10:
# best............ 6.121831e+01
# mean............ 4.827080e+02
# variance........ 8.900775e+04
# var 11:
# best............ 2.802264e+01
# mean............ 4.751369e+02
# variance........ 7.518632e+04
# var 12:
# best............ 9.141276e+02
# mean............ 4.923940e+02
# variance........ 9.121997e+04
# var 13:
# best............ 7.200177e+02
# mean............ 4.967329e+02
# variance........ 8.588041e+04
# var 14:
# best............ 1.233953e+02
# mean............ 5.080666e+02
# variance........ 9.237514e+04
# var 15:
# best............ 2.437495e+02
# mean............ 4.748908e+02
# variance........ 8.626079e+04
# var 16:
# best............ 4.980239e+01
# mean............ 5.224776e+02
# variance........ 8.268876e+04
# var 17:
# best............ 4.614227e+02
# mean............ 5.053564e+02
# variance........ 7.918751e+04
# var 18:
# best............ 3.915479e+02
# mean............ 4.698898e+02
# variance........ 7.992868e+04
# var 19:
# best............ 9.434716e+02
# mean............ 5.445842e+02
# variance........ 8.322068e+04
# var 20:
# best............ 3.310675e+02
# mean............ 5.047648e+02
# variance........ 8.794486e+04
# var 21:
# best............ 4.134894e+02
# mean............ 5.155561e+02
# variance........ 9.543404e+04
# var 22:
# best............ 5.638618e+02
# mean............ 4.907408e+02
# variance........ 8.704777e+04
# var 23:
# best............ 3.866842e+02
# mean............ 4.995166e+02
# variance........ 7.816412e+04
# var 24:
# best............ 8.115031e+02
# mean............ 5.073902e+02
# variance........ 8.237377e+04
# var 25:
# best............ 4.176153e+02
# mean............ 5.272967e+02
# variance........ 7.731253e+04
# var 26:
# best............ 4.275438e+02
# mean............ 5.382438e+02
# variance........ 8.194648e+04
# var 27:
# best............ 2.323138e+02
# mean............ 4.718536e+02
# variance........ 7.967212e+04
#
# GENERATION: 1
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  1.776357e-15  3.552714e-15  1.121325e-14  1.598721e-14  3.497203e-14  1.705303e-13  2.875478e-12  3.363532e-12  2.612088e-11  2.947660e-10  2.551075e-09  2.263955e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.974618e-06  1.974618e-06  3.216306e-06  4.083533e-06  5.366252e-06  6.422717e-06  1.538300e-05  1.697752e-05  1.697752e-05  6.440707e-05  6.440707e-05  6.440707e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  8.564876e-04  1.267778e-03  1.452327e-03  2.186863e-03  2.772238e-03  5.912819e-03  5.946011e-03  9.558856e-03  7.580170e-02  7.580170e-02  7.580170e-02  6.341382e-01  6.782257e-01  8.878005e-01
# #unique......... 193, #Total UniqueCount: 443
# var 1:
# best............ 7.735725e+02
# mean............ 3.416736e+02
# variance........ 7.508891e+04
# var 2:
# best............ 6.139971e+02
# mean............ 5.938244e+02
# variance........ 2.801003e+04
# var 3:
# best............ 9.024761e+01
# mean............ 4.579677e+02
# variance........ 7.962862e+04
# var 4:
# best............ 8.324403e+02
# mean............ 6.405298e+02
# variance........ 4.286746e+04
# var 5:
# best............ 2.462778e+02
# mean............ 5.220816e+02
# variance........ 4.821445e+04
# var 6:
# best............ 9.198856e+02
# mean............ 5.746413e+02
# variance........ 5.489026e+04
# var 7:
# best............ 1.615549e+01
# mean............ 1.449395e+02
# variance........ 3.453050e+04
# var 8:
# best............ 4.348586e+02
# mean............ 4.544742e+02
# variance........ 3.637203e+04
# var 9:
# best............ 6.899451e+01
# mean............ 1.816274e+02
# variance........ 5.006057e+04
# var 10:
# best............ 3.532879e+02
# mean............ 3.454478e+02
# variance........ 8.221501e+04
# var 11:
# best............ 6.251794e+02
# mean............ 3.470249e+02
# variance........ 8.497278e+04
# var 12:
# best............ 3.574029e+02
# mean............ 6.515926e+02
# variance........ 7.120970e+04
# var 13:
# best............ 1.878068e+02
# mean............ 4.759064e+02
# variance........ 6.064489e+04
# var 14:
# best............ 1.461840e+02
# mean............ 2.673933e+02
# variance........ 2.658883e+04
# var 15:
# best............ 2.668341e+02
# mean............ 3.581466e+02
# variance........ 2.245040e+04
# var 16:
# best............ 5.840387e+01
# mean............ 2.045885e+02
# variance........ 5.458145e+04
# var 17:
# best............ 4.284243e+02
# mean............ 3.859133e+02
# variance........ 3.524636e+04
# var 18:
# best............ 4.138746e+02
# mean............ 4.579336e+02
# variance........ 3.289111e+04
# var 19:
# best............ 8.814732e+02
# mean............ 6.870553e+02
# variance........ 7.131683e+04
# var 20:
# best............ 3.401644e+02
# mean............ 4.598851e+02
# variance........ 4.326228e+04
# var 21:
# best............ 3.894041e+02
# mean............ 4.123094e+02
# variance........ 5.616959e+04
# var 22:
# best............ 5.159237e+02
# mean............ 4.639525e+02
# variance........ 7.314068e+04
# var 23:
# best............ 4.074398e+02
# mean............ 5.228230e+02
# variance........ 3.527938e+04
# var 24:
# best............ 8.233779e+02
# mean............ 7.538163e+02
# variance........ 4.064303e+04
# var 25:
# best............ 4.395922e+02
# mean............ 5.306201e+02
# variance........ 3.574245e+04
# var 26:
# best............ 4.391939e+02
# mean............ 5.068932e+02
# variance........ 3.598503e+04
# var 27:
# best............ 2.294114e+02
# mean............ 3.022076e+02
# variance........ 2.818030e+04
#
# GENERATION: 2
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  1.776357e-15  3.552714e-15  1.121325e-14  1.598721e-14  3.497203e-14  1.705303e-13  2.875478e-12  3.363532e-12  2.612088e-11  2.947660e-10  2.551075e-09  2.263955e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.974618e-06  1.974618e-06  3.216306e-06  4.083533e-06  5.366252e-06  6.422717e-06  1.538300e-05  1.697752e-05  1.697752e-05  6.440707e-05  6.440707e-05  6.440707e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  8.564876e-04  1.267778e-03  1.452327e-03  2.186863e-03  2.772238e-03  5.912819e-03  5.946011e-03  9.558856e-03  7.580170e-02  7.580170e-02  7.580170e-02  6.341382e-01  6.782257e-01  8.878005e-01
# #unique......... 194, #Total UniqueCount: 637
# var 1:
# best............ 7.735725e+02
# mean............ 4.033366e+02
# variance........ 9.225535e+04
# var 2:
# best............ 6.139971e+02
# mean............ 6.304614e+02
# variance........ 7.518379e+03
# var 3:
# best............ 9.024761e+01
# mean............ 3.642502e+02
# variance........ 6.109868e+04
# var 4:
# best............ 8.324403e+02
# mean............ 7.149682e+02
# variance........ 1.736280e+04
# var 5:
# best............ 2.462778e+02
# mean............ 4.782482e+02
# variance........ 4.949715e+04
# var 6:
# best............ 9.198856e+02
# mean............ 6.579676e+02
# variance........ 5.750748e+04
# var 7:
# best............ 1.615549e+01
# mean............ 6.935300e+01
# variance........ 1.379305e+04
# var 8:
# best............ 4.348586e+02
# mean............ 4.090475e+02
# variance........ 7.578224e+03
# var 9:
# best............ 6.899451e+01
# mean............ 1.039408e+02
# variance........ 1.761966e+04
# var 10:
# best............ 3.532879e+02
# mean............ 2.374847e+02
# variance........ 2.941024e+04
# var 11:
# best............ 6.251794e+02
# mean............ 3.367792e+02
# variance........ 7.590792e+04
# var 12:
# best............ 3.574029e+02
# mean............ 6.125049e+02
# variance........ 6.862936e+04
# var 13:
# best............ 1.878068e+02
# mean............ 3.873932e+02
# variance........ 6.505298e+04
# var 14:
# best............ 1.461840e+02
# mean............ 1.785852e+02
# variance........ 1.117668e+04
# var 15:
# best............ 2.668341e+02
# mean............ 2.930197e+02
# variance........ 6.915710e+03
# var 16:
# best............ 5.840387e+01
# mean............ 8.538734e+01
# variance........ 7.026052e+03
# var 17:
# best............ 4.284243e+02
# mean............ 4.169758e+02
# variance........ 1.270097e+04
# var 18:
# best............ 4.138746e+02
# mean............ 4.124714e+02
# variance........ 9.465033e+03
# var 19:
# best............ 8.814732e+02
# mean............ 8.349944e+02
# variance........ 2.990244e+04
# var 20:
# best............ 3.401644e+02
# mean............ 3.738357e+02
# variance........ 1.430238e+04
# var 21:
# best............ 3.894041e+02
# mean............ 3.885117e+02
# variance........ 1.234314e+04
# var 22:
# best............ 5.159237e+02
# mean............ 5.087658e+02
# variance........ 2.164819e+04
# var 23:
# best............ 4.074398e+02
# mean............ 4.397688e+02
# variance........ 1.298216e+04
# var 24:
# best............ 8.233779e+02
# mean............ 8.129563e+02
# variance........ 5.844541e+03
# var 25:
# best............ 4.395922e+02
# mean............ 4.563038e+02
# variance........ 9.914057e+03
# var 26:
# best............ 4.391939e+02
# mean............ 4.501715e+02
# variance........ 7.948312e+03
# var 27:
# best............ 2.294114e+02
# mean............ 2.431863e+02
# variance........ 4.595238e+03
#
# GENERATION: 3
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.220446e-15  3.552714e-15  7.105427e-15  1.121325e-14  3.497203e-14  8.837375e-14  1.235456e-12  1.338041e-12  1.148970e-11  1.816594e-10  1.330771e-09  1.690336e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.019898e-06  1.889774e-06  1.974618e-06  2.184540e-06  3.613471e-06  8.456373e-06  1.083367e-05  1.697752e-05  3.340340e-05  3.340340e-05  3.340340e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.297362e-03  1.732317e-03  2.222404e-03  4.923113e-03  5.946011e-03  6.326192e-03  9.558856e-03  5.216543e-02  5.216543e-02  7.580170e-02  5.755367e-01  6.161244e-01  9.631067e-01
# #unique......... 199, #Total UniqueCount: 836
# var 1:
# best............ 8.097665e+02
# mean............ 7.515276e+02
# variance........ 1.479611e+04
# var 2:
# best............ 6.102663e+02
# mean............ 6.092289e+02
# variance........ 3.330481e+03
# var 3:
# best............ 6.953311e+01
# mean............ 1.156707e+02
# variance........ 1.169448e+04
# var 4:
# best............ 8.440309e+02
# mean............ 8.107790e+02
# variance........ 9.589516e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.584051e+02
# variance........ 8.377278e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.047570e+02
# variance........ 9.841828e+03
# var 7:
# best............ 1.395008e+01
# mean............ 2.360874e+01
# variance........ 1.399128e+03
# var 8:
# best............ 4.382440e+02
# mean............ 4.358503e+02
# variance........ 1.505103e+03
# var 9:
# best............ 6.991127e+01
# mean............ 8.300901e+01
# variance........ 2.695078e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.624217e+02
# variance........ 4.651685e+03
# var 11:
# best............ 6.587350e+02
# mean............ 6.216048e+02
# variance........ 7.047552e+03
# var 12:
# best............ 5.339148e+02
# mean............ 3.671704e+02
# variance........ 8.919182e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.885080e+02
# variance........ 5.239516e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.626107e+02
# variance........ 5.241952e+03
# var 15:
# best............ 2.681313e+02
# mean............ 2.754059e+02
# variance........ 3.648512e+03
# var 16:
# best............ 5.888720e+01
# mean............ 8.069897e+01
# variance........ 1.051223e+04
# var 17:
# best............ 4.265700e+02
# mean............ 4.306014e+02
# variance........ 3.997725e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.192982e+02
# variance........ 2.914696e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.595601e+02
# variance........ 6.973808e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.509482e+02
# variance........ 3.786823e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.937286e+02
# variance........ 3.226577e+03
# var 22:
# best............ 5.132299e+02
# mean............ 5.135699e+02
# variance........ 2.573644e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.094760e+02
# variance........ 4.546720e+03
# var 24:
# best............ 8.240451e+02
# mean............ 8.162176e+02
# variance........ 2.574749e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.425091e+02
# variance........ 1.583072e+03
# var 26:
# best............ 4.398485e+02
# mean............ 4.455966e+02
# variance........ 2.055092e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.389834e+02
# variance........ 3.173589e+03
#
# GENERATION: 4
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.220446e-15  3.552714e-15  7.105427e-15  1.121325e-14  3.497203e-14  8.837375e-14  1.235456e-12  1.338041e-12  1.148970e-11  1.816594e-10  1.330771e-09  1.690336e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.019898e-06  1.889774e-06  1.974618e-06  2.184540e-06  3.613471e-06  8.456373e-06  1.083367e-05  1.697752e-05  3.340340e-05  3.340340e-05  3.340340e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.297362e-03  1.732317e-03  2.222404e-03  4.923113e-03  5.946011e-03  6.326192e-03  9.558856e-03  5.216543e-02  5.216543e-02  7.580170e-02  5.755367e-01  6.161244e-01  9.631067e-01
# #unique......... 186, #Total UniqueCount: 1022
# var 1:
# best............ 8.097665e+02
# mean............ 7.846864e+02
# variance........ 2.882316e+03
# var 2:
# best............ 6.102663e+02
# mean............ 6.098998e+02
# variance........ 6.769071e+02
# var 3:
# best............ 6.953311e+01
# mean............ 9.577673e+01
# variance........ 5.181326e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.150094e+02
# variance........ 7.028690e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.384523e+02
# variance........ 2.254055e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.220958e+02
# variance........ 3.549179e+03
# var 7:
# best............ 1.395008e+01
# mean............ 2.591363e+01
# variance........ 2.702078e+03
# var 8:
# best............ 4.382440e+02
# mean............ 4.380199e+02
# variance........ 1.701424e+03
# var 9:
# best............ 6.991127e+01
# mean............ 7.989546e+01
# variance........ 2.561477e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.704388e+02
# variance........ 3.099773e+03
# var 11:
# best............ 6.587350e+02
# mean............ 6.384964e+02
# variance........ 2.921206e+03
# var 12:
# best............ 5.339148e+02
# mean............ 5.624410e+02
# variance........ 4.401057e+04
# var 13:
# best............ 1.579006e+02
# mean............ 1.819483e+02
# variance........ 4.069842e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.541359e+02
# variance........ 2.141045e+03
# var 15:
# best............ 2.681313e+02
# mean............ 2.702565e+02
# variance........ 1.544250e+03
# var 16:
# best............ 5.888720e+01
# mean............ 7.104891e+01
# variance........ 3.325364e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.286539e+02
# variance........ 1.589491e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.132345e+02
# variance........ 1.761104e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.474215e+02
# variance........ 9.651918e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.680116e+02
# variance........ 9.406775e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.948180e+02
# variance........ 2.502624e+03
# var 22:
# best............ 5.132299e+02
# mean............ 5.078919e+02
# variance........ 4.336360e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.146873e+02
# variance........ 4.284297e+03
# var 24:
# best............ 8.240451e+02
# mean............ 8.133529e+02
# variance........ 2.940996e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.459188e+02
# variance........ 1.721868e+03
# var 26:
# best............ 4.398485e+02
# mean............ 4.436945e+02
# variance........ 2.642245e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.455191e+02
# variance........ 4.498882e+03
#
# GENERATION: 5
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.220446e-15  3.552714e-15  7.105427e-15  1.121325e-14  3.497203e-14  8.837375e-14  1.235456e-12  1.338041e-12  1.148970e-11  1.816594e-10  1.330771e-09  1.690336e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.019898e-06  1.889774e-06  1.974618e-06  2.184540e-06  3.613471e-06  8.456373e-06  1.083367e-05  1.697752e-05  3.340340e-05  3.340340e-05  3.340340e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.297362e-03  1.732317e-03  2.222404e-03  4.923113e-03  5.946011e-03  6.326192e-03  9.558856e-03  5.216543e-02  5.216543e-02  7.580170e-02  5.755367e-01  6.161244e-01  9.631067e-01
# #unique......... 191, #Total UniqueCount: 1213
# var 1:
# best............ 8.097665e+02
# mean............ 7.862419e+02
# variance........ 3.048679e+03
# var 2:
# best............ 6.102663e+02
# mean............ 6.108736e+02
# variance........ 1.287689e+03
# var 3:
# best............ 6.953311e+01
# mean............ 8.567596e+01
# variance........ 3.985543e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.310091e+02
# variance........ 4.439806e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.263571e+02
# variance........ 1.486582e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.298317e+02
# variance........ 3.569010e+03
# var 7:
# best............ 1.395008e+01
# mean............ 3.335959e+01
# variance........ 8.527618e+03
# var 8:
# best............ 4.382440e+02
# mean............ 4.383030e+02
# variance........ 2.843193e+02
# var 9:
# best............ 6.991127e+01
# mean............ 8.205465e+01
# variance........ 6.638020e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.703750e+02
# variance........ 3.152622e+03
# var 11:
# best............ 6.587350e+02
# mean............ 6.412638e+02
# variance........ 2.835605e+03
# var 12:
# best............ 5.339148e+02
# mean............ 5.819072e+02
# variance........ 9.735340e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.763393e+02
# variance........ 5.463563e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.671164e+02
# variance........ 8.549321e+03
# var 15:
# best............ 2.681313e+02
# mean............ 2.719635e+02
# variance........ 4.297213e+03
# var 16:
# best............ 5.888720e+01
# mean............ 7.329006e+01
# variance........ 4.620567e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.253115e+02
# variance........ 2.207287e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.073130e+02
# variance........ 2.176365e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.489886e+02
# variance........ 7.299597e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.523300e+02
# variance........ 4.683813e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.941995e+02
# variance........ 3.234637e+03
# var 22:
# best............ 5.132299e+02
# mean............ 5.105257e+02
# variance........ 2.146490e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.128276e+02
# variance........ 1.865853e+03
# var 24:
# best............ 8.240451e+02
# mean............ 8.170829e+02
# variance........ 3.109912e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.369616e+02
# variance........ 2.505890e+03
# var 26:
# best............ 4.398485e+02
# mean............ 4.394880e+02
# variance........ 2.384665e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.410505e+02
# variance........ 3.668127e+03
#
# GENERATION: 6
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.220446e-15  3.552714e-15  7.105427e-15  1.121325e-14  3.497203e-14  8.837375e-14  1.235456e-12  1.338041e-12  1.148970e-11  1.816594e-10  1.330771e-09  1.690336e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.019898e-06  1.889774e-06  1.974618e-06  2.184540e-06  3.613471e-06  8.456373e-06  1.083367e-05  1.697752e-05  3.340340e-05  3.340340e-05  3.340340e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.297362e-03  1.732317e-03  2.222404e-03  4.923113e-03  5.946011e-03  6.326192e-03  9.558856e-03  5.216543e-02  5.216543e-02  7.580170e-02  5.755367e-01  6.161244e-01  9.631067e-01
# #unique......... 191, #Total UniqueCount: 1404
# var 1:
# best............ 8.097665e+02
# mean............ 7.877091e+02
# variance........ 4.080832e+03
# var 2:
# best............ 6.102663e+02
# mean............ 6.112708e+02
# variance........ 2.415185e+03
# var 3:
# best............ 6.953311e+01
# mean............ 8.285142e+01
# variance........ 4.067600e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.346672e+02
# variance........ 3.155524e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.288465e+02
# variance........ 2.009551e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.359569e+02
# variance........ 2.973382e+03
# var 7:
# best............ 1.395008e+01
# mean............ 2.466204e+01
# variance........ 3.362358e+03
# var 8:
# best............ 4.382440e+02
# mean............ 4.353043e+02
# variance........ 1.761755e+03
# var 9:
# best............ 6.991127e+01
# mean............ 7.978528e+01
# variance........ 3.710090e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.678804e+02
# variance........ 7.875234e+02
# var 11:
# best............ 6.587350e+02
# mean............ 6.366976e+02
# variance........ 4.376532e+03
# var 12:
# best............ 5.339148e+02
# mean............ 5.504517e+02
# variance........ 3.939191e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.650290e+02
# variance........ 7.940031e+02
# var 14:
# best............ 1.474645e+02
# mean............ 1.597611e+02
# variance........ 4.579227e+03
# var 15:
# best............ 2.681313e+02
# mean............ 2.765028e+02
# variance........ 5.906882e+03
# var 16:
# best............ 5.888720e+01
# mean............ 6.952671e+01
# variance........ 2.647073e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.243563e+02
# variance........ 1.864737e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.135947e+02
# variance........ 1.728355e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.510181e+02
# variance........ 7.554976e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.461821e+02
# variance........ 1.213378e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.939788e+02
# variance........ 1.550032e+03
# var 22:
# best............ 5.132299e+02
# mean............ 5.138473e+02
# variance........ 2.524994e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.169553e+02
# variance........ 2.506713e+03
# var 24:
# best............ 8.240451e+02
# mean............ 8.136182e+02
# variance........ 4.102691e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.326487e+02
# variance........ 3.356898e+03
# var 26:
# best............ 4.398485e+02
# mean............ 4.408788e+02
# variance........ 1.935271e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.331458e+02
# variance........ 1.308003e+03
#
# GENERATION: 7
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.220446e-15  3.552714e-15  7.105427e-15  1.121325e-14  3.497203e-14  8.837375e-14  1.235456e-12  1.338041e-12  1.148970e-11  1.816594e-10  1.330771e-09  1.690336e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.019898e-06  1.889774e-06  1.974618e-06  2.184540e-06  3.613471e-06  8.456373e-06  1.083367e-05  1.697752e-05  3.340340e-05  3.340340e-05  3.340340e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.297362e-03  1.732317e-03  2.222404e-03  4.923113e-03  5.946011e-03  6.326192e-03  9.558856e-03  5.216543e-02  5.216543e-02  7.580170e-02  5.755367e-01  6.161244e-01  9.631067e-01
# #unique......... 182, #Total UniqueCount: 1586
# var 1:
# best............ 8.097665e+02
# mean............ 7.935850e+02
# variance........ 1.952582e+03
# var 2:
# best............ 6.102663e+02
# mean............ 6.134941e+02
# variance........ 5.097607e+02
# var 3:
# best............ 6.953311e+01
# mean............ 8.097952e+01
# variance........ 4.153248e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.384469e+02
# variance........ 1.248874e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.344441e+02
# variance........ 4.949717e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.383322e+02
# variance........ 3.488885e+03
# var 7:
# best............ 1.395008e+01
# mean............ 2.385842e+01
# variance........ 4.390275e+03
# var 8:
# best............ 4.382440e+02
# mean............ 4.398701e+02
# variance........ 3.008422e+02
# var 9:
# best............ 6.991127e+01
# mean............ 8.399912e+01
# variance........ 6.382322e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.728273e+02
# variance........ 2.361200e+03
# var 11:
# best............ 6.587350e+02
# mean............ 6.379652e+02
# variance........ 4.054171e+03
# var 12:
# best............ 5.339148e+02
# mean............ 5.545738e+02
# variance........ 3.854305e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.718233e+02
# variance........ 3.821860e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.503681e+02
# variance........ 8.038499e+02
# var 15:
# best............ 2.681313e+02
# mean............ 2.674620e+02
# variance........ 1.828616e+03
# var 16:
# best............ 5.888720e+01
# mean............ 7.151439e+01
# variance........ 3.817588e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.264533e+02
# variance........ 3.332982e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.181553e+02
# variance........ 3.533282e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.567304e+02
# variance........ 5.112945e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.438477e+02
# variance........ 1.003181e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.908018e+02
# variance........ 1.206826e+03
# var 22:
# best............ 5.132299e+02
# mean............ 5.181199e+02
# variance........ 1.869414e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.200645e+02
# variance........ 2.534726e+03
# var 24:
# best............ 8.240451e+02
# mean............ 8.179321e+02
# variance........ 4.878297e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.380399e+02
# variance........ 2.479762e+03
# var 26:
# best............ 4.398485e+02
# mean............ 4.396276e+02
# variance........ 7.059424e+02
# var 27:
# best............ 2.292483e+02
# mean............ 2.378000e+02
# variance........ 2.086317e+03
#
# GENERATION: 8
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.220446e-15  3.552714e-15  7.105427e-15  1.121325e-14  3.497203e-14  8.837375e-14  1.235456e-12  1.338041e-12  1.148970e-11  1.816594e-10  1.330771e-09  1.690336e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.019898e-06  1.889774e-06  1.974618e-06  2.184540e-06  3.613471e-06  8.456373e-06  1.083367e-05  1.697752e-05  3.340340e-05  3.340340e-05  3.340340e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.297362e-03  1.732317e-03  2.222404e-03  4.923113e-03  5.946011e-03  6.326192e-03  9.558856e-03  5.216543e-02  5.216543e-02  7.580170e-02  5.755367e-01  6.161244e-01  9.631067e-01
# #unique......... 187, #Total UniqueCount: 1773
# var 1:
# best............ 8.097665e+02
# mean............ 7.836936e+02
# variance........ 5.557506e+03
# var 2:
# best............ 6.102663e+02
# mean............ 6.107681e+02
# variance........ 1.461326e+03
# var 3:
# best............ 6.953311e+01
# mean............ 9.129881e+01
# variance........ 8.846918e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.371401e+02
# variance........ 3.928669e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.238792e+02
# variance........ 2.917643e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.351887e+02
# variance........ 5.740403e+03
# var 7:
# best............ 1.395008e+01
# mean............ 2.387158e+01
# variance........ 3.984971e+03
# var 8:
# best............ 4.382440e+02
# mean............ 4.418933e+02
# variance........ 1.625160e+03
# var 9:
# best............ 6.991127e+01
# mean............ 7.776417e+01
# variance........ 2.857708e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.741952e+02
# variance........ 2.527564e+03
# var 11:
# best............ 6.587350e+02
# mean............ 6.354569e+02
# variance........ 3.990008e+03
# var 12:
# best............ 5.339148e+02
# mean............ 5.562038e+02
# variance........ 4.298151e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.679244e+02
# variance........ 2.746969e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.558218e+02
# variance........ 4.657212e+03
# var 15:
# best............ 2.681313e+02
# mean............ 2.721545e+02
# variance........ 2.728813e+03
# var 16:
# best............ 5.888720e+01
# mean............ 7.662931e+01
# variance........ 6.473065e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.223246e+02
# variance........ 2.698332e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.201489e+02
# variance........ 2.402874e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.523493e+02
# variance........ 8.217283e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.479757e+02
# variance........ 2.172914e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.988489e+02
# variance........ 6.202190e+03
# var 22:
# best............ 5.132299e+02
# mean............ 5.169404e+02
# variance........ 2.885283e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.169808e+02
# variance........ 3.015194e+03
# var 24:
# best............ 8.240451e+02
# mean............ 8.129144e+02
# variance........ 5.274355e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.375098e+02
# variance........ 2.561779e+03
# var 26:
# best............ 4.398485e+02
# mean............ 4.442252e+02
# variance........ 2.405982e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.362250e+02
# variance........ 2.000862e+03
#
# GENERATION: 9
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.220446e-15  3.552714e-15  7.105427e-15  1.121325e-14  3.497203e-14  8.837375e-14  1.235456e-12  1.338041e-12  1.148970e-11  1.816594e-10  1.330771e-09  1.690336e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.019898e-06  1.889774e-06  1.974618e-06  2.184540e-06  3.613471e-06  8.456373e-06  1.083367e-05  1.697752e-05  3.340340e-05  3.340340e-05  3.340340e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.297362e-03  1.732317e-03  2.222404e-03  4.923113e-03  5.946011e-03  6.326192e-03  9.558856e-03  5.216543e-02  5.216543e-02  7.580170e-02  5.755367e-01  6.161244e-01  9.631067e-01
# #unique......... 188, #Total UniqueCount: 1961
# var 1:
# best............ 8.097665e+02
# mean............ 7.873099e+02
# variance........ 6.358739e+03
# var 2:
# best............ 6.102663e+02
# mean............ 6.113707e+02
# variance........ 1.000041e+03
# var 3:
# best............ 6.953311e+01
# mean............ 8.351560e+01
# variance........ 5.496706e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.349529e+02
# variance........ 3.177383e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.297612e+02
# variance........ 3.735327e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.336852e+02
# variance........ 5.460095e+03
# var 7:
# best............ 1.395008e+01
# mean............ 3.292675e+01
# variance........ 9.779381e+03
# var 8:
# best............ 4.382440e+02
# mean............ 4.418313e+02
# variance........ 1.289157e+03
# var 9:
# best............ 6.991127e+01
# mean............ 7.709332e+01
# variance........ 2.215820e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.697023e+02
# variance........ 2.484060e+03
# var 11:
# best............ 6.587350e+02
# mean............ 6.410042e+02
# variance........ 4.430494e+03
# var 12:
# best............ 5.339148e+02
# mean............ 5.559481e+02
# variance........ 4.094247e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.699543e+02
# variance........ 3.845574e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.615516e+02
# variance........ 5.654401e+03
# var 15:
# best............ 2.681313e+02
# mean............ 2.788259e+02
# variance........ 6.229245e+03
# var 16:
# best............ 5.888720e+01
# mean............ 7.417264e+01
# variance........ 5.437142e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.226517e+02
# variance........ 2.275501e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.157549e+02
# variance........ 1.353380e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.514196e+02
# variance........ 9.701341e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.498198e+02
# variance........ 3.339322e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.883391e+02
# variance........ 1.321280e+03
# var 22:
# best............ 5.132299e+02
# mean............ 5.112409e+02
# variance........ 1.789305e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.138835e+02
# variance........ 2.184678e+03
# var 24:
# best............ 8.240451e+02
# mean............ 8.162201e+02
# variance........ 3.687376e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.428961e+02
# variance........ 2.093200e+03
# var 26:
# best............ 4.398485e+02
# mean............ 4.401337e+02
# variance........ 1.435305e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.358243e+02
# variance........ 2.771671e+03
#
# GENERATION: 10
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.664535e-15  3.108624e-15  3.552714e-15  1.121325e-14  3.497203e-14  4.529710e-14  4.805045e-13  6.337153e-13  5.217826e-12  1.151395e-10  7.350338e-10  1.257855e-07  2.385959e-07  4.252923e-07  5.127274e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.477965e-06  1.974618e-06  2.422631e-06  4.127817e-06  7.598219e-06  1.697752e-05  1.697752e-05  1.697752e-05  1.697752e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.373691e-03  1.944507e-03  3.366316e-03  4.109345e-03  5.946011e-03  9.558856e-03  1.370414e-02  3.518054e-02  3.518054e-02  7.580170e-02  5.209333e-01  5.580633e-01  9.649853e-01
# #unique......... 176, #Total UniqueCount: 2137
# var 1:
# best............ 5.490186e+02
# mean............ 7.924785e+02
# variance........ 2.349026e+03
# var 2:
# best............ 6.102663e+02
# mean............ 6.075840e+02
# variance........ 2.367046e+03
# var 3:
# best............ 6.953311e+01
# mean............ 8.077344e+01
# variance........ 3.557120e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.385617e+02
# variance........ 2.627051e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.253957e+02
# variance........ 2.520742e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.268321e+02
# variance........ 1.123611e+04
# var 7:
# best............ 1.395008e+01
# mean............ 2.045160e+01
# variance........ 2.101555e+03
# var 8:
# best............ 4.385899e+02
# mean............ 4.417278e+02
# variance........ 1.650849e+03
# var 9:
# best............ 6.991127e+01
# mean............ 7.619990e+01
# variance........ 2.263282e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.706395e+02
# variance........ 2.482162e+03
# var 11:
# best............ 3.058062e+02
# mean............ 6.431699e+02
# variance........ 3.711338e+03
# var 12:
# best............ 6.056916e+02
# mean............ 5.599997e+02
# variance........ 4.968297e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.737029e+02
# variance........ 4.340396e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.570174e+02
# variance........ 4.334446e+03
# var 15:
# best............ 3.090008e+02
# mean............ 2.699751e+02
# variance........ 2.539251e+03
# var 16:
# best............ 5.888720e+01
# mean............ 6.796540e+01
# variance........ 2.252952e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.274607e+02
# variance........ 3.391589e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.167331e+02
# variance........ 2.602050e+03
# var 19:
# best............ 8.779894e+02
# mean............ 8.575257e+02
# variance........ 7.027647e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.451344e+02
# variance........ 2.109744e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.888009e+02
# variance........ 1.262236e+03
# var 22:
# best............ 4.680621e+02
# mean............ 5.146623e+02
# variance........ 1.405190e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.152035e+02
# variance........ 2.991841e+03
# var 24:
# best............ 9.527816e+02
# mean............ 8.172062e+02
# variance........ 4.938865e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.405010e+02
# variance........ 3.765024e+03
# var 26:
# best............ 5.589236e+02
# mean............ 4.429128e+02
# variance........ 2.357668e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.312407e+02
# variance........ 8.794895e+02
#
# GENERATION: 11
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  2.664535e-15  3.108624e-15  3.552714e-15  1.121325e-14  3.497203e-14  4.529710e-14  4.805045e-13  6.337153e-13  5.217826e-12  1.151395e-10  7.350338e-10  1.257855e-07  2.385959e-07  4.252923e-07  5.127274e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.477965e-06  1.974618e-06  2.422631e-06  4.127817e-06  7.598219e-06  1.697752e-05  1.697752e-05  1.697752e-05  1.697752e-05  2.253712e-04  2.253712e-04  4.089972e-04  7.273922e-04  1.267778e-03  1.373691e-03  1.944507e-03  3.366316e-03  4.109345e-03  5.946011e-03  9.558856e-03  1.370414e-02  3.518054e-02  3.518054e-02  7.580170e-02  5.209333e-01  5.580633e-01  9.649853e-01
# #unique......... 174, #Total UniqueCount: 2311
# var 1:
# best............ 5.490186e+02
# mean............ 6.835419e+02
# variance........ 1.894115e+04
# var 2:
# best............ 6.102663e+02
# mean............ 6.098049e+02
# variance........ 1.826352e+03
# var 3:
# best............ 6.953311e+01
# mean............ 8.445573e+01
# variance........ 7.693468e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.366240e+02
# variance........ 3.608502e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.279109e+02
# variance........ 4.274773e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.425676e+02
# variance........ 1.157676e+03
# var 7:
# best............ 1.395008e+01
# mean............ 2.732253e+01
# variance........ 6.951327e+03
# var 8:
# best............ 4.385899e+02
# mean............ 4.375556e+02
# variance........ 2.684365e+03
# var 9:
# best............ 6.991127e+01
# mean............ 8.534059e+01
# variance........ 7.209335e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.730658e+02
# variance........ 1.606384e+03
# var 11:
# best............ 3.058062e+02
# mean............ 4.966175e+02
# variance........ 2.958090e+04
# var 12:
# best............ 6.056916e+02
# mean............ 5.768524e+02
# variance........ 4.125088e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.646638e+02
# variance........ 1.378054e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.592410e+02
# variance........ 4.765393e+03
# var 15:
# best............ 3.090008e+02
# mean............ 2.904806e+02
# variance........ 2.942924e+03
# var 16:
# best............ 5.888720e+01
# mean............ 7.103106e+01
# variance........ 3.465840e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.253328e+02
# variance........ 1.494273e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.157394e+02
# variance........ 9.555545e+02
# var 19:
# best............ 8.779894e+02
# mean............ 8.619449e+02
# variance........ 4.963195e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.474616e+02
# variance........ 2.047420e+03
# var 21:
# best............ 3.880507e+02
# mean............ 3.909462e+02
# variance........ 1.856118e+03
# var 22:
# best............ 4.680621e+02
# mean............ 5.012736e+02
# variance........ 3.065038e+03
# var 23:
# best............ 4.086061e+02
# mean............ 4.148518e+02
# variance........ 2.193993e+03
# var 24:
# best............ 9.527816e+02
# mean............ 8.766446e+02
# variance........ 4.994146e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.380215e+02
# variance........ 2.609557e+03
# var 26:
# best............ 5.589236e+02
# mean............ 4.902412e+02
# variance........ 4.321194e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.319356e+02
# variance........ 5.347310e+02
#
# GENERATION: 12
# Lexical Fit..... 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.110223e-16  1.110223e-16  8.881784e-16  3.552714e-15  3.996803e-15  8.881784e-15  1.121325e-14  3.497203e-14  1.132427e-13  1.117106e-12  1.427747e-12  1.074718e-11  4.004224e-10  2.177939e-09  6.060167e-08  9.253883e-08  1.667653e-07  1.914826e-07  7.740663e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.145205e-06  1.974618e-06  1.974618e-06  3.608762e-06  8.456373e-06  8.456373e-06  8.456373e-06  3.340340e-05  4.089972e-04  4.089972e-04  4.089972e-04  4.089972e-04  7.043408e-04  1.267778e-03  2.193543e-03  3.624699e-03  5.734526e-03  5.946011e-03  9.523746e-03  3.518054e-02  3.518054e-02  3.892000e-02  1.079376e-01  5.928993e-01  6.296475e-01  7.514119e-01
# #unique......... 197, #Total UniqueCount: 2508
# var 1:
# best............ 5.490186e+02
# mean............ 5.476251e+02
# variance........ 7.747300e+02
# var 2:
# best............ 6.102663e+02
# mean............ 6.108354e+02
# variance........ 1.510161e+03
# var 3:
# best............ 6.953311e+01
# mean............ 7.868290e+01
# variance........ 5.159570e+03
# var 4:
# best............ 8.440309e+02
# mean............ 8.385531e+02
# variance........ 3.151527e+03
# var 5:
# best............ 2.193306e+02
# mean............ 2.226189e+02
# variance........ 2.365344e+03
# var 6:
# best............ 9.492438e+02
# mean............ 9.411877e+02
# variance........ 2.363336e+03
# var 7:
# best............ 1.395008e+01
# mean............ 1.995398e+01
# variance........ 2.457514e+03
# var 8:
# best............ 4.385899e+02
# mean............ 4.431137e+02
# variance........ 1.228411e+03
# var 9:
# best............ 6.991127e+01
# mean............ 7.853568e+01
# variance........ 4.344390e+03
# var 10:
# best............ 3.697000e+02
# mean............ 3.704432e+02
# variance........ 3.844581e+02
# var 11:
# best............ 3.058062e+02
# mean............ 3.140949e+02
# variance........ 3.705536e+03
# var 12:
# best............ 9.890791e+02
# mean............ 6.038578e+02
# variance........ 1.981852e+03
# var 13:
# best............ 1.579006e+02
# mean............ 1.664623e+02
# variance........ 4.228991e+03
# var 14:
# best............ 1.474645e+02
# mean............ 1.557716e+02
# variance........ 3.409365e+03
# var 15:
# best............ 3.090008e+02
# mean............ 3.179890e+02
# variance........ 3.438979e+03
# var 16:
# best............ 5.888720e+01
# mean............ 7.068367e+01
# variance........ 5.792301e+03
# var 17:
# best............ 4.265700e+02
# mean............ 4.269388e+02
# variance........ 2.373768e+03
# var 18:
# best............ 4.151292e+02
# mean............ 4.200553e+02
# variance........ 7.561032e+02
# var 19:
# best............ 8.779894e+02
# mean............ 8.691574e+02
# variance........ 3.892996e+03
# var 20:
# best............ 3.406755e+02
# mean............ 3.401224e+02
# variance........ 9.517596e+02
# var 21:
# best............ 3.880507e+02
# mean............ 3.850473e+02
# variance........ 7.607046e+02
# var 22:
# best............ 4.680621e+02
# mean............ 4.669164e+02
# variance........ 8.729076e+02
# var 23:
# best............ 4.086061e+02
# mean............ 4.094771e+02
# variance........ 1.487982e+03
# var 24:
# best............ 9.527816e+02
# mean............ 9.430697e+02
# variance........ 4.003981e+03
# var 25:
# best............ 4.408271e+02
# mean............ 4.404503e+02
# variance........ 1.555281e+03
# var 26:
# best............ 5.589236e+02
# mean............ 5.614053e+02
# variance........ 1.718116e+03
# var 27:
# best............ 2.292483e+02
# mean............ 2.415124e+02
# variance........ 5.525146e+03
#
# GENERATION: 13
# ...
# mean............ 5.586825e+02
# variance........ 1.851766e+03
# var 24:
# best............ 6.656641e+02
# mean............ 6.596436e+02
# variance........ 2.897766e+03
# var 25:
# best............ 5.190083e+02
# mean............ 5.158706e+02
# variance........ 2.760364e+03
# var 26:
# best............ 5.432544e+02
# mean............ 5.360479e+02
# variance........ 2.842418e+03
# var 27:
# best............ 2.384604e+02
# mean............ 2.410268e+02
# variance........ 1.467814e+03
#
# GENERATION: 52
# Lexical Fit..... 0.000000e+00  1.110223e-16  1.110223e-16  4.440892e-16  8.881784e-16  3.108624e-15  3.552714e-15  1.121325e-14  3.497203e-14  1.012523e-13  6.710188e-13  8.104628e-13  2.629690e-09  5.926537e-09  9.642438e-09  1.548149e-08  1.661668e-08  3.638655e-08  8.448847e-08  9.097362e-08  9.137247e-08  2.668346e-07  4.252923e-07  4.252923e-07  4.252923e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.197958e-06  1.974618e-06  2.237229e-06  1.671585e-05  2.277745e-05  3.254379e-05  3.340340e-05  1.217034e-04  2.253712e-04  4.089972e-04  7.074892e-04  1.215090e-03  1.267778e-03  1.267778e-03  9.558856e-03  9.558856e-03  9.558856e-03  3.518054e-02  3.518054e-02  2.508724e-01  6.358830e-01  6.681470e-01  7.275775e-01  7.736092e-01  8.365613e-01
# #unique......... 177, #Total UniqueCount: 9690
# var 1:
# best............ 1.884827e+02
# mean............ 1.960048e+02
# variance........ 3.793734e+03
# var 2:
# best............ 6.061618e+02
# mean............ 5.989526e+02
# variance........ 4.133586e+03
# var 3:
# best............ 9.901963e+02
# mean............ 9.748966e+02
# variance........ 7.244139e+03
# var 4:
# best............ 8.618042e+01
# mean............ 9.375813e+01
# variance........ 2.892226e+03
# var 5:
# best............ 5.420233e+01
# mean............ 6.490803e+01
# variance........ 3.218976e+03
# var 6:
# best............ 9.484360e+02
# mean............ 9.341008e+02
# variance........ 5.723141e+03
# var 7:
# best............ 1.771630e+01
# mean............ 2.296286e+01
# variance........ 1.166606e+03
# var 8:
# best............ 9.333489e+02
# mean............ 9.229772e+02
# variance........ 5.513827e+03
# var 9:
# best............ 5.965634e+02
# mean............ 5.942749e+02
# variance........ 4.901490e+02
# var 10:
# best............ 4.234819e+02
# mean............ 4.287549e+02
# variance........ 2.224268e+03
# var 11:
# best............ 6.271961e+01
# mean............ 7.695745e+01
# variance........ 6.494979e+03
# var 12:
# best............ 9.890651e+02
# mean............ 9.712302e+02
# variance........ 9.271126e+03
# var 13:
# best............ 4.766460e+00
# mean............ 2.988554e+01
# variance........ 1.287435e+04
# var 14:
# best............ 9.622921e-03
# mean............ 1.242048e+01
# variance........ 6.792541e+03
# var 15:
# best............ 4.449735e+01
# mean............ 5.442802e+01
# variance........ 3.130218e+03
# var 16:
# best............ 5.886087e+01
# mean............ 6.411025e+01
# variance........ 1.047430e+03
# var 17:
# best............ 5.376560e+00
# mean............ 1.955893e+01
# variance........ 7.566955e+03
# var 18:
# best............ 5.083451e+02
# mean............ 5.086003e+02
# variance........ 1.237376e+03
# var 19:
# best............ 7.942818e+02
# mean............ 7.815323e+02
# variance........ 5.288805e+03
# var 20:
# best............ 3.708336e+02
# mean............ 3.785018e+02
# variance........ 3.234090e+03
# var 21:
# best............ 8.689317e+02
# mean............ 8.620119e+02
# variance........ 1.781294e+03
# var 22:
# best............ 5.261344e+02
# mean............ 5.247149e+02
# variance........ 4.453372e+03
# var 23:
# best............ 5.611410e+02
# mean............ 5.573444e+02
# variance........ 3.275795e+03
# var 24:
# best............ 6.656641e+02
# mean............ 6.566194e+02
# variance........ 4.549670e+03
# var 25:
# best............ 5.190083e+02
# mean............ 5.223993e+02
# variance........ 2.427017e+03
# var 26:
# best............ 5.432544e+02
# mean............ 5.439935e+02
# variance........ 1.814182e+03
# var 27:
# best............ 2.384604e+02
# mean............ 2.425869e+02
# variance........ 2.350945e+03
#
# GENERATION: 53
# Lexical Fit..... 0.000000e+00  1.110223e-16  1.110223e-16  4.440892e-16  8.881784e-16  3.108624e-15  3.552714e-15  1.121325e-14  3.497203e-14  1.012523e-13  6.710188e-13  8.104628e-13  2.629690e-09  5.926537e-09  9.642438e-09  1.548149e-08  1.661668e-08  3.638655e-08  8.448847e-08  9.097362e-08  9.137247e-08  2.668346e-07  4.252923e-07  4.252923e-07  4.252923e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.197958e-06  1.974618e-06  2.237229e-06  1.671585e-05  2.277745e-05  3.254379e-05  3.340340e-05  1.217034e-04  2.253712e-04  4.089972e-04  7.074892e-04  1.215090e-03  1.267778e-03  1.267778e-03  9.558856e-03  9.558856e-03  9.558856e-03  3.518054e-02  3.518054e-02  2.508724e-01  6.358830e-01  6.681470e-01  7.275775e-01  7.736092e-01  8.365613e-01
# #unique......... 175, #Total UniqueCount: 9865
# var 1:
# best............ 1.884827e+02
# mean............ 1.919498e+02
# variance........ 1.591513e+03
# var 2:
# best............ 6.061618e+02
# mean............ 6.040877e+02
# variance........ 8.602018e+02
# var 3:
# best............ 9.901963e+02
# mean............ 9.763385e+02
# variance........ 6.276717e+03
# var 4:
# best............ 8.618042e+01
# mean............ 9.571300e+01
# variance........ 3.204724e+03
# var 5:
# best............ 5.420233e+01
# mean............ 6.031895e+01
# variance........ 1.335427e+03
# var 6:
# best............ 9.484360e+02
# mean............ 9.428892e+02
# variance........ 1.483548e+03
# var 7:
# best............ 1.771630e+01
# mean............ 2.852488e+01
# variance........ 5.691225e+03
# var 8:
# best............ 9.333489e+02
# mean............ 9.269743e+02
# variance........ 2.293812e+03
# var 9:
# best............ 5.965634e+02
# mean............ 5.945706e+02
# variance........ 1.102957e+03
# var 10:
# best............ 4.234819e+02
# mean............ 4.259066e+02
# variance........ 1.384341e+03
# var 11:
# best............ 6.271961e+01
# mean............ 7.299354e+01
# variance........ 5.061893e+03
# var 12:
# best............ 9.890651e+02
# mean............ 9.746252e+02
# variance........ 7.305304e+03
# var 13:
# best............ 4.766460e+00
# mean............ 1.542918e+01
# variance........ 4.525372e+03
# var 14:
# best............ 9.622921e-03
# mean............ 9.630293e+00
# variance........ 3.312874e+03
# var 15:
# best............ 4.449735e+01
# mean............ 5.644154e+01
# variance........ 4.453954e+03
# var 16:
# best............ 5.886087e+01
# mean............ 6.801718e+01
# variance........ 3.173399e+03
# var 17:
# best............ 5.376560e+00
# mean............ 2.059769e+01
# variance........ 7.007147e+03
# var 18:
# best............ 5.083451e+02
# mean............ 5.058633e+02
# variance........ 1.163804e+03
# var 19:
# best............ 7.942818e+02
# mean............ 7.860289e+02
# variance........ 3.519621e+03
# var 20:
# best............ 3.708336e+02
# mean............ 3.762682e+02
# variance........ 2.275107e+03
# var 21:
# best............ 8.689317e+02
# mean............ 8.661431e+02
# variance........ 9.483120e+02
# var 22:
# best............ 5.261344e+02
# mean............ 5.299118e+02
# variance........ 2.901064e+03
# var 23:
# best............ 5.611410e+02
# mean............ 5.588747e+02
# variance........ 1.057592e+03
# var 24:
# best............ 6.656641e+02
# mean............ 6.635475e+02
# variance........ 7.061012e+02
# var 25:
# best............ 5.190083e+02
# mean............ 5.207603e+02
# variance........ 7.772334e+02
# var 26:
# best............ 5.432544e+02
# mean............ 5.452480e+02
# variance........ 1.411579e+03
# var 27:
# best............ 2.384604e+02
# mean............ 2.462993e+02
# variance........ 3.877737e+03
#
# GENERATION: 54
# Lexical Fit..... 0.000000e+00  1.110223e-16  1.110223e-16  4.440892e-16  8.881784e-16  3.108624e-15  3.552714e-15  1.121325e-14  3.497203e-14  1.012523e-13  6.710188e-13  8.104628e-13  2.629690e-09  5.926537e-09  9.642438e-09  1.548149e-08  1.661668e-08  3.638655e-08  8.448847e-08  9.097362e-08  9.137247e-08  2.668346e-07  4.252923e-07  4.252923e-07  4.252923e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.197958e-06  1.974618e-06  2.237229e-06  1.671585e-05  2.277745e-05  3.254379e-05  3.340340e-05  1.217034e-04  2.253712e-04  4.089972e-04  7.074892e-04  1.215090e-03  1.267778e-03  1.267778e-03  9.558856e-03  9.558856e-03  9.558856e-03  3.518054e-02  3.518054e-02  2.508724e-01  6.358830e-01  6.681470e-01  7.275775e-01  7.736092e-01  8.365613e-01
# #unique......... 170, #Total UniqueCount: 10035
# var 1:
# best............ 1.884827e+02
# mean............ 2.029146e+02
# variance........ 5.937502e+03
# var 2:
# best............ 6.061618e+02
# mean............ 6.000935e+02
# variance........ 2.552456e+03
# var 3:
# best............ 9.901963e+02
# mean............ 9.718740e+02
# variance........ 1.027596e+04
# var 4:
# best............ 8.618042e+01
# mean............ 9.665650e+01
# variance........ 3.303717e+03
# var 5:
# best............ 5.420233e+01
# mean............ 6.510941e+01
# variance........ 4.274187e+03
# var 6:
# best............ 9.484360e+02
# mean............ 9.372387e+02
# variance........ 4.349593e+03
# var 7:
# best............ 1.771630e+01
# mean............ 3.436945e+01
# variance........ 7.265583e+03
# var 8:
# best............ 9.333489e+02
# mean............ 9.258883e+02
# variance........ 2.288771e+03
# var 9:
# best............ 5.965634e+02
# mean............ 5.929150e+02
# variance........ 1.609061e+03
# var 10:
# best............ 4.234819e+02
# mean............ 4.231070e+02
# variance........ 3.052849e+03
# var 11:
# best............ 6.271961e+01
# mean............ 7.143030e+01
# variance........ 3.090252e+03
# var 12:
# best............ 9.890651e+02
# mean............ 9.777283e+02
# variance........ 4.003326e+03
# var 13:
# best............ 4.766460e+00
# mean............ 1.716560e+01
# variance........ 5.268127e+03
# var 14:
# best............ 9.622921e-03
# mean............ 2.400302e+01
# variance........ 1.171452e+04
# var 15:
# best............ 4.449735e+01
# mean............ 5.588435e+01
# variance........ 4.459270e+03
# var 16:
# best............ 5.886087e+01
# mean............ 7.475599e+01
# variance........ 7.591933e+03
# var 17:
# best............ 5.376560e+00
# mean............ 2.098975e+01
# variance........ 7.978893e+03
# var 18:
# best............ 5.083451e+02
# mean............ 5.075764e+02
# variance........ 1.366208e+03
# var 19:
# best............ 7.942818e+02
# mean............ 7.871359e+02
# variance........ 2.916092e+03
# var 20:
# best............ 3.708336e+02
# mean............ 3.693013e+02
# variance........ 9.457592e+02
# var 21:
# best............ 8.689317e+02
# mean............ 8.601798e+02
# variance........ 3.629328e+03
# var 22:
# best............ 5.261344e+02
# mean............ 5.212653e+02
# variance........ 1.444342e+03
# var 23:
# best............ 5.611410e+02
# mean............ 5.591640e+02
# variance........ 2.679394e+03
# var 24:
# best............ 6.656641e+02
# mean............ 6.605797e+02
# variance........ 2.298982e+03
# var 25:
# best............ 5.190083e+02
# mean............ 5.188390e+02
# variance........ 2.718953e+03
# var 26:
# best............ 5.432544e+02
# mean............ 5.428023e+02
# variance........ 2.836445e+03
# var 27:
# best............ 2.384604e+02
# mean............ 2.507187e+02
# variance........ 6.165796e+03
#
# GENERATION: 55
# Lexical Fit..... 0.000000e+00  1.110223e-16  1.110223e-16  4.440892e-16  8.881784e-16  3.108624e-15  3.552714e-15  1.121325e-14  3.497203e-14  1.012523e-13  6.710188e-13  8.104628e-13  2.629690e-09  5.926537e-09  9.642438e-09  1.548149e-08  1.661668e-08  3.638655e-08  8.448847e-08  9.097362e-08  9.137247e-08  2.668346e-07  4.252923e-07  4.252923e-07  4.252923e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.197958e-06  1.974618e-06  2.237229e-06  1.671585e-05  2.277745e-05  3.254379e-05  3.340340e-05  1.217034e-04  2.253712e-04  4.089972e-04  7.074892e-04  1.215090e-03  1.267778e-03  1.267778e-03  9.558856e-03  9.558856e-03  9.558856e-03  3.518054e-02  3.518054e-02  2.508724e-01  6.358830e-01  6.681470e-01  7.275775e-01  7.736092e-01  8.365613e-01
# #unique......... 177, #Total UniqueCount: 10212
# var 1:
# best............ 1.884827e+02
# mean............ 1.933781e+02
# variance........ 2.456815e+03
# var 2:
# best............ 6.061618e+02
# mean............ 6.056065e+02
# variance........ 1.371306e+03
# var 3:
# best............ 9.901963e+02
# mean............ 9.740275e+02
# variance........ 7.790188e+03
# var 4:
# best............ 8.618042e+01
# mean............ 9.618469e+01
# variance........ 4.492238e+03
# var 5:
# best............ 5.420233e+01
# mean............ 6.439005e+01
# variance........ 3.653446e+03
# var 6:
# best............ 9.484360e+02
# mean............ 9.317783e+02
# variance........ 6.982616e+03
# var 7:
# best............ 1.771630e+01
# mean............ 4.178920e+01
# variance........ 1.639554e+04
# var 8:
# best............ 9.333489e+02
# mean............ 9.264210e+02
# variance........ 3.046763e+03
# var 9:
# best............ 5.965634e+02
# mean............ 5.932061e+02
# variance........ 1.326054e+03
# var 10:
# best............ 4.234819e+02
# mean............ 4.290326e+02
# variance........ 1.944128e+03
# var 11:
# best............ 6.271961e+01
# mean............ 7.534730e+01
# variance........ 5.552995e+03
# var 12:
# best............ 9.890651e+02
# mean............ 9.742360e+02
# variance........ 8.490023e+03
# var 13:
# best............ 4.766460e+00
# mean............ 2.310411e+01
# variance........ 1.054905e+04
# var 14:
# best............ 9.622921e-03
# mean............ 9.685747e+00
# variance........ 2.890797e+03
# var 15:
# best............ 4.449735e+01
# mean............ 5.125215e+01
# variance........ 2.309982e+03
# var 16:
# best............ 5.886087e+01
# mean............ 6.929811e+01
# variance........ 4.759252e+03
# var 17:
# best............ 5.376560e+00
# mean............ 1.841624e+01
# variance........ 6.028615e+03
# var 18:
# best............ 5.083451e+02
# mean............ 5.108413e+02
# variance........ 3.266101e+03
# var 19:
# best............ 7.942818e+02
# mean............ 7.891977e+02
# variance........ 1.394523e+03
# var 20:
# best............ 3.708336e+02
# mean............ 3.706770e+02
# variance........ 1.930906e+03
# var 21:
# best............ 8.689317e+02
# mean............ 8.640271e+02
# variance........ 2.052558e+03
# var 22:
# best............ 5.261344e+02
# mean............ 5.246640e+02
# variance........ 1.823999e+03
# var 23:
# best............ 5.611410e+02
# mean............ 5.600885e+02
# variance........ 9.972157e+02
# var 24:
# best............ 6.656641e+02
# mean............ 6.550397e+02
# variance........ 3.756154e+03
# var 25:
# best............ 5.190083e+02
# mean............ 5.145472e+02
# variance........ 2.870032e+03
# var 26:
# best............ 5.432544e+02
# mean............ 5.433645e+02
# variance........ 2.539095e+03
# var 27:
# best............ 2.384604e+02
# mean............ 2.541430e+02
# variance........ 8.164577e+03
#
# 'wait.generations' limit reached.
# No significant improvement in 25 generations.
#
# Solution Lexical Fitness Value:
# 0.000000e+00  1.110223e-16  1.110223e-16  4.440892e-16  8.881784e-16  3.108624e-15  3.552714e-15  1.121325e-14  3.497203e-14  1.012523e-13  6.710188e-13  8.104628e-13  2.629690e-09  5.926537e-09  9.642438e-09  1.548149e-08  1.661668e-08  3.638655e-08  8.448847e-08  9.097362e-08  9.137247e-08  2.668346e-07  4.252923e-07  4.252923e-07  4.252923e-07  9.257039e-07  9.257039e-07  9.257039e-07  9.257039e-07  1.197958e-06  1.974618e-06  2.237229e-06  1.671585e-05  2.277745e-05  3.254379e-05  3.340340e-05  1.217034e-04  2.253712e-04  4.089972e-04  7.074892e-04  1.215090e-03  1.267778e-03  1.267778e-03  9.558856e-03  9.558856e-03  9.558856e-03  3.518054e-02  3.518054e-02  2.508724e-01  6.358830e-01  6.681470e-01  7.275775e-01  7.736092e-01  8.365613e-01
#
# Parameters at the Solution:
#
#  X[ 1] :	1.884827e+02
#  X[ 2] :	6.061618e+02
#  X[ 3] :	9.901963e+02
#  X[ 4] :	8.618042e+01
#  X[ 5] :	5.420233e+01
#  X[ 6] :	9.484360e+02
#  X[ 7] :	1.771630e+01
#  X[ 8] :	9.333489e+02
#  X[ 9] :	5.965634e+02
#  X[10] :	4.234819e+02
#  X[11] :	6.271961e+01
#  X[12] :	9.890651e+02
#  X[13] :	4.766460e+00
#  X[14] :	9.622921e-03
#  X[15] :	4.449735e+01
#  X[16] :	5.886087e+01
#  X[17] :	5.376560e+00
#  X[18] :	5.083451e+02
#  X[19] :	7.942818e+02
#  X[20] :	3.708336e+02
#  X[21] :	8.689317e+02
#  X[22] :	5.261344e+02
#  X[23] :	5.611410e+02
#  X[24] :	6.656641e+02
#  X[25] :	5.190083e+02
#  X[26] :	5.432544e+02
#  X[27] :	2.384604e+02
#
# Solution Found Generation 29
# Number of Generations Run 55
#
# Fri Dec 20 02:10:52 2019
# Total run time : 0 hours 3 minutes and 0 seconds

# %%
mout = Match(Tr = Tr, X = X.all, M=1, Weight.matrix = genout)

# %%
summary(mout)
# Out:
# Estimate...  0
# SE.........  0
# T-stat.....  NaN
# p.val......  NA
#
# Original number of observations..............  130
# Original number of treated obs...............  99
# Matched number of observations...............  99
# Matched number of observations  (unweighted).  99

# %%
mb <- MatchBalance(after.data$treat ~ after.data$state + after.data$pcgsdp + after.data$pfemale + after.data$plit + after.data$pwlit + after.data$prural, match.out=mout, nboots=500)
# Out:
# ***** (V1) after.data$state *****
#                        Before Matching 	 	 After Matching
# mean treatment........     6.9091 	 	     6.9091
# mean control..........     8.5484 	 	     9.5859
# std mean diff.........    -32.599 	 	     -53.23
#
# mean raw eQQ diff.....     2.1613 	 	     2.6768
# med  raw eQQ diff.....          1 	 	          1
# max  raw eQQ diff.....          9 	 	          9
#
# mean eCDF diff........    0.13851 	 	    0.15253
# med  eCDF diff........    0.12284 	 	    0.13131
# max  eCDF diff........    0.33464 	 	    0.39394
#
# var ratio (Tr/Co).....    0.65871 	 	    0.81092
# T-test p-value........    0.18686 	 	 1.6716e-05
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value......   0.010111 	 	 4.2529e-07
# KS Statistic..........    0.33464 	 	    0.39394
#
#
# ***** (V2) after.data$pcgsdp *****
#                        Before Matching 	 	 After Matching
# mean treatment........     2.1787 	 	     2.1787
# mean control..........      1.164 	 	     1.5799
# std mean diff.........     143.57 	 	     84.724
#
# mean raw eQQ diff.....     1.0135 	 	    0.59927
# med  raw eQQ diff.....    0.93248 	 	    0.48144
# max  raw eQQ diff.....     2.3154 	 	     2.3154
#
# mean eCDF diff........    0.42017 	 	    0.27535
# med  eCDF diff........    0.42929 	 	    0.27273
# max  eCDF diff........    0.75562 	 	    0.61616
#
# var ratio (Tr/Co).....     4.1453 	 	     4.8435
# T-test p-value........ < 2.22e-16 	 	 8.8818e-16
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... 5.9952e-14 	 	 < 2.22e-16
# KS Statistic..........    0.75562 	 	    0.61616
#
#
# ***** (V3) after.data$pfemale *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.93402 	 	    0.93402
# mean control..........    0.91168 	 	    0.93514
# std mean diff.........     54.573 	 	    -2.7156
#
# mean raw eQQ diff.....   0.029935 	 	   0.011245
# med  raw eQQ diff.....   0.022884 	 	  0.0089636
# max  raw eQQ diff.....   0.054991 	 	   0.033243
#
# mean eCDF diff........    0.20641 	 	   0.077348
# med  eCDF diff........    0.24373 	 	   0.075758
# max  eCDF diff........    0.41219 	 	    0.20202
#
# var ratio (Tr/Co).....      4.068 	 	     1.2761
# T-test p-value........ 9.4019e-05 	 	    0.72758
# KS Bootstrap p-value.. < 2.22e-16 	 	       0.02
# KS Naive p-value...... 0.00039652 	 	   0.035181
# KS Statistic..........    0.41219 	 	    0.20202
#
#
# ***** (V4) after.data$plit *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.55776 	 	    0.55776
# mean control..........    0.44882 	 	    0.51753
# std mean diff.........     131.34 	 	     48.505
#
# mean raw eQQ diff.....    0.10727 	 	   0.041475
# med  raw eQQ diff.....    0.10429 	 	   0.037501
# max  raw eQQ diff.....    0.17097 	 	     0.1375
#
# mean eCDF diff........    0.35533 	 	    0.15002
# med  eCDF diff........    0.35761 	 	    0.14646
# max  eCDF diff........    0.63245 	 	    0.38384
#
# var ratio (Tr/Co).....     2.1262 	 	     1.7102
# T-test p-value........ 4.4098e-12 	 	 5.9265e-09
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... 1.7559e-09 	 	  9.257e-07
# KS Statistic..........    0.63245 	 	    0.38384
#
#
# ***** (V5) after.data$pwlit *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.46168 	 	    0.46168
# mean control..........    0.34436 	 	    0.42216
# std mean diff.........     119.33 	 	     40.189
#
# mean raw eQQ diff.....    0.11511 	 	   0.042256
# med  raw eQQ diff.....    0.12534 	 	   0.033844
# max  raw eQQ diff.....    0.17462 	 	    0.16177
#
# mean eCDF diff........    0.32959 	 	    0.13318
# med  eCDF diff........    0.35761 	 	    0.13131
# max  eCDF diff........     0.5334 	 	    0.38384
#
# var ratio (Tr/Co).....     1.9776 	 	     1.7698
# T-test p-value........ 2.8749e-10 	 	 9.0974e-08
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value......  1.009e-06 	 	  9.257e-07
# KS Statistic..........     0.5334 	 	    0.38384
#
#
# ***** (V6) after.data$prural *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.74033 	 	    0.74033
# mean control..........    0.81251 	 	    0.73935
# std mean diff.........    -66.339 	 	    0.90432
#
# mean raw eQQ diff.....   0.081253 	 	   0.028798
# med  raw eQQ diff.....   0.074682 	 	   0.023051
# max  raw eQQ diff.....    0.21918 	 	    0.10663
#
# mean eCDF diff........    0.25724 	 	   0.080902
# med  eCDF diff........    0.23656 	 	   0.070707
# max  eCDF diff........     0.5536 	 	    0.23232
#
# var ratio (Tr/Co).....     3.2615 	 	     1.1561
# T-test p-value........ 9.2926e-06 	 	    0.83656
# KS Bootstrap p-value.. < 2.22e-16 	 	      0.008
# KS Naive p-value...... 3.1028e-07 	 	  0.0095589
# KS Statistic..........     0.5536 	 	    0.23232
#
#
# Before Matching Minimum p.value: < 2.22e-16
# Variable Name(s): after.data$state after.data$pcgsdp after.data$pfemale after.data$plit after.data$pwlit after.data$prural  Number(s): 1 2 3 4 5 6
#
# After Matching Minimum p.value: < 2.22e-16
# Variable Name(s): after.data$state after.data$pcgsdp after.data$plit after.data$pwlit  Number(s): 1 2 4 5

# %%
mout = Match(Y=Y, Tr = Tr, X = X.all, M=1, Weight.matrix = genout)
summary(mout)
# Out:
# Estimate...  0.056408
# AI SE......  0.03582
# T-stat.....  1.5747
# p.val......  0.11532
#
# Original number of observations..............  130
# Original number of treated obs...............  99
# Matched number of observations...............  99
# Matched number of observations  (unweighted).  99

# %%
attach(before.data)
X = cbind(state, pcgsdp, pfemale, plit, pwlit, prural)
X.all = cbind(state, pcgsdp, pfemale, plit, pwlit, prural, state^2, pcgsdp^2, pfemale^2, plit^2, pwlit^2, prural^2, 
          state*pcgsdp, state*pfemale, state*plit, state*pwlit, state*prural,
          pcgsdp*pfemale, pcgsdp*plit, pcgsdp*pwlit, pcgsdp*prural,
          pfemale*plit, pfemale*pwlit, pfemale*prural, plit*pwlit, plit*prural, pwlit*prural)
Tr = treat
Y = pcr_womtot
detach(before.data)
# Out:
# The following object is masked _by_ .GlobalEnv:
#
#     X

# %%
genout = GenMatch(Tr = Tr, X = X.all, M=1, pop.size = 250,
                  max.generations = 20, wait.generations = 25)
# Out:
# Fri Dec 20 02:10:53 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#  0.000000e+00   <=  X7   <=    1.000000e+03
#  0.000000e+00   <=  X8   <=    1.000000e+03
#  0.000000e+00   <=  X9   <=    1.000000e+03
#  0.000000e+00   <=  X10  <=    1.000000e+03
#  0.000000e+00   <=  X11  <=    1.000000e+03
#  0.000000e+00   <=  X12  <=    1.000000e+03
#  0.000000e+00   <=  X13  <=    1.000000e+03
#  0.000000e+00   <=  X14  <=    1.000000e+03
#  0.000000e+00   <=  X15  <=    1.000000e+03
#  0.000000e+00   <=  X16  <=    1.000000e+03
#  0.000000e+00   <=  X17  <=    1.000000e+03
#  0.000000e+00   <=  X18  <=    1.000000e+03
#  0.000000e+00   <=  X19  <=    1.000000e+03
#  0.000000e+00   <=  X20  <=    1.000000e+03
#  0.000000e+00   <=  X21  <=    1.000000e+03
#  0.000000e+00   <=  X22  <=    1.000000e+03
#  0.000000e+00   <=  X23  <=    1.000000e+03
#  0.000000e+00   <=  X24  <=    1.000000e+03
#  0.000000e+00   <=  X25  <=    1.000000e+03
#  0.000000e+00   <=  X26  <=    1.000000e+03
#  0.000000e+00   <=  X27  <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	30
# 	(2) Uniform Mutation.................. 	31
# 	(3) Boundary Mutation................. 	31
# 	(4) Non-Uniform Mutation.............. 	31
# 	(5) Polytope Crossover................ 	31
# 	(6) Simple Crossover.................. 	32
# 	(7) Whole Non-Uniform Mutation........ 	31
# 	(8) Heuristic Crossover............... 	32
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 20
# Maximum Nonchanging Generations: 25
# Population size       : 250
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 8.852150e-08  9.431144e-08  1.169723e-07  1.230700e-07  1.722511e-07  2.268592e-07  2.733605e-07  4.413216e-07  5.728545e-07  7.872736e-07  7.889980e-07  1.040951e-06  1.902085e-06  2.142962e-06  4.886798e-06  5.022626e-06  7.041035e-06  1.035134e-05  1.051435e-05  1.187738e-05  2.872238e-05  4.222110e-05  2.123067e-02  2.123067e-02  2.123067e-02  5.035351e-02  5.035351e-02  5.035351e-02  5.035351e-02  5.035351e-02  5.035351e-02  5.035351e-02  5.035351e-02  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  2.153739e-01  2.153739e-01  2.153739e-01  3.794570e-01  4.083897e-01  4.558007e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 250, #Total UniqueCount: 250
# var 1:
# best............ 1.000000e+00
# mean............ 4.839292e+02
# variance........ 8.789802e+04
# var 2:
# best............ 1.000000e+00
# mean............ 5.047017e+02
# variance........ 8.901871e+04
# var 3:
# best............ 1.000000e+00
# mean............ 4.773979e+02
# variance........ 8.478195e+04
# var 4:
# best............ 1.000000e+00
# mean............ 5.079501e+02
# variance........ 7.991427e+04
# var 5:
# best............ 1.000000e+00
# mean............ 4.708139e+02
# variance........ 7.417535e+04
# var 6:
# best............ 1.000000e+00
# mean............ 5.047394e+02
# variance........ 7.852989e+04
# var 7:
# best............ 1.000000e+00
# mean............ 4.717069e+02
# variance........ 8.129896e+04
# var 8:
# best............ 1.000000e+00
# mean............ 4.842967e+02
# variance........ 7.853341e+04
# var 9:
# best............ 1.000000e+00
# mean............ 4.883604e+02
# variance........ 8.794131e+04
# var 10:
# best............ 1.000000e+00
# mean............ 4.889632e+02
# variance........ 8.580247e+04
# var 11:
# best............ 1.000000e+00
# mean............ 4.785841e+02
# variance........ 8.852280e+04
# var 12:
# best............ 1.000000e+00
# mean............ 4.722596e+02
# variance........ 8.122025e+04
# var 13:
# best............ 1.000000e+00
# mean............ 4.824316e+02
# variance........ 9.285211e+04
# var 14:
# best............ 1.000000e+00
# mean............ 4.805076e+02
# variance........ 8.432898e+04
# var 15:
# best............ 1.000000e+00
# mean............ 4.974878e+02
# variance........ 8.312553e+04
# var 16:
# best............ 1.000000e+00
# mean............ 5.037513e+02
# variance........ 9.068383e+04
# var 17:
# best............ 1.000000e+00
# mean............ 5.279400e+02
# variance........ 8.141444e+04
# var 18:
# best............ 1.000000e+00
# mean............ 5.176074e+02
# variance........ 8.042650e+04
# var 19:
# best............ 1.000000e+00
# mean............ 5.037986e+02
# variance........ 8.359573e+04
# var 20:
# best............ 1.000000e+00
# mean............ 5.311841e+02
# variance........ 8.250389e+04
# var 21:
# best............ 1.000000e+00
# mean............ 5.316626e+02
# variance........ 8.160667e+04
# var 22:
# best............ 1.000000e+00
# mean............ 4.648846e+02
# variance........ 9.216003e+04
# var 23:
# best............ 1.000000e+00
# mean............ 4.858488e+02
# variance........ 8.519300e+04
# var 24:
# best............ 1.000000e+00
# mean............ 4.710106e+02
# variance........ 8.537080e+04
# var 25:
# best............ 1.000000e+00
# mean............ 4.625545e+02
# variance........ 7.538858e+04
# var 26:
# best............ 1.000000e+00
# mean............ 4.988196e+02
# variance........ 8.746352e+04
# var 27:
# best............ 1.000000e+00
# mean............ 4.859103e+02
# variance........ 7.652177e+04
#
# GENERATION: 1
# Lexical Fit..... 1.472674e-04  2.454079e-04  2.666730e-04  3.463161e-04  9.222714e-04  5.462267e-03  5.997134e-03  7.544177e-03  8.986139e-03  9.378931e-03  1.066285e-02  1.165663e-02  1.366002e-02  1.536902e-02  2.208098e-02  2.947732e-02  3.022392e-02  3.451278e-02  3.650825e-02  4.959221e-02  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.797169e-01  2.051524e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.436199e-01  2.587637e-01  3.865045e-01  3.865045e-01  4.645588e-01  6.208099e-01  6.208099e-01  6.208099e-01  7.047237e-01  7.751264e-01  8.279924e-01  8.602552e-01  9.866869e-01  9.866869e-01  9.866869e-01
# #unique......... 186, #Total UniqueCount: 436
# var 1:
# best............ 1.000000e+00
# mean............ 2.912142e+02
# variance........ 1.014646e+05
# var 2:
# best............ 1.000000e+00
# mean............ 2.790383e+02
# variance........ 6.010862e+04
# var 3:
# best............ 1.000000e+00
# mean............ 1.849120e+02
# variance........ 4.607205e+04
# var 4:
# best............ 1.000000e+00
# mean............ 3.716187e+02
# variance........ 1.073990e+05
# var 5:
# best............ 1.000000e+00
# mean............ 3.075288e+02
# variance........ 6.377035e+04
# var 6:
# best............ 1.000000e+00
# mean............ 3.454930e+02
# variance........ 9.735117e+04
# var 7:
# best............ 1.000000e+00
# mean............ 4.574969e+02
# variance........ 1.190838e+05
# var 8:
# best............ 1.000000e+00
# mean............ 4.033538e+02
# variance........ 1.074401e+05
# var 9:
# best............ 1.000000e+00
# mean............ 3.244224e+02
# variance........ 7.798005e+04
# var 10:
# best............ 1.000000e+00
# mean............ 2.372493e+02
# variance........ 5.327614e+04
# var 11:
# best............ 1.000000e+00
# mean............ 3.572143e+02
# variance........ 8.172848e+04
# var 12:
# best............ 1.000000e+00
# mean............ 2.462909e+02
# variance........ 7.370984e+04
# var 13:
# best............ 1.000000e+00
# mean............ 4.482211e+02
# variance........ 1.271560e+05
# var 14:
# best............ 1.000000e+00
# mean............ 4.132707e+02
# variance........ 1.082624e+05
# var 15:
# best............ 1.000000e+00
# mean............ 3.634768e+02
# variance........ 9.558553e+04
# var 16:
# best............ 1.000000e+00
# mean............ 2.674475e+02
# variance........ 7.156546e+04
# var 17:
# best............ 1.000000e+00
# mean............ 3.924017e+02
# variance........ 9.645713e+04
# var 18:
# best............ 2.874910e+02
# mean............ 3.688741e+02
# variance........ 8.959335e+04
# var 19:
# best............ 1.000000e+00
# mean............ 4.701551e+02
# variance........ 1.329013e+05
# var 20:
# best............ 1.000000e+00
# mean............ 2.152052e+02
# variance........ 8.001829e+04
# var 21:
# best............ 1.000000e+00
# mean............ 4.360601e+02
# variance........ 1.097492e+05
# var 22:
# best............ 1.000000e+00
# mean............ 2.220380e+02
# variance........ 5.771788e+04
# var 23:
# best............ 1.000000e+00
# mean............ 3.046042e+02
# variance........ 7.717087e+04
# var 24:
# best............ 1.000000e+00
# mean............ 3.539667e+02
# variance........ 8.632431e+04
# var 25:
# best............ 1.000000e+00
# mean............ 3.327252e+02
# variance........ 7.803028e+04
# var 26:
# best............ 1.000000e+00
# mean............ 3.950429e+02
# variance........ 1.012701e+05
# var 27:
# best............ 1.000000e+00
# mean............ 2.915716e+02
# variance........ 6.481103e+04
#
# GENERATION: 2
# Lexical Fit..... 9.222714e-04  5.697130e-03  6.038056e-03  7.760398e-03  8.114183e-03  8.402059e-03  1.013470e-02  1.143532e-02  1.167228e-02  2.261563e-02  2.376890e-02  2.505539e-02  2.862368e-02  3.055950e-02  3.395137e-02  3.467166e-02  4.155643e-02  6.145499e-02  9.544523e-02  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.625819e-01  1.707019e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.306906e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  4.153450e-01  4.510848e-01  5.327974e-01  6.189543e-01  6.208099e-01  6.208099e-01  6.208099e-01  8.545810e-01  8.602552e-01  8.602552e-01  8.602552e-01  9.148046e-01  9.866869e-01
# #unique......... 165, #Total UniqueCount: 601
# var 1:
# best............ 1.000000e+00
# mean............ 1.545605e+02
# variance........ 8.083472e+04
# var 2:
# best............ 1.000000e+00
# mean............ 1.251887e+02
# variance........ 5.970599e+04
# var 3:
# best............ 1.000000e+00
# mean............ 1.139666e+02
# variance........ 4.298808e+04
# var 4:
# best............ 1.000000e+00
# mean............ 1.023268e+02
# variance........ 4.395828e+04
# var 5:
# best............ 1.000000e+00
# mean............ 1.330177e+02
# variance........ 5.884658e+04
# var 6:
# best............ 1.000000e+00
# mean............ 1.311907e+02
# variance........ 6.751584e+04
# var 7:
# best............ 1.000000e+00
# mean............ 1.307032e+02
# variance........ 6.901753e+04
# var 8:
# best............ 1.000000e+00
# mean............ 2.601434e+02
# variance........ 6.065972e+04
# var 9:
# best............ 1.000000e+00
# mean............ 1.284931e+02
# variance........ 6.200432e+04
# var 10:
# best............ 1.000000e+00
# mean............ 1.036443e+02
# variance........ 4.886267e+04
# var 11:
# best............ 1.000000e+00
# mean............ 1.212317e+02
# variance........ 5.484424e+04
# var 12:
# best............ 1.000000e+00
# mean............ 1.209315e+02
# variance........ 5.478657e+04
# var 13:
# best............ 9.836272e-01
# mean............ 1.378846e+02
# variance........ 7.083158e+04
# var 14:
# best............ 1.000000e+00
# mean............ 1.132293e+02
# variance........ 5.094531e+04
# var 15:
# best............ 1.000000e+00
# mean............ 1.370523e+02
# variance........ 6.959114e+04
# var 16:
# best............ 1.000000e+00
# mean............ 1.485901e+02
# variance........ 6.709847e+04
# var 17:
# best............ 1.000000e+00
# mean............ 1.146046e+02
# variance........ 5.633979e+04
# var 18:
# best............ 2.874910e+02
# mean............ 2.496973e+02
# variance........ 5.884607e+04
# var 19:
# best............ 2.324450e+02
# mean............ 1.530668e+02
# variance........ 8.155124e+04
# var 20:
# best............ 1.000000e+00
# mean............ 1.427773e+02
# variance........ 5.847338e+04
# var 21:
# best............ 1.000000e+00
# mean............ 1.588065e+02
# variance........ 7.157460e+04
# var 22:
# best............ 1.000000e+00
# mean............ 1.228976e+02
# variance........ 5.690176e+04
# var 23:
# best............ 1.000000e+00
# mean............ 1.343657e+02
# variance........ 6.158941e+04
# var 24:
# best............ 1.000000e+00
# mean............ 1.508903e+02
# variance........ 7.717300e+04
# var 25:
# best............ 1.000000e+00
# mean............ 1.307967e+02
# variance........ 5.739953e+04
# var 26:
# best............ 1.000000e+00
# mean............ 1.374656e+02
# variance........ 6.157573e+04
# var 27:
# best............ 1.000000e+00
# mean............ 1.372822e+02
# variance........ 5.517717e+04
#
# GENERATION: 3
# Lexical Fit..... 1.709795e-03  2.541663e-03  2.732000e-03  3.762547e-03  1.026453e-02  1.678761e-02  1.717452e-02  1.922535e-02  2.054621e-02  2.059135e-02  2.107887e-02  2.123067e-02  2.268210e-02  3.282559e-02  3.618099e-02  4.090913e-02  4.734205e-02  5.204268e-02  5.341426e-02  1.090329e-01  1.090329e-01  2.153739e-01  2.153739e-01  2.525902e-01  2.897329e-01  3.608810e-01  3.801159e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  4.759502e-01  6.113617e-01  6.156793e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.250698e-01  6.353196e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01
# #unique......... 164, #Total UniqueCount: 765
# var 1:
# best............ 1.000000e+00
# mean............ 2.342521e+01
# variance........ 8.558613e+03
# var 2:
# best............ 1.000000e+00
# mean............ 5.137789e+01
# variance........ 2.014133e+04
# var 3:
# best............ 1.000000e+00
# mean............ 2.663510e+01
# variance........ 8.197601e+03
# var 4:
# best............ 1.000000e+00
# mean............ 1.720506e+01
# variance........ 6.217481e+03
# var 5:
# best............ 1.000000e+00
# mean............ 1.819119e+01
# variance........ 4.670710e+03
# var 6:
# best............ 1.000000e+00
# mean............ 2.818755e+01
# variance........ 1.079391e+04
# var 7:
# best............ 1.000000e+00
# mean............ 3.061199e+01
# variance........ 1.253093e+04
# var 8:
# best............ 1.000000e+00
# mean............ 4.740677e+01
# variance........ 1.515296e+04
# var 9:
# best............ 1.000000e+00
# mean............ 2.475373e+01
# variance........ 1.005430e+04
# var 10:
# best............ 1.000000e+00
# mean............ 1.755864e+01
# variance........ 5.497173e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.945698e+01
# variance........ 4.206531e+03
# var 12:
# best............ 1.000000e+00
# mean............ 2.017078e+01
# variance........ 6.440598e+03
# var 13:
# best............ 9.836272e-01
# mean............ 1.875419e+01
# variance........ 6.221912e+03
# var 14:
# best............ 1.000000e+00
# mean............ 4.221817e+01
# variance........ 1.989708e+04
# var 15:
# best............ 1.000000e+00
# mean............ 1.937027e+01
# variance........ 3.297685e+03
# var 16:
# best............ 1.000000e+00
# mean............ 2.578855e+01
# variance........ 8.356534e+03
# var 17:
# best............ 1.000000e+00
# mean............ 2.174501e+01
# variance........ 7.679729e+03
# var 18:
# best............ 1.289946e+01
# mean............ 2.789130e+02
# variance........ 1.105258e+04
# var 19:
# best............ 2.324450e+02
# mean............ 2.816323e+02
# variance........ 8.762057e+04
# var 20:
# best............ 1.000000e+00
# mean............ 1.925623e+01
# variance........ 6.239582e+03
# var 21:
# best............ 1.000000e+00
# mean............ 2.930086e+01
# variance........ 1.014826e+04
# var 22:
# best............ 1.000000e+00
# mean............ 2.132162e+01
# variance........ 6.828003e+03
# var 23:
# best............ 1.000000e+00
# mean............ 2.502178e+01
# variance........ 9.186417e+03
# var 24:
# best............ 1.000000e+00
# mean............ 2.095238e+01
# variance........ 9.122554e+03
# var 25:
# best............ 1.000000e+00
# mean............ 2.619712e+01
# variance........ 8.423284e+03
# var 26:
# best............ 1.000000e+00
# mean............ 2.690132e+01
# variance........ 9.421319e+03
# var 27:
# best............ 1.000000e+00
# mean............ 2.056274e+01
# variance........ 8.844439e+03
#
# GENERATION: 4
# Lexical Fit..... 1.729637e-03  2.651534e-03  9.692175e-03  1.135052e-02  1.547760e-02  1.568929e-02  2.629095e-02  4.123747e-02  5.035351e-02  5.035351e-02  5.035351e-02  5.035351e-02  5.035351e-02  8.904418e-02  9.190156e-02  1.001523e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.094194e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.153739e-01  2.184502e-01  3.041643e-01  3.060717e-01  3.857431e-01  4.017747e-01  4.526554e-01  5.592686e-01  6.136161e-01  6.475968e-01  7.112923e-01  7.142126e-01  7.535186e-01  7.644964e-01  8.934268e-01  9.299064e-01  9.999894e-01  9.999894e-01
# #unique......... 177, #Total UniqueCount: 942
# var 1:
# best............ 2.411335e+02
# mean............ 7.652374e+01
# variance........ 1.949946e+04
# var 2:
# best............ 1.000000e+00
# mean............ 9.752525e+00
# variance........ 9.347740e+02
# var 3:
# best............ 1.000000e+00
# mean............ 1.713386e+01
# variance........ 5.460936e+03
# var 4:
# best............ 1.000000e+00
# mean............ 2.590092e+01
# variance........ 1.164610e+04
# var 5:
# best............ 1.000000e+00
# mean............ 1.346384e+01
# variance........ 3.538502e+03
# var 6:
# best............ 1.000000e+00
# mean............ 3.396856e+01
# variance........ 5.680898e+03
# var 7:
# best............ 8.650738e-01
# mean............ 1.521707e+01
# variance........ 5.692045e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.645552e+01
# variance........ 6.978784e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.374524e+01
# variance........ 5.234921e+03
# var 10:
# best............ 1.000000e+00
# mean............ 1.055574e+01
# variance........ 1.280310e+03
# var 11:
# best............ 9.270753e-01
# mean............ 1.138181e+01
# variance........ 1.375677e+03
# var 12:
# best............ 2.902295e+01
# mean............ 2.814254e+01
# variance........ 1.513049e+04
# var 13:
# best............ 1.000000e+00
# mean............ 1.571637e+01
# variance........ 3.833345e+03
# var 14:
# best............ 1.483877e+02
# mean............ 1.932210e+01
# variance........ 6.474570e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.302464e+01
# variance........ 2.024762e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.948113e+01
# variance........ 6.034565e+03
# var 17:
# best............ 2.380357e+02
# mean............ 1.898295e+01
# variance........ 5.444637e+03
# var 18:
# best............ 2.874910e+02
# mean............ 1.955912e+02
# variance........ 1.628976e+04
# var 19:
# best............ 8.604837e+02
# mean............ 2.920671e+02
# variance........ 1.985697e+04
# var 20:
# best............ 3.553949e+01
# mean............ 1.961999e+01
# variance........ 6.178262e+03
# var 21:
# best............ 1.000000e+00
# mean............ 8.593699e+00
# variance........ 1.152693e+03
# var 22:
# best............ 1.000000e+00
# mean............ 9.355746e+00
# variance........ 2.081679e+03
# var 23:
# best............ 8.841198e-01
# mean............ 8.453250e+00
# variance........ 2.258388e+03
# var 24:
# best............ 9.860874e-01
# mean............ 1.442436e+01
# variance........ 3.781923e+03
# var 25:
# best............ 9.837251e-01
# mean............ 1.223628e+01
# variance........ 1.973406e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.175754e+01
# variance........ 3.791386e+03
# var 27:
# best............ 8.693026e-01
# mean............ 1.147707e+01
# variance........ 2.101548e+03
#
# GENERATION: 5
# Lexical Fit..... 2.873262e-03  5.768099e-03  6.836536e-03  7.489620e-03  8.173542e-03  1.643942e-02  2.221674e-02  2.296230e-02  2.625326e-02  2.778323e-02  2.965067e-02  3.309936e-02  3.377796e-02  4.165186e-02  4.344806e-02  4.579369e-02  4.748555e-02  4.797744e-02  4.918441e-02  5.128267e-02  5.776302e-02  7.108655e-02  8.495556e-02  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.090329e-01  1.128065e-01  2.057292e-01  2.153739e-01  2.332271e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.918115e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  9.741148e-01  9.774772e-01  9.866869e-01
# #unique......... 176, #Total UniqueCount: 1118
# var 1:
# best............ 1.000000e+00
# mean............ 1.171855e+02
# variance........ 1.763805e+04
# var 2:
# best............ 1.000000e+00
# mean............ 1.513121e+01
# variance........ 4.326325e+03
# var 3:
# best............ 1.000000e+00
# mean............ 2.064168e+01
# variance........ 7.010925e+03
# var 4:
# best............ 1.000000e+00
# mean............ 2.372922e+01
# variance........ 1.188752e+04
# var 5:
# best............ 1.000000e+00
# mean............ 1.073340e+01
# variance........ 1.878067e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.985520e+01
# variance........ 6.832912e+03
# var 7:
# best............ 1.000000e+00
# mean............ 2.365181e+01
# variance........ 1.129247e+04
# var 8:
# best............ 1.000000e+00
# mean............ 1.652128e+01
# variance........ 5.026737e+03
# var 9:
# best............ 1.000000e+00
# mean............ 2.229574e+01
# variance........ 1.005606e+04
# var 10:
# best............ 1.000000e+00
# mean............ 1.531900e+01
# variance........ 7.008439e+03
# var 11:
# best............ 1.000000e+00
# mean............ 8.854859e+00
# variance........ 1.529369e+03
# var 12:
# best............ 1.000000e+00
# mean............ 3.024009e+01
# variance........ 5.455618e+03
# var 13:
# best............ 9.836272e-01
# mean............ 2.025974e+01
# variance........ 1.179051e+04
# var 14:
# best............ 1.000000e+00
# mean............ 8.053263e+01
# variance........ 9.959315e+03
# var 15:
# best............ 1.000000e+00
# mean............ 2.009500e+01
# variance........ 9.557007e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.728252e+01
# variance........ 6.268023e+03
# var 17:
# best............ 1.000000e+00
# mean............ 1.198476e+02
# variance........ 1.749915e+04
# var 18:
# best............ 1.078560e+01
# mean............ 1.561391e+02
# variance........ 2.086258e+04
# var 19:
# best............ 2.324450e+02
# mean............ 5.043674e+02
# variance........ 8.789693e+04
# var 20:
# best............ 7.985755e+02
# mean............ 3.568387e+01
# variance........ 9.100872e+03
# var 21:
# best............ 1.000000e+00
# mean............ 2.462854e+01
# variance........ 1.225069e+04
# var 22:
# best............ 1.000000e+00
# mean............ 1.486095e+01
# variance........ 5.144013e+03
# var 23:
# best............ 1.000000e+00
# mean............ 1.589729e+01
# variance........ 5.565108e+03
# var 24:
# best............ 1.000000e+00
# mean............ 1.463918e+01
# variance........ 4.187622e+03
# var 25:
# best............ 1.000000e+00
# mean............ 2.320776e+01
# variance........ 9.865785e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.678141e+01
# variance........ 6.585613e+03
# var 27:
# best............ 1.000175e+00
# mean............ 1.630550e+01
# variance........ 5.976190e+03
#
# GENERATION: 6
# Lexical Fit..... 4.742366e-03  6.979233e-03  7.023711e-03  1.194153e-02  2.123067e-02  3.932777e-02  4.443748e-02  6.231106e-02  6.330277e-02  6.914649e-02  7.238351e-02  2.153739e-01  2.153739e-01  2.551658e-01  3.837582e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  6.060588e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.352067e-01  6.393356e-01  6.436221e-01  6.552569e-01  6.762200e-01  6.958991e-01  7.208453e-01  8.296182e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.790614e-01  9.070026e-01  9.333093e-01  9.416673e-01  9.811039e-01  9.979057e-01
# #unique......... 176, #Total UniqueCount: 1294
# var 1:
# best............ 5.005720e+01
# mean............ 8.736026e+01
# variance........ 1.670695e+04
# var 2:
# best............ 1.000000e+00
# mean............ 9.569558e+00
# variance........ 2.591978e+03
# var 3:
# best............ 1.000000e+00
# mean............ 2.267669e+01
# variance........ 9.705834e+03
# var 4:
# best............ 1.000000e+00
# mean............ 1.364894e+01
# variance........ 4.950411e+03
# var 5:
# best............ 1.000000e+00
# mean............ 2.072478e+01
# variance........ 1.037881e+04
# var 6:
# best............ 2.448267e-01
# mean............ 1.186767e+01
# variance........ 4.130079e+03
# var 7:
# best............ 9.724358e-01
# mean............ 1.490270e+01
# variance........ 5.200029e+03
# var 8:
# best............ 1.000000e+00
# mean............ 2.086932e+01
# variance........ 8.161203e+03
# var 9:
# best............ 1.000000e+00
# mean............ 2.516948e+01
# variance........ 1.184221e+04
# var 10:
# best............ 1.000000e+00
# mean............ 1.169860e+01
# variance........ 3.281933e+03
# var 11:
# best............ 9.851021e-01
# mean............ 1.808124e+01
# variance........ 7.644685e+03
# var 12:
# best............ 6.724847e+00
# mean............ 1.834851e+01
# variance........ 1.796366e+03
# var 13:
# best............ 9.869720e-01
# mean............ 1.850241e+01
# variance........ 5.131108e+03
# var 14:
# best............ 3.111003e+01
# mean............ 5.999229e+01
# variance........ 8.007359e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.930863e+01
# variance........ 7.379233e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.698052e+01
# variance........ 6.423336e+03
# var 17:
# best............ 4.942434e+01
# mean............ 9.173374e+01
# variance........ 1.859695e+04
# var 18:
# best............ 6.731552e+01
# mean............ 1.107858e+02
# variance........ 2.004127e+04
# var 19:
# best............ 3.607478e+02
# mean............ 4.265047e+02
# variance........ 8.034642e+04
# var 20:
# best............ 2.888963e+02
# mean............ 3.822513e+02
# variance........ 1.330300e+05
# var 21:
# best............ 9.737856e+01
# mean............ 5.977451e+01
# variance........ 1.174350e+04
# var 22:
# best............ 1.000000e+00
# mean............ 1.417278e+01
# variance........ 3.282821e+03
# var 23:
# best............ 9.763267e-01
# mean............ 1.475664e+01
# variance........ 3.840402e+03
# var 24:
# best............ 9.971578e-01
# mean............ 1.812483e+01
# variance........ 7.121478e+03
# var 25:
# best............ 9.966676e-01
# mean............ 1.533633e+01
# variance........ 5.601799e+03
# var 26:
# best............ 1.000000e+00
# mean............ 2.489039e+01
# variance........ 9.861719e+03
# var 27:
# best............ 9.734388e-01
# mean............ 1.474080e+01
# variance........ 5.292391e+03
#
# GENERATION: 7
# Lexical Fit..... 8.173542e-03  1.138392e-02  2.143584e-02  2.897960e-02  2.903740e-02  3.054782e-02  3.204402e-02  4.225482e-02  4.292084e-02  4.666967e-02  4.815872e-02  5.035351e-02  6.467023e-02  6.851366e-02  7.091300e-02  7.427145e-02  7.699271e-02  1.158252e-01  1.267383e-01  1.414123e-01  1.540609e-01  2.153739e-01  2.153739e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.956265e-01  4.265287e-01  5.089422e-01  5.671959e-01  6.059274e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  7.079507e-01  7.668914e-01  7.787294e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  9.866869e-01
# #unique......... 194, #Total UniqueCount: 1488
# var 1:
# best............ 1.000000e+00
# mean............ 3.634240e+01
# variance........ 3.108153e+03
# var 2:
# best............ 1.000000e+00
# mean............ 8.159565e+00
# variance........ 3.642177e+03
# var 3:
# best............ 1.000000e+00
# mean............ 2.208730e+01
# variance........ 1.004187e+04
# var 4:
# best............ 1.000000e+00
# mean............ 1.145974e+01
# variance........ 3.910515e+03
# var 5:
# best............ 1.000000e+00
# mean............ 1.089117e+01
# variance........ 3.926171e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.084245e+01
# variance........ 3.633083e+03
# var 7:
# best............ 1.000000e+00
# mean............ 1.110334e+01
# variance........ 3.728135e+03
# var 8:
# best............ 1.000000e+00
# mean............ 2.333865e+01
# variance........ 8.864048e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.230093e+01
# variance........ 4.638404e+03
# var 10:
# best............ 1.000000e+00
# mean............ 6.524073e+00
# variance........ 1.193351e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.390433e+01
# variance........ 4.847621e+03
# var 12:
# best............ 1.000000e+00
# mean............ 1.259560e+01
# variance........ 4.331275e+03
# var 13:
# best............ 9.836272e-01
# mean............ 1.563158e+01
# variance........ 7.474958e+03
# var 14:
# best............ 1.000000e+00
# mean............ 2.307488e+01
# variance........ 3.088409e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.263152e+01
# variance........ 4.061912e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.296543e+01
# variance........ 5.226403e+03
# var 17:
# best............ 1.000000e+00
# mean............ 3.654940e+01
# variance........ 4.583976e+03
# var 18:
# best............ 1.078560e+01
# mean............ 4.949726e+01
# variance........ 3.793279e+03
# var 19:
# best............ 3.479176e+02
# mean............ 3.012344e+02
# variance........ 6.179246e+03
# var 20:
# best............ 3.398642e+02
# mean............ 4.944824e+02
# variance........ 5.966981e+04
# var 21:
# best............ 8.774070e+01
# mean............ 6.873471e+01
# variance........ 4.043187e+03
# var 22:
# best............ 1.000000e+00
# mean............ 6.791363e+00
# variance........ 1.194552e+03
# var 23:
# best............ 9.786940e-01
# mean............ 1.438097e+01
# variance........ 5.507827e+03
# var 24:
# best............ 9.974420e-01
# mean............ 9.281273e+00
# variance........ 2.272018e+03
# var 25:
# best............ 9.970008e-01
# mean............ 1.254110e+01
# variance........ 5.085670e+03
# var 26:
# best............ 1.000000e+00
# mean............ 9.279010e+00
# variance........ 2.151307e+03
# var 27:
# best............ 9.761124e-01
# mean............ 1.752377e+01
# variance........ 7.283995e+03
#
# GENERATION: 8
# Lexical Fit..... 8.173542e-03  1.571109e-02  1.689868e-02  1.763097e-02  2.413828e-02  2.474780e-02  2.490944e-02  2.788054e-02  3.289661e-02  3.626723e-02  4.871586e-02  5.035351e-02  5.179544e-02  5.233859e-02  5.280086e-02  5.589602e-02  6.075748e-02  8.328083e-02  9.371932e-02  1.071605e-01  2.040253e-01  2.153739e-01  2.153739e-01  2.401540e-01  3.068943e-01  3.167225e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  4.054166e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.376102e-01  8.012484e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.885860e-01  8.992046e-01  9.866869e-01
# #unique......... 193, #Total UniqueCount: 1681
# var 1:
# best............ 1.000000e+00
# mean............ 2.133108e+01
# variance........ 4.465192e+03
# var 2:
# best............ 1.000000e+00
# mean............ 1.128200e+01
# variance........ 3.519079e+03
# var 3:
# best............ 1.000000e+00
# mean............ 9.772331e+00
# variance........ 3.227838e+03
# var 4:
# best............ 1.000000e+00
# mean............ 7.043751e+00
# variance........ 1.984931e+03
# var 5:
# best............ 1.000000e+00
# mean............ 1.483976e+01
# variance........ 6.067695e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.499721e+01
# variance........ 8.111853e+03
# var 7:
# best............ 1.000000e+00
# mean............ 1.286392e+01
# variance........ 4.882035e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.230834e+01
# variance........ 5.154945e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.335568e+01
# variance........ 5.016310e+03
# var 10:
# best............ 1.000000e+00
# mean............ 1.340506e+01
# variance........ 5.277040e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.702243e+01
# variance........ 6.964994e+03
# var 12:
# best............ 1.000000e+00
# mean............ 1.852180e+01
# variance........ 6.160440e+03
# var 13:
# best............ 9.836272e-01
# mean............ 9.282076e+00
# variance........ 3.815377e+03
# var 14:
# best............ 1.000000e+00
# mean............ 1.911986e+01
# variance........ 2.285719e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.328856e+01
# variance........ 7.151224e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.363617e+01
# variance........ 5.705687e+03
# var 17:
# best............ 1.000000e+00
# mean............ 3.246511e+01
# variance........ 3.795114e+03
# var 18:
# best............ 1.078560e+01
# mean............ 4.665964e+01
# variance........ 5.047970e+03
# var 19:
# best............ 3.440659e+02
# mean............ 3.355548e+02
# variance........ 4.818373e+03
# var 20:
# best............ 3.757568e+02
# mean............ 3.881339e+02
# variance........ 2.398663e+04
# var 21:
# best............ 7.908160e+01
# mean............ 8.885108e+01
# variance........ 3.351522e+03
# var 22:
# best............ 1.000000e+00
# mean............ 1.837048e+01
# variance........ 9.077028e+03
# var 23:
# best............ 9.794047e-01
# mean............ 1.731260e+01
# variance........ 8.668981e+03
# var 24:
# best............ 9.975273e-01
# mean............ 1.137830e+01
# variance........ 2.253245e+03
# var 25:
# best............ 9.971006e-01
# mean............ 1.627777e+01
# variance........ 8.249275e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.468068e+01
# variance........ 5.542688e+03
# var 27:
# best............ 9.769150e-01
# mean............ 2.400538e+01
# variance........ 1.383926e+04
#
# GENERATION: 9
# Lexical Fit..... 8.173542e-03  1.571109e-02  1.689868e-02  1.763097e-02  2.413828e-02  2.474780e-02  2.490944e-02  2.788054e-02  3.289661e-02  3.626723e-02  4.871586e-02  5.035351e-02  5.179544e-02  5.233859e-02  5.280086e-02  5.589602e-02  6.075748e-02  8.328083e-02  9.371932e-02  1.071605e-01  2.040253e-01  2.153739e-01  2.153739e-01  2.401540e-01  3.068943e-01  3.167225e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  4.054166e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.376102e-01  8.012484e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.885860e-01  8.992046e-01  9.866869e-01
# #unique......... 185, #Total UniqueCount: 1866
# var 1:
# best............ 1.000000e+00
# mean............ 8.575060e+00
# variance........ 3.132500e+03
# var 2:
# best............ 1.000000e+00
# mean............ 9.293005e+00
# variance........ 2.655164e+03
# var 3:
# best............ 1.000000e+00
# mean............ 1.173884e+01
# variance........ 4.052131e+03
# var 4:
# best............ 1.000000e+00
# mean............ 1.641258e+01
# variance........ 9.053781e+03
# var 5:
# best............ 1.000000e+00
# mean............ 9.057358e+00
# variance........ 2.868584e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.939653e+01
# variance........ 1.075698e+04
# var 7:
# best............ 1.000000e+00
# mean............ 1.353690e+01
# variance........ 5.029493e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.365842e+01
# variance........ 6.163440e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.674592e+01
# variance........ 8.261638e+03
# var 10:
# best............ 1.000000e+00
# mean............ 1.094700e+01
# variance........ 4.481530e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.553840e+01
# variance........ 6.249103e+03
# var 12:
# best............ 1.000000e+00
# mean............ 5.641813e+00
# variance........ 1.644511e+03
# var 13:
# best............ 9.836272e-01
# mean............ 2.038955e+01
# variance........ 1.100496e+04
# var 14:
# best............ 1.000000e+00
# mean............ 1.536221e+01
# variance........ 5.518252e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.241577e+01
# variance........ 6.554195e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.108549e+01
# variance........ 3.333869e+03
# var 17:
# best............ 1.000000e+00
# mean............ 1.429655e+01
# variance........ 4.088617e+03
# var 18:
# best............ 1.078560e+01
# mean............ 2.728048e+01
# variance........ 4.194717e+03
# var 19:
# best............ 3.440659e+02
# mean............ 3.547165e+02
# variance........ 3.457597e+03
# var 20:
# best............ 3.757568e+02
# mean............ 3.623523e+02
# variance........ 4.264319e+03
# var 21:
# best............ 7.908160e+01
# mean............ 9.423124e+01
# variance........ 3.321939e+03
# var 22:
# best............ 1.000000e+00
# mean............ 1.664814e+01
# variance........ 7.489712e+03
# var 23:
# best............ 9.794047e-01
# mean............ 1.275281e+01
# variance........ 3.636301e+03
# var 24:
# best............ 9.975273e-01
# mean............ 1.548915e+01
# variance........ 6.310090e+03
# var 25:
# best............ 9.971006e-01
# mean............ 1.456590e+01
# variance........ 6.123121e+03
# var 26:
# best............ 1.000000e+00
# mean............ 2.345997e+01
# variance........ 1.068200e+04
# var 27:
# best............ 9.769150e-01
# mean............ 7.478963e+00
# variance........ 1.611192e+03
#
# GENERATION: 10
# Lexical Fit..... 1.050134e-02  1.496128e-02  1.661272e-02  2.118733e-02  2.123067e-02  2.380579e-02  2.528071e-02  2.723253e-02  2.901373e-02  3.076552e-02  3.530531e-02  4.160386e-02  4.229593e-02  5.016111e-02  7.971678e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.622273e-01  1.823438e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.333670e-01  2.518243e-01  3.839081e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.947190e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  7.216449e-01  7.685062e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.687941e-01  9.856500e-01  9.895225e-01
# #unique......... 185, #Total UniqueCount: 2051
# var 1:
# best............ 9.999782e-01
# mean............ 1.123739e+01
# variance........ 5.928062e+03
# var 2:
# best............ 1.000000e+00
# mean............ 9.312666e+00
# variance........ 3.255002e+03
# var 3:
# best............ 1.000000e+00
# mean............ 4.724294e+00
# variance........ 1.100873e+03
# var 4:
# best............ 3.261260e+00
# mean............ 7.215778e+00
# variance........ 1.518018e+03
# var 5:
# best............ 1.000000e+00
# mean............ 7.944182e+00
# variance........ 2.578047e+03
# var 6:
# best............ 4.988389e-02
# mean............ 1.116767e+00
# variance........ 7.733048e+01
# var 7:
# best............ 1.000000e+00
# mean............ 6.942293e+00
# variance........ 2.459902e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.308476e+01
# variance........ 7.578900e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.196412e+01
# variance........ 3.985628e+03
# var 10:
# best............ 3.355565e+00
# mean............ 9.571732e+00
# variance........ 3.129836e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.448747e+01
# variance........ 6.089289e+03
# var 12:
# best............ 1.000000e+00
# mean............ 9.873327e+00
# variance........ 2.570502e+03
# var 13:
# best............ 9.836272e-01
# mean............ 1.790162e+01
# variance........ 1.056989e+04
# var 14:
# best............ 1.000000e+00
# mean............ 8.616305e+00
# variance........ 3.409755e+03
# var 15:
# best............ 3.521210e+00
# mean............ 1.090576e+01
# variance........ 4.446017e+03
# var 16:
# best............ 1.142732e+00
# mean............ 9.832911e+00
# variance........ 2.908255e+03
# var 17:
# best............ 1.479893e+00
# mean............ 1.503336e+01
# variance........ 6.255479e+03
# var 18:
# best............ 1.660956e+01
# mean............ 1.909419e+01
# variance........ 3.840173e+03
# var 19:
# best............ 3.394230e+02
# mean............ 3.456973e+02
# variance........ 2.460578e+03
# var 20:
# best............ 4.071809e+02
# mean............ 3.827216e+02
# variance........ 2.692996e+03
# var 21:
# best............ 7.150052e+01
# mean............ 8.358803e+01
# variance........ 1.965873e+03
# var 22:
# best............ 1.000000e+00
# mean............ 1.149778e+01
# variance........ 4.103690e+03
# var 23:
# best............ 9.800269e-01
# mean............ 1.325830e+01
# variance........ 5.289963e+03
# var 24:
# best............ 9.976020e-01
# mean............ 8.985181e+00
# variance........ 3.839606e+03
# var 25:
# best............ 9.971880e-01
# mean............ 7.986582e+00
# variance........ 2.376307e+03
# var 26:
# best............ 1.000000e+00
# mean............ 6.762042e+00
# variance........ 1.699071e+03
# var 27:
# best............ 9.776177e-01
# mean............ 1.238933e+01
# variance........ 5.626810e+03
#
# GENERATION: 11
# Lexical Fit..... 1.050134e-02  1.496128e-02  1.661272e-02  2.118733e-02  2.123067e-02  2.380579e-02  2.528071e-02  2.723253e-02  2.901373e-02  3.076552e-02  3.530531e-02  4.160386e-02  4.229593e-02  5.016111e-02  7.971678e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.622273e-01  1.823438e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.333670e-01  2.518243e-01  3.839081e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.947190e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  7.216449e-01  7.685062e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.687941e-01  9.856500e-01  9.895225e-01
# #unique......... 187, #Total UniqueCount: 2238
# var 1:
# best............ 9.999782e-01
# mean............ 1.759648e+01
# variance........ 7.888574e+03
# var 2:
# best............ 1.000000e+00
# mean............ 1.975821e+01
# variance........ 1.083059e+04
# var 3:
# best............ 1.000000e+00
# mean............ 1.234681e+01
# variance........ 5.137063e+03
# var 4:
# best............ 3.261260e+00
# mean............ 1.555791e+01
# variance........ 5.495296e+03
# var 5:
# best............ 1.000000e+00
# mean............ 8.067617e+00
# variance........ 3.305028e+03
# var 6:
# best............ 4.988389e-02
# mean............ 7.599939e+00
# variance........ 2.404205e+03
# var 7:
# best............ 1.000000e+00
# mean............ 1.006928e+01
# variance........ 3.463233e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.812890e+01
# variance........ 9.817401e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.434302e+01
# variance........ 6.754091e+03
# var 10:
# best............ 3.355565e+00
# mean............ 1.179489e+01
# variance........ 5.334192e+03
# var 11:
# best............ 1.000000e+00
# mean............ 9.490500e+00
# variance........ 4.118331e+03
# var 12:
# best............ 1.000000e+00
# mean............ 5.579104e+00
# variance........ 1.377804e+03
# var 13:
# best............ 9.836272e-01
# mean............ 1.826252e+01
# variance........ 9.674083e+03
# var 14:
# best............ 1.000000e+00
# mean............ 1.639911e+01
# variance........ 7.591778e+03
# var 15:
# best............ 3.521210e+00
# mean............ 9.877892e+00
# variance........ 4.515442e+03
# var 16:
# best............ 1.142732e+00
# mean............ 1.074711e+01
# variance........ 4.628160e+03
# var 17:
# best............ 1.479893e+00
# mean............ 1.348301e+01
# variance........ 5.414906e+03
# var 18:
# best............ 1.660956e+01
# mean............ 2.446597e+01
# variance........ 5.313976e+03
# var 19:
# best............ 3.394230e+02
# mean............ 3.418196e+02
# variance........ 2.305259e+02
# var 20:
# best............ 4.071809e+02
# mean............ 3.953930e+02
# variance........ 2.437188e+03
# var 21:
# best............ 7.150052e+01
# mean............ 7.857268e+01
# variance........ 1.093091e+03
# var 22:
# best............ 1.000000e+00
# mean............ 1.494500e+01
# variance........ 8.490605e+03
# var 23:
# best............ 9.800269e-01
# mean............ 1.652112e+01
# variance........ 7.689633e+03
# var 24:
# best............ 9.976020e-01
# mean............ 7.510787e+00
# variance........ 2.525097e+03
# var 25:
# best............ 9.971880e-01
# mean............ 6.976475e+00
# variance........ 1.486082e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.550154e+01
# variance........ 8.260636e+03
# var 27:
# best............ 9.776177e-01
# mean............ 1.809822e+01
# variance........ 8.798616e+03
#
# GENERATION: 12
# Lexical Fit..... 1.050134e-02  1.496128e-02  1.661272e-02  2.118733e-02  2.123067e-02  2.380579e-02  2.528071e-02  2.723253e-02  2.901373e-02  3.076552e-02  3.530531e-02  4.160386e-02  4.229593e-02  5.016111e-02  7.971678e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.622273e-01  1.823438e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.333670e-01  2.518243e-01  3.839081e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.865045e-01  3.947190e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  7.216449e-01  7.685062e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.687941e-01  9.856500e-01  9.895225e-01
# #unique......... 189, #Total UniqueCount: 2427
# var 1:
# best............ 9.999782e-01
# mean............ 8.403509e+00
# variance........ 1.596435e+03
# var 2:
# best............ 1.000000e+00
# mean............ 2.108876e+01
# variance........ 1.101293e+04
# var 3:
# best............ 1.000000e+00
# mean............ 1.592235e+01
# variance........ 7.040146e+03
# var 4:
# best............ 3.261260e+00
# mean............ 1.357669e+01
# variance........ 5.989778e+03
# var 5:
# best............ 1.000000e+00
# mean............ 1.041876e+01
# variance........ 3.525521e+03
# var 6:
# best............ 4.988389e-02
# mean............ 7.306898e+00
# variance........ 2.653140e+03
# var 7:
# best............ 1.000000e+00
# mean............ 1.377322e+01
# variance........ 6.618239e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.043129e+01
# variance........ 3.380121e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.140886e+01
# variance........ 3.594370e+03
# var 10:
# best............ 3.355565e+00
# mean............ 1.640029e+01
# variance........ 4.548331e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.708049e+01
# variance........ 8.981290e+03
# var 12:
# best............ 1.000000e+00
# mean............ 1.980242e+01
# variance........ 1.013550e+04
# var 13:
# best............ 9.836272e-01
# mean............ 1.046943e+01
# variance........ 4.004468e+03
# var 14:
# best............ 1.000000e+00
# mean............ 6.487326e+00
# variance........ 1.310681e+03
# var 15:
# best............ 3.521210e+00
# mean............ 1.959149e+01
# variance........ 8.365662e+03
# var 16:
# best............ 1.142732e+00
# mean............ 2.425375e+01
# variance........ 1.168961e+04
# var 17:
# best............ 1.479893e+00
# mean............ 1.221907e+01
# variance........ 5.458830e+03
# var 18:
# best............ 1.660956e+01
# mean............ 2.402792e+01
# variance........ 2.949885e+03
# var 19:
# best............ 3.394230e+02
# mean............ 3.457953e+02
# variance........ 3.436623e+03
# var 20:
# best............ 4.071809e+02
# mean............ 4.026710e+02
# variance........ 3.229498e+03
# var 21:
# best............ 7.150052e+01
# mean............ 8.488016e+01
# variance........ 4.898799e+03
# var 22:
# best............ 1.000000e+00
# mean............ 7.515209e+00
# variance........ 2.524044e+03
# var 23:
# best............ 9.800269e-01
# mean............ 9.330628e+00
# variance........ 3.580986e+03
# var 24:
# best............ 9.976020e-01
# mean............ 1.662379e+01
# variance........ 1.069728e+04
# var 25:
# best............ 9.971880e-01
# mean............ 9.395639e+00
# variance........ 3.311726e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.442407e+01
# variance........ 6.031454e+03
# var 27:
# best............ 9.776177e-01
# mean............ 1.339630e+01
# variance........ 5.831184e+03
#
# GENERATION: 13
# ...
# mean............ 1.453632e+01
# variance........ 5.849370e+03
# var 24:
# best............ 9.975273e-01
# mean............ 8.876245e+00
# variance........ 2.543827e+03
# var 25:
# best............ 9.971006e-01
# mean............ 2.034928e+01
# variance........ 9.867820e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.667666e+01
# variance........ 7.391365e+03
# var 27:
# best............ 9.769150e-01
# mean............ 1.736541e+01
# variance........ 9.528265e+03
#
# GENERATION: 38
# Lexical Fit..... 1.958935e-02  2.123067e-02  2.352312e-02  2.631478e-02  2.708721e-02  2.715371e-02  2.893184e-02  3.348312e-02  3.544244e-02  3.697041e-02  4.135081e-02  4.539809e-02  4.690383e-02  5.596982e-02  7.053309e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.642511e-01  1.744297e-01  1.825200e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.382400e-01  3.069322e-01  3.368713e-01  3.865045e-01  3.865045e-01  3.865045e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  8.240263e-01  8.278134e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  9.870740e-01  9.883303e-01  9.895103e-01
# #unique......... 174, #Total UniqueCount: 6987
# var 1:
# best............ 1.000000e+00
# mean............ 2.786158e+01
# variance........ 1.147237e+04
# var 2:
# best............ 1.000000e+00
# mean............ 1.036823e+01
# variance........ 4.251858e+03
# var 3:
# best............ 1.000000e+00
# mean............ 1.085883e+01
# variance........ 6.044134e+03
# var 4:
# best............ 1.487704e+00
# mean............ 1.765694e+01
# variance........ 7.226686e+03
# var 5:
# best............ 1.000000e+00
# mean............ 9.566846e+00
# variance........ 3.114622e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.265263e+01
# variance........ 5.289428e+03
# var 7:
# best............ 9.887699e-01
# mean............ 1.272116e+01
# variance........ 4.656310e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.260491e+01
# variance........ 6.282047e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.361426e+01
# variance........ 6.004013e+03
# var 10:
# best............ 1.000000e+00
# mean............ 1.892282e+01
# variance........ 1.060517e+04
# var 11:
# best............ 1.000000e+00
# mean............ 1.801506e+01
# variance........ 8.595910e+03
# var 12:
# best............ 1.000000e+00
# mean............ 2.133448e+01
# variance........ 1.081337e+04
# var 13:
# best............ 9.836272e-01
# mean............ 2.550446e+01
# variance........ 1.220944e+04
# var 14:
# best............ 5.735817e-01
# mean............ 1.398331e+01
# variance........ 5.808498e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.891700e+01
# variance........ 9.895894e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.147124e+01
# variance........ 4.293814e+03
# var 17:
# best............ 2.683245e+00
# mean............ 1.647907e+01
# variance........ 6.015368e+03
# var 18:
# best............ 1.078560e+01
# mean............ 3.519102e+01
# variance........ 1.280669e+04
# var 19:
# best............ 3.440659e+02
# mean............ 3.457051e+02
# variance........ 2.152933e+03
# var 20:
# best............ 3.757568e+02
# mean............ 3.837577e+02
# variance........ 2.639189e+03
# var 21:
# best............ 1.299145e+01
# mean............ 2.642434e+01
# variance........ 8.662366e+03
# var 22:
# best............ 1.000000e+00
# mean............ 1.615480e+01
# variance........ 6.174985e+03
# var 23:
# best............ 9.794047e-01
# mean............ 2.064617e+01
# variance........ 1.172229e+04
# var 24:
# best............ 9.975273e-01
# mean............ 8.724227e+00
# variance........ 3.103981e+03
# var 25:
# best............ 9.971006e-01
# mean............ 1.080016e+01
# variance........ 2.653694e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.416107e+01
# variance........ 6.871980e+03
# var 27:
# best............ 9.769150e-01
# mean............ 1.924024e+01
# variance........ 7.856794e+03
#
# GENERATION: 39
# Lexical Fit..... 1.958935e-02  2.123067e-02  2.352312e-02  2.631478e-02  2.708721e-02  2.715371e-02  2.893184e-02  3.348312e-02  3.544244e-02  3.697041e-02  4.135081e-02  4.539809e-02  4.690383e-02  5.596982e-02  7.053309e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.642511e-01  1.744297e-01  1.825200e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.382400e-01  3.069322e-01  3.368713e-01  3.865045e-01  3.865045e-01  3.865045e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  8.240263e-01  8.278134e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  9.870740e-01  9.883303e-01  9.895103e-01
# #unique......... 167, #Total UniqueCount: 7154
# var 1:
# best............ 1.000000e+00
# mean............ 1.583802e+01
# variance........ 6.823829e+03
# var 2:
# best............ 1.000000e+00
# mean............ 1.207859e+01
# variance........ 5.300131e+03
# var 3:
# best............ 1.000000e+00
# mean............ 1.296032e+01
# variance........ 4.841196e+03
# var 4:
# best............ 1.487704e+00
# mean............ 2.273334e+01
# variance........ 1.110477e+04
# var 5:
# best............ 1.000000e+00
# mean............ 1.309684e+01
# variance........ 8.479671e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.537114e+01
# variance........ 5.231388e+03
# var 7:
# best............ 9.887699e-01
# mean............ 1.222515e+01
# variance........ 3.723919e+03
# var 8:
# best............ 1.000000e+00
# mean............ 9.937671e+00
# variance........ 3.164665e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.738653e+01
# variance........ 7.362649e+03
# var 10:
# best............ 1.000000e+00
# mean............ 1.440039e+01
# variance........ 7.892383e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.755547e+01
# variance........ 6.463593e+03
# var 12:
# best............ 1.000000e+00
# mean............ 1.817177e+01
# variance........ 8.681594e+03
# var 13:
# best............ 9.836272e-01
# mean............ 1.294316e+01
# variance........ 4.024304e+03
# var 14:
# best............ 5.735817e-01
# mean............ 1.146190e+01
# variance........ 3.731596e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.264293e+01
# variance........ 4.929042e+03
# var 16:
# best............ 1.000000e+00
# mean............ 3.931857e+00
# variance........ 5.155133e+02
# var 17:
# best............ 2.683245e+00
# mean............ 1.240595e+01
# variance........ 3.362657e+03
# var 18:
# best............ 1.078560e+01
# mean............ 2.146158e+01
# variance........ 5.817894e+03
# var 19:
# best............ 3.440659e+02
# mean............ 3.468803e+02
# variance........ 2.367819e+03
# var 20:
# best............ 3.757568e+02
# mean............ 3.804260e+02
# variance........ 3.512954e+03
# var 21:
# best............ 1.299145e+01
# mean............ 2.304485e+01
# variance........ 4.381705e+03
# var 22:
# best............ 1.000000e+00
# mean............ 1.620887e+01
# variance........ 5.126644e+03
# var 23:
# best............ 9.794047e-01
# mean............ 1.877382e+01
# variance........ 9.001904e+03
# var 24:
# best............ 9.975273e-01
# mean............ 1.601273e+01
# variance........ 5.680270e+03
# var 25:
# best............ 9.971006e-01
# mean............ 1.168436e+01
# variance........ 4.160733e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.027171e+01
# variance........ 2.894955e+03
# var 27:
# best............ 9.769150e-01
# mean............ 2.077018e+01
# variance........ 8.639762e+03
#
# GENERATION: 40
# Lexical Fit..... 1.958935e-02  2.123067e-02  2.352312e-02  2.631478e-02  2.708721e-02  2.715371e-02  2.893184e-02  3.348312e-02  3.544244e-02  3.697041e-02  4.135081e-02  4.539809e-02  4.690383e-02  5.596982e-02  7.053309e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.642511e-01  1.744297e-01  1.825200e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.382400e-01  3.069322e-01  3.368713e-01  3.865045e-01  3.865045e-01  3.865045e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  8.240263e-01  8.278134e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  9.870740e-01  9.883303e-01  9.895103e-01
# #unique......... 166, #Total UniqueCount: 7320
# var 1:
# best............ 1.000000e+00
# mean............ 1.840883e+01
# variance........ 8.303747e+03
# var 2:
# best............ 1.000000e+00
# mean............ 1.163001e+01
# variance........ 4.897656e+03
# var 3:
# best............ 1.000000e+00
# mean............ 1.223584e+01
# variance........ 6.161523e+03
# var 4:
# best............ 1.487704e+00
# mean............ 1.038294e+01
# variance........ 4.795621e+03
# var 5:
# best............ 1.000000e+00
# mean............ 7.566603e+00
# variance........ 2.972238e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.094605e+01
# variance........ 3.893622e+03
# var 7:
# best............ 9.887699e-01
# mean............ 8.481135e+00
# variance........ 4.747169e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.266800e+01
# variance........ 3.751421e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.054981e+01
# variance........ 3.951673e+03
# var 10:
# best............ 1.000000e+00
# mean............ 5.586508e+00
# variance........ 1.197548e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.154698e+01
# variance........ 5.378749e+03
# var 12:
# best............ 1.000000e+00
# mean............ 1.096117e+01
# variance........ 2.923949e+03
# var 13:
# best............ 9.836272e-01
# mean............ 1.489065e+01
# variance........ 7.414871e+03
# var 14:
# best............ 5.735817e-01
# mean............ 1.205450e+01
# variance........ 3.876521e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.559393e+01
# variance........ 7.813738e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.690552e+01
# variance........ 7.070479e+03
# var 17:
# best............ 2.683245e+00
# mean............ 1.506895e+01
# variance........ 5.076818e+03
# var 18:
# best............ 1.078560e+01
# mean............ 2.106582e+01
# variance........ 4.555172e+03
# var 19:
# best............ 3.440659e+02
# mean............ 3.523075e+02
# variance........ 2.770089e+03
# var 20:
# best............ 3.757568e+02
# mean............ 3.788358e+02
# variance........ 2.053989e+03
# var 21:
# best............ 1.299145e+01
# mean............ 1.647104e+01
# variance........ 1.215723e+03
# var 22:
# best............ 1.000000e+00
# mean............ 2.119733e+01
# variance........ 9.187775e+03
# var 23:
# best............ 9.794047e-01
# mean............ 1.407097e+01
# variance........ 6.716144e+03
# var 24:
# best............ 9.975273e-01
# mean............ 1.362135e+01
# variance........ 6.072793e+03
# var 25:
# best............ 9.971006e-01
# mean............ 2.543370e+01
# variance........ 1.409274e+04
# var 26:
# best............ 1.000000e+00
# mean............ 1.663702e+01
# variance........ 6.026524e+03
# var 27:
# best............ 9.769150e-01
# mean............ 1.650902e+01
# variance........ 7.316459e+03
#
# GENERATION: 41
# Lexical Fit..... 1.958935e-02  2.123067e-02  2.352312e-02  2.631478e-02  2.708721e-02  2.715371e-02  2.893184e-02  3.348312e-02  3.544244e-02  3.697041e-02  4.135081e-02  4.539809e-02  4.690383e-02  5.596982e-02  7.053309e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.642511e-01  1.744297e-01  1.825200e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.382400e-01  3.069322e-01  3.368713e-01  3.865045e-01  3.865045e-01  3.865045e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  8.240263e-01  8.278134e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  9.870740e-01  9.883303e-01  9.895103e-01
# #unique......... 161, #Total UniqueCount: 7481
# var 1:
# best............ 1.000000e+00
# mean............ 8.822193e+00
# variance........ 2.889183e+03
# var 2:
# best............ 1.000000e+00
# mean............ 2.776012e+01
# variance........ 1.296205e+04
# var 3:
# best............ 1.000000e+00
# mean............ 1.719559e+01
# variance........ 8.035653e+03
# var 4:
# best............ 1.487704e+00
# mean............ 1.935908e+01
# variance........ 9.172908e+03
# var 5:
# best............ 1.000000e+00
# mean............ 1.173979e+01
# variance........ 5.320666e+03
# var 6:
# best............ 5.014762e-02
# mean............ 1.256672e+01
# variance........ 5.721585e+03
# var 7:
# best............ 9.887699e-01
# mean............ 1.357635e+01
# variance........ 5.628291e+03
# var 8:
# best............ 1.000000e+00
# mean............ 1.818842e+01
# variance........ 7.380162e+03
# var 9:
# best............ 1.000000e+00
# mean............ 1.649556e+01
# variance........ 6.428488e+03
# var 10:
# best............ 1.000000e+00
# mean............ 1.303993e+01
# variance........ 3.872348e+03
# var 11:
# best............ 1.000000e+00
# mean............ 1.763486e+01
# variance........ 1.067470e+04
# var 12:
# best............ 1.000000e+00
# mean............ 1.857571e+01
# variance........ 8.135408e+03
# var 13:
# best............ 9.836272e-01
# mean............ 2.428055e+01
# variance........ 1.242422e+04
# var 14:
# best............ 5.735817e-01
# mean............ 1.749744e+01
# variance........ 7.952300e+03
# var 15:
# best............ 1.000000e+00
# mean............ 1.401225e+01
# variance........ 5.497815e+03
# var 16:
# best............ 1.000000e+00
# mean............ 1.632747e+01
# variance........ 6.861200e+03
# var 17:
# best............ 2.683245e+00
# mean............ 1.497897e+01
# variance........ 5.369691e+03
# var 18:
# best............ 1.078560e+01
# mean............ 1.373661e+01
# variance........ 1.119000e+03
# var 19:
# best............ 3.440659e+02
# mean............ 3.456664e+02
# variance........ 1.617579e+03
# var 20:
# best............ 3.757568e+02
# mean............ 3.815238e+02
# variance........ 3.150027e+03
# var 21:
# best............ 1.299145e+01
# mean............ 2.383733e+01
# variance........ 4.224400e+03
# var 22:
# best............ 1.000000e+00
# mean............ 1.221121e+01
# variance........ 5.637577e+03
# var 23:
# best............ 9.794047e-01
# mean............ 1.619116e+01
# variance........ 9.866024e+03
# var 24:
# best............ 9.975273e-01
# mean............ 1.493555e+01
# variance........ 6.207573e+03
# var 25:
# best............ 9.971006e-01
# mean............ 9.336229e+00
# variance........ 3.650501e+03
# var 26:
# best............ 1.000000e+00
# mean............ 1.244100e+01
# variance........ 4.582861e+03
# var 27:
# best............ 9.769150e-01
# mean............ 1.361007e+01
# variance........ 6.167449e+03
#
# 'wait.generations' limit reached.
# No significant improvement in 25 generations.
#
# Solution Lexical Fitness Value:
# 1.958935e-02  2.123067e-02  2.352312e-02  2.631478e-02  2.708721e-02  2.715371e-02  2.893184e-02  3.348312e-02  3.544244e-02  3.697041e-02  4.135081e-02  4.539809e-02  4.690383e-02  5.596982e-02  7.053309e-02  1.034972e-01  1.090329e-01  1.090329e-01  1.642511e-01  1.744297e-01  1.825200e-01  2.143325e-01  2.153739e-01  2.153739e-01  2.382400e-01  3.069322e-01  3.368713e-01  3.865045e-01  3.865045e-01  3.865045e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  6.208099e-01  8.240263e-01  8.278134e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  8.602552e-01  9.870740e-01  9.883303e-01  9.895103e-01
#
# Parameters at the Solution:
#
#  X[ 1] :	1.000000e+00
#  X[ 2] :	1.000000e+00
#  X[ 3] :	1.000000e+00
#  X[ 4] :	1.487704e+00
#  X[ 5] :	1.000000e+00
#  X[ 6] :	5.014762e-02
#  X[ 7] :	9.887699e-01
#  X[ 8] :	1.000000e+00
#  X[ 9] :	1.000000e+00
#  X[10] :	1.000000e+00
#  X[11] :	1.000000e+00
#  X[12] :	1.000000e+00
#  X[13] :	9.836272e-01
#  X[14] :	5.735817e-01
#  X[15] :	1.000000e+00
#  X[16] :	1.000000e+00
#  X[17] :	2.683245e+00
#  X[18] :	1.078560e+01
#  X[19] :	3.440659e+02
#  X[20] :	3.757568e+02
#  X[21] :	1.299145e+01
#  X[22] :	1.000000e+00
#  X[23] :	9.794047e-01
#  X[24] :	9.975273e-01
#  X[25] :	9.971006e-01
#  X[26] :	1.000000e+00
#  X[27] :	9.769150e-01
#
# Solution Found Generation 15
# Number of Generations Run 41
#
# Fri Dec 20 02:12:45 2019
# Total run time : 0 hours 1 minutes and 52 seconds

# %%
mout = Match(Tr = Tr, X = X.all, M=1, Weight.matrix = genout)

# %%
mb <- MatchBalance(treat ~ state + pcgsdp + pfemale + plit + pwlit + prural, data=before.data, match.out=mout, nboots=500)
# Out:
# ***** (V1) state *****
#                        Before Matching 	 	 After Matching
# mean treatment........     10.273 	 	     10.273
# mean control..........     11.958 	 	         11
# std mean diff.........    -61.773 	 	    -26.653
#
# mean raw eQQ diff.....     1.7273 	 	     1.0909
# med  raw eQQ diff.....          2 	 	          1
# max  raw eQQ diff.....          5 	 	          4
#
# mean eCDF diff........    0.20833 	 	    0.13636
# med  eCDF diff........    0.22727 	 	    0.13636
# max  eCDF diff........    0.37879 	 	    0.22727
#
# var ratio (Tr/Co).....     1.0356 	 	     1.4478
# T-test p-value........   0.020505 	 	     0.1035
# KS Bootstrap p-value..      0.006 	 	       0.36
# KS Naive p-value......   0.026361 	 	    0.62081
# KS Statistic..........    0.37879 	 	    0.22727
#
#
# ***** (V2) pcgsdp *****
#                        Before Matching 	 	 After Matching
# mean treatment........     1.3631 	 	     1.3631
# mean control..........     1.2199 	 	     1.4035
# std mean diff.........     29.002 	 	    -8.1874
#
# mean raw eQQ diff.....    0.17316 	 	    0.12075
# med  raw eQQ diff.....    0.13723 	 	   0.075612
# max  raw eQQ diff.....    0.48856 	 	    0.43613
#
# mean eCDF diff........    0.10181 	 	    0.07438
# med  eCDF diff........    0.07197 	 	   0.045455
# max  eCDF diff........    0.27652 	 	    0.18182
#
# var ratio (Tr/Co).....     0.7376 	 	    0.70179
# T-test p-value........    0.29083 	 	    0.30693
# KS Bootstrap p-value..      0.126 	 	        0.8
# KS Naive p-value......    0.16118 	 	    0.86026
# KS Statistic..........    0.27652 	 	    0.18182
#
#
# ***** (V3) pfemale *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.96387 	 	    0.96387
# mean control..........    0.94051 	 	    0.94541
# std mean diff.........     54.736 	 	     43.242
#
# mean raw eQQ diff.....   0.024367 	 	   0.018673
# med  raw eQQ diff.....   0.026087 	 	   0.011611
# max  raw eQQ diff.....   0.060867 	 	   0.063806
#
# mean eCDF diff........    0.14713 	 	   0.086777
# med  eCDF diff........    0.14205 	 	   0.090909
# max  eCDF diff........    0.36932 	 	    0.22727
#
# var ratio (Tr/Co).....    0.85977 	 	    0.76618
# T-test p-value........    0.04404 	 	   0.027154
# KS Bootstrap p-value..      0.024 	 	       0.55
# KS Naive p-value......   0.023517 	 	    0.62081
# KS Statistic..........    0.36932 	 	    0.22727
#
#
# ***** (V4) plit *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.53846 	 	    0.53846
# mean control..........     0.4768 	 	    0.50812
# std mean diff.........     48.866 	 	     24.042
#
# mean raw eQQ diff.....   0.062687 	 	    0.03314
# med  raw eQQ diff.....    0.05157 	 	   0.020304
# max  raw eQQ diff.....    0.24671 	 	    0.26313
#
# mean eCDF diff........    0.17045 	 	    0.11019
# med  eCDF diff........     0.1714 	 	   0.090909
# max  eCDF diff........    0.33333 	 	    0.27273
#
# var ratio (Tr/Co).....     1.0596 	 	     1.1762
# T-test p-value........   0.062707 	 	   0.026315
# KS Bootstrap p-value..      0.056 	 	      0.318
# KS Naive p-value......    0.05266 	 	     0.3865
# KS Statistic..........    0.33333 	 	    0.27273
#
#
# ***** (V5) pwlit *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.45226 	 	    0.45226
# mean control..........     0.3824 	 	    0.41873
# std mean diff.........     44.828 	 	     21.516
#
# mean raw eQQ diff.....   0.071041 	 	   0.035362
# med  raw eQQ diff.....   0.056334 	 	   0.021782
# max  raw eQQ diff.....    0.31462 	 	    0.29961
#
# mean eCDF diff........    0.15341 	 	   0.099174
# med  eCDF diff........    0.14773 	 	   0.090909
# max  eCDF diff........    0.33333 	 	    0.22727
#
# var ratio (Tr/Co).....     1.0848 	 	     1.1674
# T-test p-value........   0.085679 	 	   0.019589
# KS Bootstrap p-value..      0.056 	 	       0.52
# KS Naive p-value......    0.05266 	 	    0.62081
# KS Statistic..........    0.33333 	 	    0.22727
#
#
# ***** (V6) prural *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.71686 	 	    0.71686
# mean control..........    0.74083 	 	    0.71669
# std mean diff.........    -32.806 	 	    0.23339
#
# mean raw eQQ diff.....   0.024061 	 	   0.013448
# med  raw eQQ diff.....   0.020843 	 	   0.006617
# max  raw eQQ diff.....   0.047551 	 	   0.050855
#
# mean eCDF diff........     0.1622 	 	   0.082645
# med  eCDF diff........    0.15625 	 	   0.090909
# max  eCDF diff........    0.37879 	 	    0.22727
#
# var ratio (Tr/Co).....     1.0261 	 	     0.9881
# T-test p-value........    0.20809 	 	    0.98707
# KS Bootstrap p-value..      0.012 	 	      0.586
# KS Naive p-value......   0.018529 	 	    0.62081
# KS Statistic..........    0.37879 	 	    0.22727
#
#
# Before Matching Minimum p.value: 0.006
# Variable Name(s): state  Number(s): 1
#
# After Matching Minimum p.value: 0.019589
# Variable Name(s): pwlit  Number(s): 5

# %%
mout = Match(Y=Y, Tr = Tr, X = X.all, M=1, Weight.matrix = genout)
summary(mout)
# Out:
# Estimate...  0.023075
# AI SE......  0.0084669
# T-stat.....  2.7254
# p.val......  0.0064233
#
# Original number of observations..............  70
# Original number of treated obs...............  22
# Matched number of observations...............  22
# Matched number of observations  (unweighted).  22

# %%
conf.interval.95 <- function(mout){
  up = mout$est + 1.96*mout$se
  low = mout$est - 1.96*mout$se
  if (is.null(mout$se)){
    up = mout$est + 1.96*mout$se.standard
    low = mout$est - 1.96*mout$se.standard
  }
  return (paste("[",low,",",up,"]"))
}

conf.interval.95(mout)
# Out:
# [1] "[ 0.00648016338723677 , 0.0396703811127632 ]"

# %% [markdown]
# ## Synthetic Control

# %%
install.packages('Synth')
library(Synth)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘numDeriv’, ‘kernlab’, ‘optimx’
#
#
# ##
# ## Synth Package: Implements Synthetic Control Methods.
#
#
# ## See http://www.mit.edu/~jhainm/software.htm for additional information.

# %% [markdown]
# ### ASSAM: Synthetic Control

# %%
# Mahmud: the changed that I made
# data$state <- as.numeric(as.factor(data$stateid))
# data$stateuni <- as.character(data$stateuni)
# unit.names.variable = c("stateuni")
# unit.variable = "state",

# treatment happened in 2002 in ASSAM

data = data

data$state <- as.numeric(as.factor(data$stateid))
data$stateuni <- as.character(data$stateuni)

dataprep.out = 
  dataprep(
    foo = data,
    predictors = c("pcgsdp", "pfemale", "plit","pwlit","prural"),
    predictors.op = "median", #match the median of the predictors
    time.predictors.prior = 1985:2002, # data used to train the synthetic control unit 
    dependent = "pcr_womtot",
    unit.variable = "state",
    time.variable = "year",
    #special.predictors = list(
    #  list("pcgsdp", seq(1985,2001,2),"mean"),
    #  list("pfemale", seq(1985,2001,2),"mean"),
    #  list("plit",  seq(1985,2001,2),"mean"),
    #  list("pwlit",  seq(1985,2001,2),"mean"),
    #  list("prural",  seq(1985,2001,2),"mean")
    #),
    treatment.identifier = 2, #point at Assam,
    controls.identifier = c(1, 3:17),
    time.optimize.ssr = c(1985:2002), #count the outcome variables of Assam and synthetic control units and make it as small as possible
    unit.names.variable = c("stateuni"),
    time.plot = c(1985:2007)
  )

synth.out = synth(dataprep.out) #create synthetic controls

#plot treatment vs synthetic control outcomes trend
path.plot(synth.res = synth.out, dataprep.res = dataprep.out,
          Ylab = "Crime against women per 1000 women", Xlab = 'year', tr.intake = 2002,
          Legend = c("Assam", "Synthetic Assam"), Legend.position = "bottomright")
# abline(v = 2001, lw=2)
# Out:
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003042721
#
# solution.v:
#  0.2300167 0.3700114 0.393585 0.006386841 0
#
# solution.w:
#  0.05121218 0.2659888 0.03791813 0.05109935 0.02624605 0.07985753 0.04132484 0.05403987 0.03250165 0.03311749 0.03143242 0.08711503 0.03540303 0.02356482 0.06408271 0.0850961
# Plot with title “NA”

# %%
#gap or difference in treatment and synthetic control
gaps <- dataprep.out$Y1plot - (dataprep.out$Y0plot %*% synth.out$solution.w)

#pre built tables from synth objects
synth.tables <- synth.tab(dataprep.res = dataprep.out, synth.res = synth.out)

#comparing pre-treatment predictor values for the treated unit, the synthetic control unit , and all the units in the sample
synth.tables$tab.pred[1:5,]

#View control unit weights
synth.tables$tab.w
# Out:
#         Treated Synthetic Sample Mean
# pcgsdp  1.324   1.324     1.495
# pfemale 0.926   0.926     0.936
# plit    0.453   0.454     0.490
# pwlit   0.374   0.352     0.391
# prural  0.884   0.771     0.745
#    w.weights unit.names       unit.numbers
# 1  0.051     ANDHRA PRADESH    1
# 3  0.266     BIHAR             3
# 4  0.038     GUJARAT           4
# 5  0.051     HARYANA           5
# 6  0.026     HIMACHAL PRADESH  6
# 7  0.080     JAMMU & KASHMIR   7
# 8  0.041     KARNATAKA         8
# 9  0.054     KERALA            9
# 10 0.033     MADHYA PRADESH   10
# 11 0.033     MAHARASHTRA      11
# 12 0.031     ORISSA           12
# 13 0.087     PUNJAB           13
# 14 0.035     RAJASTHAN        14
# 15 0.024     TAMIL NADU       15
# 16 0.064     UTTAR PRADESH    16
# 17 0.085     WEST BENGAL      17

# %%
gaps.plot(synth.res = synth.out,
           dataprep.res = dataprep.out,
           Ylab = "Gap in crime against women (per 1000 women)",
           Xlab = "year",
           Ylim = c(-.5,.5),
           Main = NA,
           tr.intake = 2002
           )
# Out:
# Plot with title “NA”

# %% [markdown]
# #### Placebo test in space for all 17 states

# %%
### Placebo test in space

store <- matrix(NA, length(1985:2007), 17)
colnames(store) <- unique(data$stateuni)

for (k in 1:17){
  # print(k)
  dataprep.out = dataprep(
    foo = data,
    predictors = c("pcgsdp", "pfemale", "plit","pwlit","prural"),
    predictors.op = "median",
    time.predictors.prior = 1985:2002,
    dependent = "pcr_womtot",
    unit.variable = "state",
    time.variable = "year",
    #special.predictors = list(
    #  list("pcgsdp", seq(1985,2001,2),"mean"),
    #  list("pfemale", seq(1985,2001,2),"mean"),
    #  list("plit",  seq(1985,2001,2),"mean"),
    #  list("pwlit",  seq(1985,2001,2),"mean"),
    #  list("prural",  seq(1985,2001,2),"mean")
    #),
    treatment.identifier = k,
    controls.identifier = c(1:17)[-k],
    time.optimize.ssr = c(1985:2002),
    unit.names.variable = c("stateuni"),
    time.plot = c(1985:2007)
  )

  synth.out <- synth(
    data.prep.obj = dataprep.out,
    method = "BFGS"
  )

  # store gaps
  print(k)
  store[, k] <- dataprep.out$Y1plot - (dataprep.out$Y0plot %*% synth.out$solution.w)
}
# Out:
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.002281638
#
# solution.v:
#  0.1687452 0.005238963 0.5157038 0.1318055 0.1785065
#
# solution.w:
#  9.8121e-06 6e-10 0.000225708 6.73029e-05 7.4397e-06 1.97751e-05 0.25026 8.444e-07 3.4819e-06 0.0007777076 8.33e-06 0.05677168 0.6566102 0.03520986 2.866e-06 2.49876e-05
#
# [1] 1
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003042721
#
# solution.v:
#  0.2300167 0.3700114 0.393585 0.006386841 0
#
# solution.w:
#  0.05121218 0.2659888 0.03791813 0.05109935 0.02624605 0.07985753 0.04132484 0.05403987 0.03250165 0.03311749 0.03143242 0.08711503 0.03540303 0.02356482 0.06408271 0.0850961
#
# [1] 2
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.002169068
#
# solution.v:
#  0.05528547 0.002649626 0.3141791 0.4514611 0.1764247
#
# solution.w:
#  4.4e-08 4.676e-07 1.88e-08 4.73e-08 1.085e-07 6.97e-08 2.33e-08 6e-10 4.61e-08 1.34e-08 3.935e-07 2.6e-08 5e-09 1.46e-08 0.9999987 2.93e-08
#
# [1] 3
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.007221159
#
# solution.v:
#  0.001014589 0.02624114 0.373239 0.5995053 4e-10
#
# solution.w:
#  0.01552747 0.01173782 0.01670935 0.1332162 0.03664353 0.01442985 0.02045348 0.0321637 0.02280408 0.5214867 0.09646981 6.13e-06 0.03046195 0.01449249 0.01827179 0.01512569
#
# [1] 4
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.001432645
#
# solution.v:
#  0.0005694872 0.000222546 0.01699267 0.501475 0.4807403
#
# solution.w:
#  0.002629527 0.001293504 4.3041e-06 0.03008768 0.1329729 0.009914486 0.005721472 0.003283897 0.002988922 0.1314882 0.002017898 0.2484829 0.4073222 0.01258264 0.002090299 0.007119257
#
# [1] 5
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0002603912
#
# solution.v:
#  5.04e-08 0.6583224 0.01930585 0.00854398 0.3138277
#
# solution.w:
#  1.458e-07 0.04101574 2.33268e-05 1.493e-06 9.8513e-06 7.7317e-06 6.62e-07 1.4163e-06 2.8369e-06 1.0938e-06 0.9589097 5.2126e-06 4.813e-06 2.549e-07 1.22676e-05 3.4282e-06
#
# [1] 6
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0004331239
#
# solution.v:
#  0.2093455 0.173046 0.06255387 0.5531136 0.001941016
#
# solution.w:
#  0.01356235 0.01287697 0.1554817 0.01143578 0.3230693 0.006142044 0.009602002 0.0003028197 0.01317165 0.01018623 0.00748051 0.0575991 0.0614455 0.006800765 0.2995718 0.01127146
#
# [1] 7
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.003008147
#
# solution.v:
#  0.002636462 0.1844556 0.0846512 0.7276558 0.0006009241
#
# solution.w:
#  0.2501449 0.02104671 0.03251453 0.03180958 0.01911742 0.006733485 0.02609233 0.08218705 0.04723486 0.02934864 0.1136328 0.01948923 0.02647704 0.2268934 0.03580363 0.03147437
#
# [1] 8
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.02239653
#
# solution.v:
#  0.4783424 0.01448686 0.000907648 0.003371942 0.5028911
#
# solution.w:
#  1.81703e-05 0.0003411913 0.0002428478 0.0003823882 4.93518e-05 0.2995341 0.0002893402 0.0003102319 0.0003468769 0.0003340234 0.1273712 6.993e-07 0.0003315191 0.56958 0.0003258006 0.0005421554
#
# [1] 9
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.007895602
#
# solution.v:
#  1.84e-08 0.04628755 0.3321598 0.5539908 0.06756188
#
# solution.w:
#  0.2420701 0.009648989 0.05789765 0.01526821 0.01054857 0.008282109 0.01186873 0.02061672 0.0003819452 0.01317507 0.04518543 0.008196958 0.516431 0.02038274 0.008411611 0.01163417
#
# [1] 10
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.005609017
#
# solution.v:
#  0.000476318 0.04355681 0.3703635 0.5851379 0.0004654575
#
# solution.w:
#  0.002510014 0.002378307 0.002155549 0.0929607 0.4869354 0.006193566 0.003291434 0.005042277 0.2190279 0.003775956 0.004064385 0.0006443264 0.004615324 0.1584044 0.003214612 0.004785856
#
# [1] 11
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0001150248
#
# solution.v:
#  8.0019e-06 0.004853255 0.3866199 0.5960619 0.01245695
#
# solution.w:
#  0.03848954 1.54542e-05 0.3192508 4.32465e-05 1.88442e-05 0.4014789 3.39623e-05 5.00811e-05 4.9876e-06 0.0001176007 3.61404e-05 1.74037e-05 0.2403275 5.25999e-05 3.01957e-05 3.26823e-05
#
# [1] 12
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.01331187
#
# solution.v:
#  0.1341399 0.0001096425 0.01852474 0.8434723 0.003753424
#
# solution.w:
#  3.92196e-05 3.48522e-05 2.54411e-05 5.3932e-05 0.780545 3.40202e-05 3.8007e-05 4.13796e-05 0.2189391 3.01944e-05 2.51083e-05 2.61336e-05 3.33229e-05 6.83953e-05 2.68352e-05 3.90463e-05
#
# [1] 13
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.004595879
#
# solution.v:
#  0.1367132 0.2925145 0.0002309036 0.0172288 0.5533126
#
# solution.w:
#  0.1260546 0.005090514 0.08072839 0.001978938 0.01616241 0.003114587 0.4595572 0.002029671 0.0004701508 0.2110364 0.001848925 0.004299737 0.006190218 0.001746962 0.0759201 0.003771172
#
# [1] 14
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.04121765
#
# solution.v:
#  4.59581e-05 0.1556958 0.2850776 0.55344 0.005740582
#
# solution.w:
#  1.53868e-05 2.90915e-05 3.43366e-05 0.000382392 4.71453e-05 7.36502e-05 4.81695e-05 0.6958201 0.206577 0.0001623462 0.09645799 3.739e-07 1.99505e-05 0.0002151348 5.33721e-05 6.36479e-05
#
# [1] 15
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.00035292
#
# solution.v:
#  0.006262884 0.03988411 0.3674422 0.5744507 0.01196005
#
# solution.w:
#  1.93868e-05 2.24504e-05 0.6630612 3.28152e-05 0.17564 1.05485e-05 0.0548646 2.40473e-05 3.735e-07 4.98448e-05 2.69648e-05 2.06527e-05 3.85486e-05 0.1061362 1.58587e-05 3.65156e-05
#
# [1] 16
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0009140678
#
# solution.v:
#  0.06787093 0.4585871 0.1483528 0.3168044 0.008384872
#
# solution.w:
#  3.33319e-05 3.69084e-05 4.76055e-05 0.0002086855 3.803e-06 2.78828e-05 8.98553e-05 7.87283e-05 0.2150532 7.0616e-05 0.06857928 3.81444e-05 0.1962268 5.353e-05 7.80092e-05 0.5193736
#
# [1] 17

# %%
# now the figure
rownames(store) <- 1985:2007

# set bounds in gaps data:
gap.start <- 1
gap.end <- nrow(store)
years <- 1985:2007
gap.end.pre <- which(rownames(store)=='2002')


# Plot
plot(c(1,2),c(1,2),
   ylim=c(-0.5,0.5),xlab="year",
   xlim=c(1985,2007),ylab="gap in crime against women per 1000 women",
   type="l",lwd=2,col="black",
   xaxs="i",yaxs="i")

# Add lines for control states
for (i in 1:ncol(store)) { lines(years,store[gap.start:gap.end,i],col="gray") }

## Add ASSAM Line
lines(years,store[gap.start:gap.end,which(colnames(store)=="ASSAM")],lwd=2,col="black")

# Add grid
abline(v=2002,lty="dotted",lwd=2)
abline(h=0,lty="dashed",lwd=2)
legend("bottomright",legend=c("ASSAM","control regions"),
       lty=c(1,1),col=c("black","gray"),lwd=c(2,1),cex=.8)
# Out:
# plot without title

# %%
# dot chart
mse <- function(x){mean(x^2)}
preloss <- apply(store[gap.start:gap.end.pre,],2,mse)
postloss <- apply(store[(gap.end.pre+1):gap.end,],2,mse)

#pdf("2ratio_post_to_preperiod_rmse2a.pdf")
dotchart(sort(postloss/preloss),
         xlab="Post-Period MSE / Pre-Period MSE",
         pch=19)
# Out:
# plot without title

# %% [markdown]
# #### Discard the states whose pre treatment MSE is respectively 20 and 5 times larger than ASSAM pre treat MSE

# %%
# Taking out the states where pre treatment MSE is greater than (Assam pre-period MSE * 20)

store.2 = store[, preloss < 20*preloss['ASSAM']]

# Plot
plot(c(1,2),c(1,2),
   ylim=c(-0.5,0.5),xlab="year",
   xlim=c(1985,2007),ylab="gap in crime against women per 1000 women",
   type="l",lwd=2,col="black",
   xaxs="i",yaxs="i")

# Add lines for control states
for (i in 1:ncol(store.2)) { lines(years,store.2[gap.start:gap.end,i],col="gray") }

## Add ASSAM Line
lines(years,store.2[gap.start:gap.end,which(colnames(store.2)=="ASSAM")],lwd=2,col="black")

# Add grid
abline(v=2002,lty="dotted",lwd=2)
abline(h=0,lty="dashed",lwd=2)
legend("bottomright",legend=c("ASSAM","control regions"),
       lty=c(1,1),col=c("black","gray"),lwd=c(2,1),cex=.8)
# Out:
# plot without title

# %%
# dot chart
mse <- function(x){mean(x^2)}
preloss.2 <- apply(store.2[gap.start:gap.end.pre,],2,mse)
postloss.2 <- apply(store.2[(gap.end.pre+1):gap.end,],2,mse)

names(preloss.2) = colnames(store.2)

#pdf("2ratio_post_to_preperiod_rmse2a.pdf")
dotchart(sort(postloss.2/preloss.2),
         xlab="Post-Period MSE / Pre-Period MSE",
         pch=19)
# Out:
# plot without title

# %%
# Taking out the states where pre treatment MSE is greater than (Assam pre-period MSE * 5)

store.3 = store[, preloss < 5*preloss['ASSAM']]

# Plot
plot(c(1,2),c(1,2),
   ylim=c(-0.5,0.5),xlab="year",
   xlim=c(1985,2007),ylab="gap in crime against women per 1000 women",
   type="l",lwd=2,col="black",
   xaxs="i",yaxs="i")

# Add lines for control states
for (i in 1:ncol(store.3)) { lines(years,store.3[gap.start:gap.end,i],col="gray") }

## Add ASSAM Line
lines(years,store.3[gap.start:gap.end,which(colnames(store.3)=="ASSAM")],lwd=2,col="black")

# Add grid
abline(v=2002,lty="dotted",lwd=2)
abline(h=0,lty="dashed",lwd=2)
legend("bottomright",legend=c("ASSAM","control regions"),
       lty=c(1,1),col=c("black","gray"),lwd=c(2,1),cex=.8)
# Out:
# plot without title

# %%
# dot chart
mse <- function(x){mean(x^2)}
preloss.3 <- apply(store.3[gap.start:gap.end.pre,],2,mse)
postloss.3 <- apply(store.3[(gap.end.pre+1):gap.end,],2,mse)

names(preloss.3) = colnames(store.3)

#pdf("2ratio_post_to_preperiod_rmse2a.pdf")
dotchart(sort(postloss.3/preloss.3),
         xlab="Post-Period MSE / Pre-Period MSE",
         pch=19)
# Out:
# plot without title

# %% [markdown]
# #### Placebo in time for 'fake' treatment in 1998 and 1992

# %%
## Placebo effect in time at 'fake' treatment = 1998  

dataprep.out = dataprep(
  foo = data,
  predictors = c("pcgsdp", "pfemale", "plit","pwlit","prural"),
  predictors.op = "median",
  time.predictors.prior = 1985:1998,
  dependent = "pcr_womtot",
  unit.variable = "state",
  time.variable = "year",
  #special.predictors = list(
  #  list("pcgsdp", seq(1985,k,2),"mean"),
  #  list("pfemale", seq(1985,k,2),"mean"),
  #  list("plit",  seq(1985,k,2),"mean"),
  #  list("pwlit",  seq(1985,k,2),"mean"),
  #  list("prural",  seq(1985,k,2),"mean")
  #),
  treatment.identifier = 2,
  controls.identifier = c(1, 3:17),
  time.optimize.ssr = c(1985:1998),
  unit.names.variable = c("stateuni"),
  time.plot = c(1985:2007)
)

synth.out <- synth(
  data.prep.obj = dataprep.out,
  method = "BFGS"
)

#plot treatment vs synthetic control outcomes trend
path.plot(synth.res = synth.out, dataprep.res = dataprep.out,
          Ylab = "Crime against women per 1000 women", Xlab = 'year', tr.intake = 1998,
          Legend = c("Assam", "Synthetic Assam"), Legend.position = "bottomright")
# Out:
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0002812801
#
# solution.v:
#  0.010772 8.38e-07 0.3485767 0.1670458 0.4736047
#
# solution.w:
#  0.003727256 0.4663653 0.001293254 0.001872675 0.5064547 0.003208589 0.001643212 0.0007814532 0.002067115 0.001102013 0.0008822391 0.003425231 0.002217716 0.001194164 0.00205559 0.001709502
# Plot with title “NA”

# %%
#gap or difference in treatment and synthetic control
gaps <- dataprep.out$Y1plot - (dataprep.out$Y0plot %*% synth.out$solution.w)

#pre built tables from synth objects
synth.tables <- synth.tab(dataprep.res = dataprep.out, synth.res = synth.out)

#comparing pre-treatment predictor values for the treated unit, the synthetic control unit , and all the units in the sample
synth.tables$tab.pred[1:5,]

#View control unit weights
synth.tables$tab.w

gaps.plot(synth.res = synth.out,
           dataprep.res = dataprep.out,
           Ylab = "Gap in crime against women (per 1000 women)",
           Xlab = "year",
           Ylim = c(-.5,.5),
           Main = NA,
           tr.intake = 1998
           )
# Out:
#         Treated Synthetic Sample Mean
# pcgsdp  1.295   1.186     1.372
# pfemale 0.923   0.947     0.936
# plit    0.430   0.438     0.469
# pwlit   0.349   0.331     0.367
# prural  0.888   0.887     0.750
#    w.weights unit.names       unit.numbers
# 1  0.004     ANDHRA PRADESH    1
# 3  0.466     BIHAR             3
# 4  0.001     GUJARAT           4
# 5  0.002     HARYANA           5
# 6  0.506     HIMACHAL PRADESH  6
# 7  0.003     JAMMU & KASHMIR   7
# 8  0.002     KARNATAKA         8
# 9  0.001     KERALA            9
# 10 0.002     MADHYA PRADESH   10
# 11 0.001     MAHARASHTRA      11
# 12 0.001     ORISSA           12
# 13 0.003     PUNJAB           13
# 14 0.002     RAJASTHAN        14
# 15 0.001     TAMIL NADU       15
# 16 0.002     UTTAR PRADESH    16
# 17 0.002     WEST BENGAL      17
# Plot with title “NA”

# %%
## Placebo effect in time at 'fake' treatment = 1992  

dataprep.out = dataprep(
  foo = data,
  predictors = c("pcgsdp", "pfemale", "plit","pwlit","prural"),
  predictors.op = "median",
  time.predictors.prior = 1985:1992,
  dependent = "pcr_womtot",
  unit.variable = "state",
  time.variable = "year",
  #special.predictors = list(
  #  list("pcgsdp", seq(1985,k,2),"mean"),
  #  list("pfemale", seq(1985,k,2),"mean"),
  #  list("plit",  seq(1985,k,2),"mean"),
  #  list("pwlit",  seq(1985,k,2),"mean"),
  #  list("prural",  seq(1985,k,2),"mean")
  #),
  treatment.identifier = 2,
  controls.identifier = c(1, 3:17),
  time.optimize.ssr = c(1985:1992),
  unit.names.variable = c("stateuni"),
  time.plot = c(1985:2007)
)

synth.out <- synth(
  data.prep.obj = dataprep.out,
  method = "BFGS"
)

#plot treatment vs synthetic control outcomes trend
path.plot(synth.res = synth.out, dataprep.res = dataprep.out,
          Ylab = "Crime against women per 1000 women", Xlab = 'year', tr.intake = 1992,
          Legend = c("Assam", "Synthetic Assam"), Legend.position = "bottomright")
# Out:
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003258889
#
# solution.v:
#  0.0003749968 0.685861 0.2021482 0.0009821526 0.1106336
#
# solution.w:
#  0.0001345309 6.91729e-05 0.0001929298 4.60742e-05 0.4463343 0.001208715 0.0001402082 3.05958e-05 0.0003702303 0.0001505258 0.0002355566 0.0009355249 0.0005685963 7.86877e-05 0.5490402 0.0004640967
# Plot with title “NA”

# %%
#gap or difference in treatment and synthetic control
gaps <- dataprep.out$Y1plot - (dataprep.out$Y0plot %*% synth.out$solution.w)

#pre built tables from synth objects
synth.tables <- synth.tab(dataprep.res = dataprep.out, synth.res = synth.out)

#comparing pre-treatment predictor values for the treated unit, the synthetic control unit , and all the units in the sample
synth.tables$tab.pred[1:5,]

#View control unit weights
synth.tables$tab.w

gaps.plot(synth.res = synth.out,
           dataprep.res = dataprep.out,
           Ylab = "Gap in crime against women (per 1000 women)",
           Xlab = "year",
           Ylim = c(-.5,.5),
           Main = NA,
           tr.intake = 1992
           )
# Out:
#         Treated Synthetic Sample Mean
# pcgsdp  1.221   0.929     1.205
# pfemale 0.920   0.929     0.935
# plit    0.413   0.393     0.438
# pwlit   0.330   0.276     0.333
# prural  0.891   0.867     0.757
#    w.weights unit.names       unit.numbers
# 1  0.000     ANDHRA PRADESH    1
# 3  0.256     BIHAR             3
# 4  0.000     GUJARAT           4
# 5  0.001     HARYANA           5
# 6  0.413     HIMACHAL PRADESH  6
# 7  0.000     JAMMU & KASHMIR   7
# 8  0.000     KARNATAKA         8
# 9  0.000     KERALA            9
# 10 0.000     MADHYA PRADESH   10
# 11 0.000     MAHARASHTRA      11
# 12 0.000     ORISSA           12
# 13 0.000     PUNJAB           13
# 14 0.000     RAJASTHAN        14
# 15 0.000     TAMIL NADU       15
# 16 0.330     UTTAR PRADESH    16
# 17 0.000     WEST BENGAL      17
# Plot with title “NA”

# %% [markdown]
# #### Placebo in time for all years (1988:2005)

# %%
# placebo in time

store <- matrix(NA, length(1985:2007), length(1988:2005))
colnames(store) <- 1988:2005

for (k in 1988:2005){
  # print(k)
  dataprep.out = dataprep(
    foo = data,
    predictors = c("pcgsdp", "pfemale", "plit","pwlit","prural"),
    predictors.op = "median",
    time.predictors.prior = 1985:k,
    dependent = "pcr_womtot",
    unit.variable = "state",
    time.variable = "year",
    #special.predictors = list(
    #  list("pcgsdp", seq(1985,k,2),"mean"),
    #  list("pfemale", seq(1985,k,2),"mean"),
    #  list("plit",  seq(1985,k,2),"mean"),
    #  list("pwlit",  seq(1985,k,2),"mean"),
    #  list("prural",  seq(1985,k,2),"mean")
    #),
    treatment.identifier = 2,
    controls.identifier = c(1, 3:17),
    time.optimize.ssr = c(1985:k),
    unit.names.variable = c("stateuni"),
    time.plot = c(1985:2007)
  )

  synth.out <- synth(
    data.prep.obj = dataprep.out,
    method = "BFGS"
  )

  # store gaps
  print(k)
  store[, k-1987] <- dataprep.out$Y1plot - (dataprep.out$Y0plot %*% synth.out$solution.w)
}
# Out:
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0002899322
#
# solution.v:
#  0.008315458 0.7757674 0.00517139 0.02445318 0.1862926
#
# solution.w:
#  8.9968e-06 9.04408e-05 9.2568e-06 2.46689e-05 0.4348233 0.0001047573 7.1101e-06 9.3e-07 2.69642e-05 5.3939e-06 1.81288e-05 6.70461e-05 4.68922e-05 1.7175e-06 0.5647357 2.86238e-05
#
# [1] 1988
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.00041043
#
# solution.v:
#  0.008291328 0.1016437 0.3140602 0.431337 0.1446678
#
# solution.w:
#  0.0002341233 7.1999e-06 0.0002794289 0.02144436 0.5684861 0.002483961 0.0002290286 2.959e-07 0.0003719073 0.0002405535 0.0001854 0.004349875 0.0004715499 0.0001612319 0.4004269 0.0006280867
#
# [1] 1989
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003837452
#
# solution.v:
#  3.8e-09 0.08904923 0.2935551 0.4680512 0.1493445
#
# solution.w:
#  0.0002626256 1.08649e-05 0.0002999273 0.000744354 0.5794864 0.001736024 0.0002604309 3.618e-07 0.000426081 0.0002572149 0.0002295586 0.002434241 0.0004702397 0.0001821062 0.4125529 0.0006466752
#
# [1] 1990
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003738556
#
# solution.v:
#  1.016e-07 0.06726694 0.2084276 0.607556 0.1167494
#
# solution.w:
#  0.0001940938 2.9378e-06 0.0002111334 0.001470423 0.5918618 0.002069425 0.0001849497 2.035e-07 0.00030333 0.0001857113 0.0001972995 0.005083211 0.0003432384 0.0001318631 0.39726 0.0005004005
#
# [1] 1991
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003258889
#
# solution.v:
#  0.0003749968 0.685861 0.2021482 0.0009821526 0.1106336
#
# solution.w:
#  0.0001345309 6.91729e-05 0.0001929298 4.60742e-05 0.4463343 0.001208715 0.0001402082 3.05958e-05 0.0003702303 0.0001505258 0.0002355566 0.0009355249 0.0005685963 7.86877e-05 0.5490402 0.0004640967
#
# [1] 1992
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003950793
#
# solution.v:
#  0.1759153 0.3665366 0.08198014 0.2937392 0.08182876
#
# solution.w:
#  0.0003339026 2.1884e-05 0.0004271439 0.1350755 0.4853257 0.002622801 0.0003327708 7.64891e-05 0.0007397223 0.0003642919 0.0005145738 0.002877734 0.001135755 0.0002141811 0.3691134 0.0008241228
#
# [1] 1993
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003728728
#
# solution.v:
#  0.1738212 0.03559882 0.01075507 0.7494674 0.03035748
#
# solution.w:
#  0.0004857804 0.02036867 0.000505495 0.08348635 0.5485726 0.002525495 0.0004481411 4.67e-08 0.0008482752 0.0004517504 0.0007102582 0.00216078 0.001153544 0.0003166184 0.3370821 0.0008841442
#
# [1] 1994
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0002999257
#
# solution.v:
#  0.00316244 0 0.3126603 0.1395527 0.5446245
#
# solution.w:
#  0.003561086 0.4469687 0.001274596 0.001647072 0.5259052 0.003031999 0.00168661 0.000963425 0.002235638 0.001086058 0.001364488 0.002933243 0.002087784 0.001213422 0.002242865 0.001797816
#
# [1] 1995
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.000336694
#
# solution.v:
#  0.02285461 0.3559173 0.3248594 9e-09 0.2963687
#
# solution.w:
#  0.0002387196 0.4670514 0.0003298012 0.1596975 0.3653947 0.001738519 0.0002407292 6.05538e-05 0.0007697917 0.0001989369 0.0001186309 0.001164846 0.001152709 7.74254e-05 0.0008769557 0.0008888028
#
# [1] 1996
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003069527
#
# solution.v:
#  0.0002402378 0.0001342664 0.302542 0.5512747 0.1458088
#
# solution.w:
#  0.002917394 0.4674924 0.0008981595 0.0007116137 0.4951877 0.001739093 0.001284892 0.02324377 0.001146293 0.0008037302 0.0005341193 3.6859e-06 0.0007352927 0.0008911817 0.001042581 0.001368151
#
# [1] 1997
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0002812801
#
# solution.v:
#  0.010772 8.38e-07 0.3485767 0.1670458 0.4736047
#
# solution.w:
#  0.003727256 0.4663653 0.001293254 0.001872675 0.5064547 0.003208589 0.001643212 0.0007814532 0.002067115 0.001102013 0.0008822391 0.003425231 0.002217716 0.001194164 0.00205559 0.001709502
#
# [1] 1998
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0002743967
#
# solution.v:
#  0.1292817 1.04686e-05 0.3633222 0.01100598 0.4963797
#
# solution.w:
#  0.001888062 0.4641176 0.0008568575 0.03010158 0.4930762 0.00228353 0.00089461 0.000191796 0.001377683 0.0007349765 0.0001655297 0.001382749 4.5179e-06 0.0007240409 0.00135852 0.0008416732
#
# [1] 1999
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.000280745
#
# solution.v:
#  0.3333932 0.07193499 0.2998779 0.07097966 0.2238142
#
# solution.w:
#  0.0003106536 0.4464229 0.000464168 0.09345819 0.4466943 0.002024241 0.0003725857 0.0001441128 0.0006644149 0.0003773807 0.0001568419 0.001757706 0.0005821207 0.0002397721 0.005462189 0.0008684482
#
# [1] 2000
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0002522649
#
# solution.v:
#  0.2841811 0.390198 0.3072904 0.01633752 0.001992897
#
# solution.w:
#  0.006691906 0.2604135 0.01130387 0.0521979 0.3183894 0.04419417 0.007668815 3.47948e-05 0.009079267 0.01034078 7.09174e-05 0.0572272 0.01171948 0.005404259 0.1809671 0.02429663
#
# [1] 2001
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0003042721
#
# solution.v:
#  0.2300167 0.3700114 0.393585 0.006386841 0
#
# solution.w:
#  0.05121218 0.2659888 0.03791813 0.05109935 0.02624605 0.07985753 0.04132484 0.05403987 0.03250165 0.03311749 0.03143242 0.08711503 0.03540303 0.02356482 0.06408271 0.0850961
#
# [1] 2002
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.0007764939
#
# solution.v:
#  0.001419114 0.5382115 0.02510224 0.3728741 0.06239307
#
# solution.w:
#  1.1132e-05 0.3149149 2.24333e-05 0.2525168 0.4317323 0.0001018502 1.35182e-05 2.3663e-06 2.82547e-05 1.95779e-05 1.40228e-05 0.0001485664 3.13586e-05 7.8819e-06 0.000390189 4.47872e-05
#
# [1] 2003
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.001120572
#
# solution.v:
#  0.00266653 0.3546898 0.3480664 0.1969765 0.09760068
#
# solution.w:
#  1.39574e-05 0.4003205 2.67686e-05 0.1917783 0.4061733 0.0001950806 1.72232e-05 4.8192e-06 3.24109e-05 2.21586e-05 3.1548e-06 0.0009970029 2.88173e-05 8.7826e-06 0.0003086974 6.89955e-05
#
# [1] 2004
#
# X1, X0, Z1, Z0 all come directly from dataprep object.
#
#
# ****************
#  searching for synthetic control unit
#
#
# ****************
# ****************
# ****************
#
# MSPE (LOSS V): 0.001292329
#
# solution.v:
#  0.1126964 0.1979929 0.005323103 0.6839873 2.981e-07
#
# solution.w:
#  0.02035471 0.06228188 0.02965433 0.03795651 0.01986484 0.04828888 0.02556578 0.1371371 0.03739769 0.02801424 0.02561473 0.04820158 0.02952595 0.01818593 0.3690411 0.06291474
#
# [1] 2005

# %%
# now the figure
rownames(store) <- 1985:2007

# set bounds in gaps data:
gap.start <- 1
gap.end <- nrow(store)
years <- 1985:2007
# gap.end.pre <- which(rownames(store)==)


# Plot
plot(c(1,2),c(1,2),
   ylim=c(-0.3,0.3),xlab="year",
   xlim=c(1985,2007),ylab="gap in crime against women per 1000 women",
   type="l",lwd=2,col="black",
   xaxs="i",yaxs="i")

# Add lines for control years 
for (i in 1:ncol(store)) { lines(years,store[gap.start:gap.end,i],col="gray") }

## Add ASSAM Line at 2002 as a treatment year
lines(years,store[gap.start:gap.end,which(colnames(store)==2002)],lwd=2,col="black")

# Add grid
abline(v=2002,lty="dotted",lwd=2)
abline(h=0,lty="dashed",lwd=2)
legend("bottomright",legend=c("2002 as Treatment","Control Years (1988:2005)"),
       lty=c(1,1),col=c("black","gray"),lwd=c(2,1),cex=.8)
# Out:
# plot without title

# %%
# dot chart
mse <- function(x){mean(x^2)}

preloss.time = rep(NA,18)
postloss.time = rep(NA,18)
names(preloss.time) = as.character(1988:2005)
names(postloss.time) = as.character(1988:2005)

for (i in 1:ncol(store)){
  treat.year = as.character(i+1987)
  gap.end.pre <- which(rownames(store)==treat.year)
  preloss.time[i] <- mse(store[gap.start:gap.end.pre,2])
  postloss.time[i] <- mse(store[(gap.end.pre+1):gap.end,2])
}


#pdf("2ratio_post_to_preperiod_rmse2a.pdf")
dotchart(sort(postloss.time/preloss.time),
         xlab= "Post-Period MSE / Pre-Period MSE",
         pch=19)
# Out:
# plot without title

# %%
(postloss.time/preloss.time)[12]
